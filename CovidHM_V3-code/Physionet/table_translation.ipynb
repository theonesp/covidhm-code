# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os
import settings as settings

# %%
source_path = settings.csv_tables

patients = pd.read_csv(os.path.join(source_path, "patients_01.csv"))
diagnosis_er = pd.read_csv(os.path.join(source_path, "diagnosis_er_adm_03.csv"))
diagnosis_hosp = pd.read_csv(os.path.join(source_path, "diagnosis_hosp_adm_02.csv"))
vital_signs = pd.read_csv(os.path.join(source_path, "vital_signs_04.csv"))
medication = pd.read_csv(os.path.join(source_path, "medication_05.csv"))
lab = pd.read_csv(os.path.join(source_path, "lab_06.csv"))

# Show all rows from value_counts
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Patients

# %%
print(patients.info())

# diag_inpat
print("\n", patients['diag_inpat'].value_counts())

dict_patients = {
    'COVID CONFIRMADO': 'COVID CONFIRMED',
    'COVID SOSPECHA': 'COVID SUSPECTED'
}

patients['diag_inpat'] = patients['diag_inpat'].replace(dict_patients)
print(patients['diag_inpat'].value_counts())

# destin_discharge
print("\n", patients['destin_discharge'].value_counts())

dict_destin_discharge = {
    'Domicilio': 'Home',
    'Fallecimiento': 'Death',
    'Traslado al Hospital': 'Transfer to Hospital',
    'Traslado a un Centro Sociosanitario': 'Transfer to a Socio-Sanitary Center',
    'Alta Voluntaria': 'Voluntary Discharge',
    'Fuga': 'Absconded'
}

patients['destin_discharge'] = patients['destin_discharge'].replace(dict_destin_discharge)
print("\n", patients['destin_discharge'].value_counts())

# diag_emerg
print("\n", patients['diag_emerg'].value_counts())

dict_diag_emerg = {
    'DIFICULTAD RESPIRATORIA': 'RESPIRATORY DISTRESS',
    'SOSPECHA COVID-19': 'SUSPECTED COVID-19',
    'FIEBRE': 'FEVER',
    'CUADRO CATARRAL': 'COMMON COLD SYNDROME',
    'TOS': 'COUGH',
    'MALESTAR GENERAL': 'GENERAL DISCOMFORT',
    'MALESTAR': 'DISCOMFORT',
    'DETERIORO PACIENTE ONCOLÓGICO': 'DECLINE IN ONCOLOGICAL PATIENT',
    'DOLOR ABDOMINAL': 'ABDOMINAL PAIN',
    'DIARREA': 'DIARRHEA',
    'DESORIENTACIÓN': 'DISORIENTATION',
    'DISURIA': 'DYSURIA',
    'NÁUSEAS/VÓMITOS': 'NAUSEA/VOMITING',
    'DOLOR TORÁCICO': 'CHEST PAIN',
    'MAREO': 'DIZZINESS',
    'ASTENIA': 'ASTHENIA',
    'CONTRACCIONES': 'CONTRACTIONS',
    'SÍNCOPE': 'SYNCOPE',
    'DOLOR COSTAL': 'COSTALGIA',
    'DOLOR (SIN ESPECIFICAR)': 'PAIN (UNSPECIFIED)',
    'TAQUICARDIA': 'TACHYCARDIA',
    'DOLOR AL TRAGAR': 'DIFFICULTY SWALLOWING',
    'TRAUMATISMO CRANEAL': 'HEAD INJURY',
    'SOSPECHA RPM': 'SUSPECTED RUPTURED MEMBRANES',
    'DOLOR MMII': 'LOWER LIMB PAIN',
    'HINCHAZÓN MMII': 'LOWER LIMB EDEMA',
    'DOLOR LUMBAR': 'LOW BACK PAIN',
    'HIPERGLUCEMIA': 'HYPERGLYCEMIA',
    'HIPERTENSIÓN ARTERIAL': 'HYPERTENSION',
    'DIFICULTAD EN DIURESIS': 'DIFFICULTY IN DIURESIS',
    'PCR': 'CARDIOPULMONARY RESUSCITATION',
    'PALPITACIONES (ARRITMIA)': 'PALPITATIONS (ARRHYTHMIA)',
    'METRORRAGIA 3º TRIMESTRE': 'THIRD TRIMESTER METRORRHAGIA',
    'ALTERACIÓN ANALÍTICA': 'LABORATORY ABNORMALITY',
    'CEFALEA': 'HEADACHE',
    'COMPLICACIÓN POSTQUIRÚRGICA': 'POSTSURGICAL COMPLICATION',
    'ANSIEDAD': 'ANXIETY',
    'SOSPECHA CÓLICO NEFRITICO': 'SUSPECTED NEPHRITIC COLIC',
    'MELENAS': 'MELAENA',
    'DEBILIDAD DE EXTREMIDADES': 'EXTREMITY WEAKNESS',
    'POLITRAUMATISMO/POLICONTUSIÓN': 'POLYTRAUMA/POLYCONTUSION',
    'ESTREÑIMIENTO': 'CONSTIPATION',
    'DOLOR MMSS': 'UPPER LIMB PAIN',
    'REACCIÓN ALÉRGICA': 'ALLERGIC REACTION',
    'DIFICULTAD PARA HABLAR': 'DIFFICULTY SPEAKING',
    'HERIDA CABEZA/CARA': 'HEAD/FACE WOUND',
    'RECTORRAGIA': 'RECTAL BLEEDING',
    'PÉRDIDA DE CONOCIMIENTO': 'LOSS OF CONSCIOUSNESS',
    'MOLESTIAS INESPECIFICAS EN GESTANTE': 'NON-SPECIFIC DISCOMFORT IN PREGNANCY',
    'TRAUMATISMO MMII': 'LOWER LIMB TRAUMA',
    'INTOXICACIÓN MEDICAMENTOSA': 'DRUG INTOXICATION',
    'CONSULTA': 'CONSULTATION',
    'EPISTAXIS': 'EPISTAXIS',
    'DOLOR INGUINAL': 'GROIN PAIN',
    'TUMORACIÓN (SIN ESPECIFICAR)': 'MASS (UNSPECIFIED)',
    'FRACTURA ÓSEA (SIN ESPECIFICAR)': 'BONE FRACTURE (UNSPECIFIED)',
    'DIPLOPÍA': 'DIPLOPIA',
    'ICTERICIA': 'JAUNDICE',
    'TRAUMATISMO MMII/MMSS': 'LOWER LIMB/UPPER LIMB TRAUMA',
    'HEMATEMESIS': 'HEMATHEMESIS',
    'ERUPCIÓN CUTÁNEA': 'SKIN ERUPTION',
    'HERIDA (CUALQUIER LOCALIZACIÓN)': 'WOUND (ANY LOCATION)',
    'ALTERACIÓN DEL NIVEL DE CONCIENCIA': 'ALTERED LEVEL OF CONSCIOUSNESS',
    'HINCHAZÓN MMSS': 'UPPER LIMB EDEMA',
    'PARÁLISIS FACIAL': 'FACIAL PARALYSIS',
    'DOLOR CERVICAL': 'NECK PAIN',
    'TRAUMATISMO LUMBAR': 'LUMBAR TRAUMA',
    'PRÓDROMOS DE PARTO': 'PRE-LABOR SYMPTOMS',
    'PARESTESIAS': 'PARESTHESIAS',
    'COMPLICACIÓN HERIDA QUIRÚRGICA': 'POSTSURGICAL WOUND COMPLICATION',
    'HEMORRAGIA DIGESTIVA': 'DIGESTIVE BLEEDING',
    'DOLOR FACIAL': 'FACIAL PAIN',
    'HEMATOMA/S': 'HEMATOMA/S',
    'HEMOPTISIS': 'HEMOPTYSIS',
    'TRAUMATISMO COSTAL': 'COSTAL TRAUMA',
    'TRAUMATISMO FACIAL': 'FACIAL TRAUMA',
    'HEMATURIA': 'HEMATURIA',
    'Disuria': 'DYSURIA',
    'PARESIA MMSS': 'UPPER LIMB PARESIS',
    'CONVULSIONES': 'CONVULSIONS'
}

patients['diag_emerg'] = patients['diag_emerg'].replace(dict_diag_emerg)
print("\n", patients['diag_emerg'].value_counts())


# department_emerg
print("\n", patients['department_emerg'].value_counts())

dict_department_emerg = {
    'Medicina de Urgencias': 'Emergency Medicine',
    'Medicina Interna': 'Internal Medicine',
    'Medicina General': 'General Medicine',
    'Ginecología': 'Gynecology',
    'Pediatría': 'Pediatrics',
    'Traumatología': 'Traumatology',
    'Medicina Intensiva': 'Intensive Care Medicine',
    'Cardiología': 'Cardiology',
    'Oncología Médica': 'Medical Oncology',
    'Cirugía General': 'General Surgery',
    'Cirugía Torácica': 'Thoracic Surgery',
    'Cirugía Vascular': 'Vascular Surgery'
}

patients['department_emerg'] = patients['department_emerg'].replace(dict_department_emerg)
print("\n", patients['department_emerg'].value_counts())

# destin_emerg
print("\n", patients['destin_emerg'].value_counts())

dict_destin_emerg = {
    'Ingreso': 'Admission',
    'Domicilio': 'Home',
    'Traslado a Otros Hospitales': 'Transfer to other hospitals',
    'Traslado a Hospital del Grupo': 'Transfer to other HM group hospital',
    'Alta Voluntaria por motivos personales': 'Voluntary discharge for personal reasons',
    'Alta Voluntaria por falta de camas': 'Voluntary discharge due to lack of beds',
    'Alta Voluntaria': 'Voluntary discharge'
}


patients['destin_emerg'] = patients['destin_emerg'].replace(dict_destin_emerg)
print("\n", patients['destin_emerg'].value_counts())

# ant_diag_inpat
print("\n", patients['ant_diag_inpat'].value_counts())

dict_ant_diag_inpat = {
    'COVID CONFIRMADO': 'CONFIRMED COVID',
    'INFECCION RESPIRATORIA': 'RESPIRATORY INFECTION',
    'NEUMONIA': 'PNEUMONIA',
    'INFECCION URINARIA': 'URINARY INFECTION',
    'DOLOR ABDOMINAL': 'ABDOMINAL PAIN',
    'INSUFICIENCIA RESPIRATORIA': 'RESPIRATORY FAILURE',
    'HERNIA INGUINAL': 'INGUINAL HERNIA',
    'INSUFICIENCIA CARDIACA': 'HEART FAILURE',
    'ESTUDIO HEMODINAMICO': 'HEMODYNAMIC STUDY',
    'DOLOR TORACICO ': 'CHEST PAIN',
    'TEP': 'PULMONARY EMBOLISM (PE)',
    'COLECISTECTOMIA LAPAROSCOPICA': 'LAPAROSCOPIC CHOLECYSTECTOMY',
    'INGRESO EN PLANTA': 'ADMISSION TO WARD',
    'INSUFICIENCIA RENAL': 'RENAL FAILURE',
    'PARTO': 'CHILDBIRTH',
    'HEMORRAGIA DIGESTIVA': 'DIGESTIVE HEMORRHAGE',
    'EPOC REAGUDIZADO': 'EXACERBATED COPD',
    'ESTUDIO GENERAL': 'GENERAL STUDY',
    'HISTEROSCOPIA': 'HYSTEROSCOPY',
    'OBSTRUCCION INTESTINAL': 'INTESTINAL OBSTRUCTION',
    'COLICO NEFRITICO': 'RENAL COLIC',
    'RTU': 'TURP (TRANSURETHRAL RESECTION OF THE PROSTATE)',
    'FRACTURA CADERA': 'HIP FRACTURE',
    'COVID SOSPECHA': 'SUSPECTED COVID',
    'FIEBRE SIN FOCO': 'FEVER OF UNKNOWN ORIGIN',
    'HERNIA UMBILICAL': 'UMBILICAL HERNIA',
    'PORT-A-CATH': 'PORT-A-CATH',
    'FIBRILACION AURICULAR': 'ATRIAL FIBRILLATION',
    'LUMBALGIA': 'LOW BACK PAIN',
    'GEA': 'ACUTE GASTROENTERITIS',
    'ANEMIA (TRANSFUSION)': 'ANEMIA (TRANSFUSION)',
    'CESAREA': 'CESAREAN SECTION',
    'BIOPSIA': 'BIOPSY',
    'DIARREA A ESTUDIO': 'DIARRHEA UNDER STUDY',
    'VARICES': 'VARICOSE VEINS',
    'PROTESIS DE CADERA': 'HIP PROSTHESIS',
    'EXTIRP. TUMOR PARTES BLANDAS PROFUNDAS': 'DEEP SOFT TISSUE TUMOR REMOVAL',
    'ARTROSCOPIA DIAGNOSTICA RODILLA': 'DIAGNOSTIC KNEE ARTHROSCOPY',
    'BRONCOESPASMO': 'BRONCHOSPASM',
    'ARTROSCOPIA TERAPEUTICA RODILLA:MENISCO': 'THERAPEUTIC KNEE ARTHROSCOPY: MENISCUS',
    'ARTROSCOPIA': 'ARTHROSCOPY',
    'SINCOPE': 'SYNCOPE',
    'BIOPSIA PROSTATA': 'PROSTATE BIOPSY',
    'PROTESIS DE RODILLA': 'KNEE PROSTHESIS',
    'ESTUDIO ELECTROFISIOLOGICO': 'ELECTROPHYSIOLOGICAL STUDY',
    'CENS.SINUSOPAT CRON.': 'CHRONIC SINUSITIS',
    'BRONCOASPIRACIÓN': 'BRONCHOASPIRATION',
    'SIND. CORONARIO AGUDO': 'ACUTE CORONARY SYNDROME',
    'PIELONEFRITIS AGUDA': 'ACUTE PYELONEPHRITIS',
    'ARTROSCOPIA HOMBRO': 'SHOULDER ARTHROSCOPY',
    'TROMBOSIS VENOSA': 'VENOUS THROMBOSIS',
    'DIVERTICULITIS': 'DIVERTICULITIS',
    'COLECISTECTOMIA': 'CHOLECYSTECTOMY',
    'IMPLANTE MARCAPASOS': 'PACEMAKER IMPLANT',
    'AIT': 'TIA (TRANSIENT ISCHEMIC ATTACK)',
    'SINDROME CONFUSIONAL': 'CONFUSIONAL SYNDROME',
    'CIFOPLASTIA': 'KYPHOPLASTY',
    'ACV': 'STROKE',
    'ARTROPLASTIA HOMBRO': 'SHOULDER ARTHROPLASTY',
    'FRACTURA RADIO': 'RADIUS FRACTURE',
    'VOMITOS': 'VOMITING',
    'RECTORRAGIA': 'RECTAL BLEEDING',
    'SEPSIS': 'SEPSIS',
    'DERRAME PLEURAL': 'PLEURAL EFFUSION',
    'BRONQUITIS AGUDA': 'ACUTE BRONCHITIS',
    'EXTR MATERIAL OSTEO': 'REMOVAL OF OSTEO MATERIAL',
    'CRISIS HIPERTENSIVA': 'HYPERTENSIVE CRISIS',
    'SEPTOPLASTIA': 'SEPTOPLASTY',
    'EVENTRACION': 'EVENTRATION',
    'PROSTATECTOMIA': 'PROSTATECTOMY',
    'ANEMIA. ESTUDIO': 'ANEMIA STUDY',
    'CEFALEA': 'HEADACHE',
    'CELULITIS': 'CELLULITIS',
    'DETERIORO COGNITIVO': 'COGNITIVE DECLINE',
    'PROSTATITIS AGUDA': 'ACUTE PROSTATITIS',
    'PANCREATITIS AGUDA': 'ACUTE PANCREATITIS',
    'EMBOLIZACION': 'EMBOLIZATION',
    'QUISTE MAXILAR': 'MAXILLARY CYST',
    'TENOSINOVITIS': 'TENOSYNOVITIS',
    'HEMATURIA': 'HEMATURIA',
    'ABSCESO CAVIDAD ABDOMINAL': 'ABDOMINAL CAVITY ABSCESS',
    'INFECCION PARTES BLANDAS': 'SOFT TISSUE INFECTION',
    'MICROCIRUGIA LARINGE': 'LARYNGEAL MICROSURGERY',
    'FRACTURA TOBILLO': 'ANKLE FRACTURE',
    'FISTULA PERIANAL': 'PERIANAL FISTULA',
    'RTU POR LASER': 'LASER TURP',
    'HEMATOMA SUBDURAL': 'SUBDURAL HEMATOMA',
    'PANCITOPENIA': 'PANCYTOPENIA',
    'MICROC.NERVIOS PERIF': 'PERIPHERAL NERVE MICROSURGERY',
    'APENDICITIS': 'APPENDICITIS',
    'RIZOLISIS': 'RHIZOLYSIS',
    'PAAF PROSTATICA': 'PROSTATIC FNA (FINE NEEDLE ASPIRATION)',
    'TIROIDECTOMIA': 'THYROIDECTOMY',
    'PSEUDOOBSTRUCCION INTESTINAL': 'INTESTINAL PSEUDO-OBSTRUCTION',
    'CRISIS CONVULSIVA': 'SEIZURE',
    'POLITRAUMATISMO': 'POLYTRAUMA',
    'TRATAMIENTO FARMACOLOGICO': 'PHARMACOLOGICAL TREATMENT',
    'FUSIONES VERTEBRALES POR VIA POSTERIOR': 'POSTERIOR VERTEBRAL FUSIONS',
    'ARTRODESIS COLUMNA LUMBAR': 'LUMBAR SPINE ARTHRODESIS',
    'NEUTROPENIA FEBRIL': 'FEBRILE NEUTROPENIA',
    'CIRUGIA DE LA MANO': 'HAND SURGERY',
    'ILEITIS': 'ILEITIS',
    'FRACTURA VERTEBRA': 'VERTEBRAL FRACTURE',
    'TRASPLANTE MO': 'BONE MARROW TRANSPLANT',
    'METATARSO VARO': 'METATARSUS VARUS',
    'INFECCION HERIDA QUIRÚRGICA': 'SURGICAL WOUND INFECTION',
    'FRACTURA DEDO': 'FINGER FRACTURE',
    'LOBECTOMIA': 'LOBECTOMY',
    'ESTUDIO VASCULAR': 'VASCULAR STUDY',
    'DIPLOPIA A ESTUDIO': 'DIPLOPIA UNDER STUDY',
    'TRATAMIENTO DOLOR': 'PAIN TREATMENT',
    'URETEROSCOPIA': 'URETEROSCOPY',
    'MIOMECTOMIA': 'MYOMECTOMY',
    'TUMORACION CUTANEA': 'CUTANEOUS TUMOR',
    'LUXACION CADERA': 'HIP DISLOCATION',
    'NEO DE RECTO': 'RECTAL CANCER',
    'TUMOR MEDIASTINO': 'MEDIASTINAL TUMOR',
    'MAREO (OBSERVACION)': 'DIZZINESS (OBSERVATION)',
    'CIERRE TRAQUEOSTOMIA': 'TRACHEOSTOMY CLOSURE',
    'TENOLISIS MANO': 'HAND TENOLYSIS',
    'HEMITIROIDECTOMIA': 'HEMITHYROIDECTOMY',
    'EXTRACCION CUERPO EXTRAÑO': 'FOREIGN BODY REMOVAL',
    'COLOCACION CATETER': 'CATHETER PLACEMENT',
    'BY-PASS-CORONARIO': 'CORONARY BYPASS',
    'UROPATIA OBSTRUCTIVA': 'OBSTRUCTIVE UROPATHY',
    'LINFOMA': 'LYMPHOMA',
    'RESECCION OSEA': 'BONE RESECTION',
    'ABSCESO PERIANAL': 'PERIANAL ABSCESS',
    'ARTRODESIS COLUMNA': 'SPINAL ARTHRODESIS',
    'SAFENECTOMIA': 'SAPHENECTOMY',
    'EPISTAXIS': 'EPISTAXIS',
    'HIPERGLUCEMIA': 'HYPERGLYCEMIA',
    'FRACTURA PELVIS': 'PELVIS FRACTURE',
    'FRACTURA FEMUR': 'FEMUR FRACTURE',
    'FARINGOPLASTIA': 'PHARYNGOPLASTY',
    'HEMOPTISIS': 'HEMOPTYSIS',
    'LEUCEMIA AGUDA': 'ACUTE LEUKEMIA',
    'NEFRECTOMIA': 'NEPHRECTOMY',
    'VITRECTOMIA': 'VITRECTOMY',
    'URETROCISTOSCOPIA': 'URETHROCYSTOSCOPY',
    'PUNCION LUMBAR': 'LUMBAR PUNCTURE',
    'MIELOMA MULTIPLE': 'MULTIPLE MYELOMA',
    'EXTRACCION CATETER': 'CATHETER REMOVAL',
    'HIDROCELE': 'HYDROCELE',
    'CUADRANTECTOMIA': 'QUADRANTECTOMY',
    'LEGRADO': 'CURETTAGE',
    'NEUMOTORAX': 'PNEUMOTHORAX',
    'HEMORROIDES': 'HEMORRHOIDS',
    'ABSCESO PERIAMIGDALINO': 'PERITONSILLAR ABSCESS',
    'SIND. TUNEL CARPIANO': 'CARPAL TUNNEL SYNDROME',
    'COLECISTITIS AGUDA': 'ACUTE CHOLECYSTITIS',
    'HALLUX VALGUS': 'HALLUX VALGUS',
    'DESHIDRATACION': 'DEHYDRATION',
    'HERNIA ESTRANGULADA': 'STRANGULATED HERNIA',
    'OSTEOMIELITIS': 'OSTEOMYELITIS',
    'FRACTURA CUBITO': 'ULNA FRACTURE',
    'DISEC.FUNC.CUELLO': 'NECK DISSECTION',
    'METRORRAGIA': 'METRORRHAGIA',
    'PLASTIA': 'PLASTY',
    'ESPONDILODISCITIS': 'SPONDYLODISCITIS',
    'CONDROMALACIA': 'CHONDROMALACIA',
    'HERPES ZOSTER': 'HERPES ZOSTER',
    'PARESTESIAS A ESTUDIO': 'PARESTHESIAS UNDER STUDY',
    'HERNIA DISCAL': 'DISC HERNIATION',
    'ENDOCARDITIS BACTERIANA': 'BACTERIAL ENDOCARDITIS',
    'QUISTE SINOVIAL': 'SYNOVIAL CYST',
    'ARTROLISIS': 'ARTHROLYSIS',
    'COLONOSCOPIA': 'COLONOSCOPY',
    'TRATAMIENTO QUIMIOT': 'CHEMOTHERAPY TREATMENT',
    'RINOPLASTIA': 'RHINOPLASTY',
    'ARTRODESIS DE HOMBRO': 'SHOULDER ARTHRODESIS',
    'MASTECTOMIA': 'MASTECTOMY',
    'ASCITIS': 'ASCITES',
    'COLICO BILIAR': 'BILIARY COLIC',
    'TUMOR CEREBRAL': 'BRAIN TUMOR',
    'PROSTATECTOMIA LAPAR': 'LAPAROSCOPIC PROSTATECTOMY',
    'SINUS PILONIDAL': 'PILONIDAL SINUS',
    'HEMICOLECTOMIA': 'HEMICOLECTOMY',
    'LINFADENECTOMIA': 'LYMPHADENECTOMY',
    'BRADICARDIA': 'BRADYCARDIA',
    'ESTUDIO VASCULAR CEREBRAL': 'CEREBRAL VASCULAR STUDY',
    'MASA PULMONAR': 'PULMONARY MASS',
    'DORSALGIA AGUDA': 'ACUTE DORSALGIA',
    'ANGIODISPLASIA': 'ANGIODYSPLASIA',
    'HEPATECTOMIA': 'HEPATECTOMY',
    'TAQUICARDIA SINUSAL': 'SINUS TACHYCARDIA',
    'INCONTINENCIA URINAR': 'URINARY INCONTINENCE',
    'POLIPECTOMIA': 'POLYPECTOMY',
    'FRACTURA PERONE': 'FIBULA FRACTURE',
    'SIND. CONSTITUCIONAL': 'CONSTITUTIONAL SYNDROME',
    'DEDO MARTILLO': 'HAMMER TOE',
    'CARDIOVERSION': 'CARDIOVERSION',
    'EDEMA MMII': 'LOWER LIMB EDEMA',
    'NEUMONÍA ASPIRATIVA': 'ASPIRATION PNEUMONIA',
    'ARTRODESIS COLUMNA CERVICAL': 'CERVICAL SPINE ARTHRODESIS',
    'LAPAROSCOPIA EXPLORADORA': 'EXPLORATORY LAPAROSCOPY',
    'HEMATOMA PARTES BLANDAS': 'SOFT TISSUE HEMATOMA',
    'HEMORROIDECTOMIA': 'HEMORRHOIDECTOMY',
    'TUNEL CARPIANO': 'CARPAL TUNNEL',
    'HERIDA PROFUNDA': 'DEEP WOUND',
    'FRACTURA HUMERO': 'HUMERUS FRACTURE',
    'EDEMA AGUDO PULMON': 'ACUTE PULMONARY EDEMA',
    'RESECCIÓN PULMONAR': 'LUNG RESECTION',
    'BRONCONEUMONIA': 'BRONCHOPNEUMONIA',
    'TUMORACION CERVICAL': 'CERVICAL TUMOR',
    'BACTERIEMIA': 'BACTEREMIA',
    'MIASTENIA GRAVIS': 'MYASTHENIA GRAVIS',
    'ESTAPEDECTOMIA': 'STAPEDECTOMY',
    'ESTENOSIS ESOFAGICA': 'ESOPHAGEAL STENOSIS',
    'COLITIS AGUDA': 'ACUTE COLITIS',
    'PARATIRODECTOMÍA': 'PARATHYROIDECTOMY',
    'FIMOSIS': 'PHIMOSIS',
    'DERRAME PERICARDICO': 'PERICARDIAL EFFUSION',
    'CRANEOTOMIA': 'CRANIOTOMY',
    'INTOXICACION MEDICAMENTOSA': 'DRUG INTOXICATION',
    'TUMOR CUTANEO': 'CUTANEOUS TUMOR',
    'CPRE': 'ERCP (ENDOSCOPIC RETROGRADE CHOLANGIOPANCREATOGRAPHY)',
    'HIPONATREMIA': 'HYPONATREMIA',
    'PROTESIS DE HOMBRO': 'SHOULDER PROSTHESIS',
    'NEUMONIA BILATERAL': 'BILATERAL PNEUMONIA',
    'METASTASIS OSEAS': 'BONE METASTASIS',
    'TCE': 'TBI (TRAUMATIC BRAIN INJURY)',
    'ARTROSCOPIA TERAPEUTICA RODILLA:LIGAMENTOS': 'THERAPEUTIC KNEE ARTHROSCOPY: LIGAMENTS',
    'GANGLION': 'GANGLION',
    'RECAMBIO PROTESIS': 'PROSTHESIS REPLACEMENT',
    'DESCOMPENSACION DIABETICA': 'DIABETIC DECOMPENSATION',
    'LUXACION TOBILLO': 'ANKLE DISLOCATION',
    'TERAPIA METABOLICA': 'METABOLIC THERAPY',
    'IMPLANTE RESERVORIO': 'RESERVOIR IMPLANT',
    'ACROMIOPLASTIA': 'ACROMIOPLASTY',
    'GASTRECTOMIA': 'GASTRECTOMY',
    'APP': 'APPENDICITIS',
    'HEPATOPATIA A FILIAR': 'Familial hepatopathy',
    'ERITRODERMIA': 'Erythroderma',
    'FIEBRE PUERPERAL': 'Puerperal fever',
    'ADENOIDECTOMIA': 'Adenoidectomy',
    'ADENOMECTOMIA PROSTATICA POR LAPAROTOMIA': 'Prostate adenomectomy by laparotomy',
    'ARRITMIA': 'Arrhythmia',
    'FRACTURA MANDIBULA': 'Mandible fracture',
    'ABDOMEN AGUDO': 'Acute abdomen',
    'FRACTURA MUÑECA': 'Wrist fracture',
    'EVISCERACIÓN': 'Evisceration',
    'ENTEROCOLITIS': 'Enterocolitis',
    'ISQUEMIA ARTERIAL': 'Arterial ischemia',
    'INTOLERANCIA ALIMENTARIA': 'Food intolerance',
    'EXTRACCION DENTAL': 'Dental extraction',
    'PUNCION PULMONAR': 'Pulmonary puncture',
    'EMPIEMA PLEURAL': 'Pleural empyema',
    'REDUCCION MAMA': 'Breast reduction',
    'ARTRODESIS PIE': 'Foot arthrodesis',
    'CIRCUNCISION': 'Circumcision',
    'MENINGITIS VIRICA': 'Viral meningitis',
    'HEPATITIS AGUDA': 'Acute hepatitis',
    'TTO MEDICAMENTOSO': 'Drug treatment',
    'IMPLANTE ELECTRODOS': 'Electrode implantation',
    'PARESIA A ESTUDIO': 'Paresis under study',
    'NEO DE PULMON': 'Lung neoplasm',
    'ABSCESO PARTES BLANDAS': 'Soft tissue abscess',
    'QUISTE MANO': 'Hand cyst',
    'HIDROCEFALIA': 'Hydrocephalus',
    'ESTATUS CONVULSIVO': 'Convulsive status',
    'FRACTURA TIBIA-PERONE': 'Tibia-fibula fracture',
    'ENDARTERECTOMIA': 'Endarterectomy',
    'PLASTIA LIGAMENTOS': 'Ligamentoplasty',
    'ENCEFALOPATIA HEPATICA': 'Hepatic encephalopathy',
    'ARTROSCOPIA CADERA': 'Hip arthroscopy',
    'TAQUICARDIA SUPRAVENTRICULAR': 'Supraventricular tachycardia',
    'SIND. MIELODISPLASICO': 'Myelodysplastic syndrome',
    'OBSERVACION': 'Observation',
    'PERFORACION INTESTINAL': 'Intestinal perforation',
    'ABSCESO GLUTEO': 'Gluteal abscess',
    'ESTENOSIS ANO': 'Anal stenosis',
    'CISTOLITECTOMIA': 'Cistolitectomy',
    'OTROS TRASTORNOS MENTALES': 'Other mental disorders',
    'ECTROPION': 'Ectropion',
    'LIGAMENTOPLASTIA': 'Ligamentoplasty',
    'HISTERECT. VAGINAL': 'Vaginal hysterectomy',
    'NEO DE OVARIO': 'Ovarian neoplasm',
    'FISURA ANAL': 'Anal fissure',
    'ICTERICIA OBSTRUCTIVA': 'Obstructive jaundice',
    'TENDINITIS': 'Tendonitis',
    'NEUROMA DE MORTON': 'Morton\'s neuroma',
    'CATARATA BILATERAL': 'Bilateral cataract',
    'ADENOMA HIPOFISIS': 'Pituitary adenoma',
    'HERNIA HIATO': 'Hiatal hernia',
    'FECALOMA': 'Fecaloma',
    'NODULO PULMONAR': 'Pulmonary nodule',
    'COLELITIASIS': 'Cholelithiasis',
    'CORDALES': 'Wisdom teeth',
    'ABLACION FA': 'Ablation for atrial fibrillation',
    'DACRIOCISTORINOSCOP.': 'Dacryocystorhinostomy',
    'PERITONITIS': 'Peritonitis',
    'EPIGASTRALGIA': 'Epigastralgia',
    'DUPUYTREN': 'Dupuytren\'s contracture',
    'RECAMBIO MARCAPASOS': 'Pacemaker replacement',
    'EPISODIO PSICOTICO': 'Psychotic episode',
    'URETERORRENOSCOPIA': 'Ureterorenoscopy',
    'NODULO TESTICULAR': 'Testicular nodule',
    'LARINGOSCOPIA': 'Laryngoscopy',
    'LIGAMENTOS CRUZADOS': 'Cruciate ligaments',
    'TROMBOPENIA': 'Thrombocytopenia',
    'PROTESIS DE MAMA': 'Breast prosthesis',
    'CONIZACION': 'Conization',
    'ENFERM. DE DUPUYTREN': 'Dupuytren\'s disease',
    'NEURALGIA': 'Neuralgia',
    'TRASTORNOS POR USO DE SUSTANCIAS': 'Substance use disorders',
    'PSEUDOARTROSIS': 'Pseudoarthrosis',
    'CAMB.PROTESIS VALV.': 'Valve prosthesis replacement',
    'ABSCESO HEPATICO': 'Hepatic abscess',
    'VALVULOPLASTIA': 'Valvuloplasty',
    'MASTITIS': 'Mastitis',
    'BY PASS ARTERIAL': 'Arterial bypass',
    'MASA ABDOMINAL': 'Abdominal mass',
    'ENF. INFLAMAT. PELVICA': 'Pelvic inflammatory disease',
    'ESCOLIOSIS': 'Scoliosis',
    'SARCOMA': 'Sarcoma',
    'ABSCESO MAMA': 'Breast abscess',
    'ENF.TEJIDO CONECTIVO': 'Connective tissue disorder',
    'HEPATOCARCINOMA': 'Hepatocellular carcinoma',
    'ARTRODESIS DEDOS': 'Finger arthrodesis',
    'TRASTORNOS DEPRESIVOS': 'Depressive disorders',
    '#¿NOMBRE?': 'Name?',
    'METASTASIS CEREBRALES': 'Brain metastasis',
    'PARAPARESIA': 'Paraparesis',
    'HISTERECTOMIA': 'Hysterectomy',
    'MASA RETROPERITONEAL': 'Retroperitoneal mass',
    'VERTIGO CENTRAL': 'Central vertigo',
    'ABSCESO MANDIBULAR': 'Mandibular abscess',
    'POLIPO NASAL': 'Nasal polyp',
    'CISTOCELE': 'Cystocele',
    'INFECCION DE HERIDA': 'Wound infection',
    'BURSITIS': 'Bursitis',
    'BIOPSIA MAMA': 'Breast biopsy',
    'ANEXECTOMIA POR LAPAROTOMIA': 'Salpingo-oophorectomy by laparotomy',
    'DACRIOCISTITIS': 'Dacryocystitis',
    'LUXACION HOMBRO': 'Shoulder dislocation',
    'LUXACION ABIERTA': 'Open dislocation',
    'NEUMOMEDIASTINO': 'Pneumomediastinum',
    'DISECCION AORTICA': 'Aortic dissection',
    'HISTERECTOMIA (LAP)': 'Laparoscopic hysterectomy',
    'ARTRITIS SEPTICA': 'Septic arthritis',
    'ESTUDIO DEL SUEÑO': 'Sleep study',
    'BIOPSIA RENAL': 'Renal biopsy',
    'ANEURISMA AORTA': 'Aortic aneurysm',
    'TRAUMA TORACICO': 'Thoracic trauma',
    'RETIRADA MATERIAL': 'Material withdrawal',
    'LEGRADO OBSTETRICO': 'Obstetric curettage',
    'LUXACION MANO': 'Hand dislocation',
    'OSTEOTOMIA': 'Osteotomy',
    'DSE': 'DSE',
    'TORACOTOMIA': 'Thoracotomy',
    'NEO DE ESTOMAGO': 'Stomach neoplasm',
    'DEHISCENCIA HERIDA': 'Wound dehiscence',
    'DISTRES RESPIRATORIO': 'Respiratory distress',
    'AMIGDALECTOMIA/MIRINGOTOMIA CON DRENAJE': 'Tonsillectomy/myringotomy with drainage',
    'TUMOR OSEO': 'Bone tumor',
     'CETOACIDOSIS DIABETICA': 'Diabetic ketoacidosis',
    'URETROTOMIA': 'Urethrotomy',
    'BRONCOSCOPIA': 'Bronchoscopy',
    'PLASTIA VAGINAL': 'Vaginal plastic surgery',
    'VULVECTOMIA': 'Vulvectomy',
    'ESQUIZOFRENIA Y OTROS TRASTORNOS PSICÓTICOS': 'Schizophrenia and other psychotic disorders',
    'OTOMASTOIDITIS': 'Otomastoiditis',
    'HEMORRAGIA CEREBRAL': 'Cerebral hemorrhage',
    'HERNIA HIATO (LAP)': 'Hiatal hernia (laparoscopic)',
    'ARTROPLASTIA': 'Arthroplasty',
    'APENDICITIS PERFORAD': 'Perforated appendicitis',
    'RESECCIÓN INTESTINAL': 'Intestinal resection',
    'MAMOPLASTIA': 'Mammoplasty',
    'BRONQUIOLITIS': 'Bronchiolitis',
    'INFECC. URINARIA': 'Urinary tract infection',
    'MALESTAR GENERAL': 'General malaise',
    'HIPOCALCEMIA': 'Hypocalcemia',
    'SIGMOIDECTOMIA': 'Sigmoidectomy',
    'FRACTURA ESCAFOIDES': 'Scaphoid fracture',
    'COLANGITIS': 'Cholangitis',
    'PANICULITIS MESENTERICA': 'Mesenteric panniculitis',
    'PLACENTA PREVIA': 'Placenta previa',
    'TAQUICARDIA VENTRIC': 'Ventricular tachycardia',
    'GANGLIO CENTINELA': 'Sentinel lymph node',
    'GASTRITIS AGUDA': 'Acute gastritis',
    'APLASTAMIENTO VERTEBRAL': 'Vertebral compression',
    'HERNIA DIAFRAGMÁTICA': 'Diaphragmatic hernia',
    'ENFERMEDAD CROHN': 'Crohn\'s disease',
    'CATARATA': 'Cataract',
    'QUISTE C.TIROGLOSO': 'Thyroglossal duct cyst',
    'ROTURA TENDON': 'Tendon rupture',
    'QUISTE OVARIO (LAP)': 'Ovarian cyst (laparoscopic)',
    'CHEQUEO': 'Check-up',
    'PC-FIEBRE A FILIAR': 'Familial fever',
    'GASTROSTOMÍA': 'Gastrostomy',
    'URETROPLASTIA': 'Urethroplasty',
    'SINOVECTOMIA': 'Synovectomy',
    'BLOQUEO ARTICULAR': 'Joint block',
    'LIGADURA DE TROMPAS': 'Tubal ligation',
    'NEO ESOFAGO': 'Neoesophagus',
    'INTOXICACION ANTICOAGULANTES': 'Anticoagulant intoxication',
    'COMPRESION MEDULAR': 'Spinal cord compression'
}

patients['ant_diag_inpat'] = patients['ant_diag_inpat'].replace(dict_ant_diag_inpat)
print("\n", patients['ant_diag_inpat'].value_counts())

# mechvent
print("\n", patients['mechvent'].value_counts())

dict_mechvent = {
    'SI': 'Yes',
}

patients['mechvent'] = patients['mechvent'].replace(dict_mechvent)
print("\n", patients['mechvent'].value_counts())

patients.to_csv(os.path.join(source_path, "english/patient_01.csv"), sep = ',', encoding='latin1', index=False)

# %% [markdown]
# # diagnosis_er

# %%
print(diagnosis_er.info())

diagnosis_er.to_csv(os.path.join(source_path, "english/diagnosis_er_02.csv"), sep = ',', index=False)

# %% [markdown]
# # diagnosis_hosp

# %%
print(diagnosis_hosp.info())

print(diagnosis_hosp['poad_13'].value_counts())

dict_poad = {
    'S': 'Y',
    'D': 'U', 
    'I': 'W', 
    'E': '1'
}

poad_columns = [col for col in diagnosis_hosp.columns if col.startswith('poad')]

# Aplicar replace() a las columnas seleccionadas
for col in poad_columns:
    diagnosis_hosp[col] = diagnosis_hosp[col].replace(dict_poad)

diagnosis_hosp.to_csv(os.path.join(source_path, "english/diagnosis_hosp_03.csv"), sep = ',', index=False)

# %% [markdown]
# # vital_signs

# %%
print(vital_signs.info())

print(vital_signs['sat_02_ing_obs'].value_counts())

vital_signs.to_csv(os.path.join(source_path, "english/vital_signs_04.csv"), sep = ',', encoding='latin1', index=False)

# %% [markdown]
# # medication

# %%
print(medication.info())

# Extract separate df of unique values of atc5 and another df with atc7
atc7 = medication[['id_atc7', 'atc7_name']].drop_duplicates()
atc5 = medication[['id_atc5', 'atc5_name']].drop_duplicates()

atc7.to_csv(os.path.join(source_path, "english/atc7.csv"), sep = ',', encoding='latin1', index=False)
atc5.to_csv(os.path.join(source_path, "english/atc5.csv"), sep = ',', encoding='latin1', index=False)

medication = medication.drop(columns=['atc7_name', 'atc5_name'])

print(medication['drug_comercial_name'].value_counts())

medication.to_csv(os.path.join(source_path, "english/medication_05.csv"), sep = ',', encoding='latin1', index=False)

# %% [markdown]
# # lab

# %%
print(lab.info())

print(lab['item_lab'].value_counts())

dict_item_lab = {
    'K -- POTASIO': 'K -- Potassium',
    'NA -- SODIO': 'NA -- Sodium',
    'CREA -- CREATININA': 'CREA -- Creatinine',
    'U -- UREA': 'U -- Urea',
    'PCR -- PROTEINA C REACTIVA': 'CRP -- C-reactive protein',
    'GLU -- GLUCOSA': 'GLU -- Glucose',
    'GOT -- GOT (AST)': 'AST -- Aspartate Aminotransferase (AST)',
    'LDH -- LDH': 'LDH -- Lactate Dehydrogenase (LDH)',
    'GPT -- GPT (ALT)': 'ALT -- Alanine Aminotransferase (ALT)',
    'LEUC -- Leucocitos': 'WBC -- White Blood Cells (Leukocytes)',
    'NEU -- Neutrófilos': 'NEU -- Neutrophils',
    'NEU% -- Neutrófilos %': 'NEU% -- Neutrophils %',
    'HEM -- Hematíes': 'RBC -- Red Blood Cells (Erythrocytes)',
    'LIN% -- Linfocitos %': 'LYM% -- Lymphocytes %',
    'LIN -- Linfocitos': 'LYM -- Lymphocytes',
    'PLAQ -- Recuento de plaquetas': 'PLT -- Platelet Count',
    'HCTO -- Hematocrito': 'HCT -- Hematocrit',
    'VCM -- Volumen Corpuscular Medio': 'MCV -- Mean Corpuscular Volume',
    'CHCM -- Conc. Hemoglobina Corpuscular Media': 'MCHC -- Mean Corpuscular Hemoglobin Concentration',
    'HGB -- Hemoglobina': 'HGB -- Hemoglobin',
    'HCM -- Hemoglobina Corpuscular Media': 'MCH -- Mean Corpuscular Hemoglobin',
    'VPM -- Volumen plaquetar medio': 'MPV -- Mean Platelet Volume',
    'MONO -- Monocitos': 'MONO -- Monocytes',
    'ADW -- Coeficiente de anisocitosis': 'RDW -- Red Cell Distribution Width',
    'MONO% -- Monocitos %': 'MONO% -- Monocytes %',
    'EOS -- Eosinófilos': 'EOS -- Eosinophils',
    'EOS% -- Eosinófilos %': 'EOS% -- Eosinophils %',
    'BAS% -- Basófilos %': 'BASO% -- Basophils %',
    'BAS -- Basófilos': 'BASO -- Basophils',
    'DD -- DIMERO D': 'D-DIMER -- D-dimer',
    'INR -- INR': 'INR -- International Normalized Ratio',
    'TP -- TIEMPO DE PROTROMBINA': 'PT -- Prothrombin Time',
    'AP -- ACTIVIDAD DE PROTROMBINA': 'PTA -- Prothrombin Activity',
    'GGT -- GGT (GAMMA GLUTAMIL TRANSPEPTIDASA)': 'GGT -- Gamma-Glutamyl Transferase',
    'APTT -- TIEMPO DE CEFALINA (APTT)': 'APTT -- Activated Partial Thromboplastin Time',
    'LAC -- LACTATO': 'LAC -- Lactate',
    'CA++ -- Ca++ Gasometria': 'Ca++ -- Calcium (Ionized)',
    'PO2 -- pO2': 'PO2 -- Partial Pressure of Oxygen',
    'BE(b) -- BE(b)': 'BE(b) -- Base Excess (Blood)',
    'BEecf -- BEecf': 'BEecf -- Base Excess (Extracellular Fluid)',
    'TCO2 -- tCO2(B)c': 'TCO2 -- Total CO2',
    'HCO3 -- HCO3-': 'HCO3 -- Bicarbonate',
    'PH -- pH': 'PH -- pH',
    'PCO2 -- pCO2': 'PCO2 -- Partial Pressure of Carbon Dioxide',
    'SO2C -- sO2c (Saturación de oxígeno)': 'SO2 -- Oxygen Saturation',
    'FA -- FOSFATASA ALCALINA': 'ALP -- Alkaline Phosphatase',
    'CK -- CK (CREATINQUINASA)': 'CK -- Creatine Kinase',
    'FIB -- FIBRINÓGENO': 'FIB -- Fibrinogen',
    'MG -- MAGNESIO': 'MG -- Magnesium',
    'FOS -- FOSFORO': 'PHOS -- Phosphate',
    'G-CORONAV (RT-PCR) -- Tipo de muestra: EXUDADO': 'G-CORONAV (RT-PCR) -- Sample Type: Exudate',
    'BT -- BILIRRUBINA TOTAL': 'TBIL -- Total Bilirubin',
    'BT -- BILIRRUBINA TOTAL                                                               ': 'TBIL -- Total Bilirubin',
    'CL -- CLORO': 'CL -- Chloride',
    'LEUC -- SISTEMATICO DE SANGRE': 'WBC -- White Blood Cells (Blood Count)',
    'NEU -- SISTEMATICO DE SANGRE': 'NEU -- Neutrophils (Blood Count)',
    'NEU% -- SISTEMATICO DE SANGRE': 'NEU% -- Neutrophils % (Blood Count)',
    'LIN% -- SISTEMATICO DE SANGRE': 'LYM% -- Lymphocytes % (Blood Count)',
    'PLAQ -- SISTEMATICO DE SANGRE': 'PLT -- Platelet Count (Blood Count)',
    'LIN -- SISTEMATICO DE SANGRE': 'LYM -- Lymphocytes (Blood Count)',
    'HEM -- SISTEMATICO DE SANGRE': 'RBC -- Red Blood Cells (Blood Count)',
    'HCTO -- SISTEMATICO DE SANGRE': 'HCT -- Hematocrit (Blood Count)',
    'VCM -- SISTEMATICO DE SANGRE': 'MCV -- Mean Corpuscular Volume (Blood Count)',
    'MONO -- SISTEMATICO DE SANGRE': 'MONO -- Monocytes (Blood Count)',
    'MONO% -- SISTEMATICO DE SANGRE': 'MONO% -- Monocytes % (Blood Count)',
    'HGB -- SISTEMATICO DE SANGRE': 'HGB -- Hemoglobin (Blood Count)',
    'CHCM -- SISTEMATICO DE SANGRE': 'MCHC -- Mean Corpuscular Hemoglobin Concentration (Blood Count)',
    'HCM -- SISTEMATICO DE SANGRE': 'MCH -- Mean Corpuscular Hemoglobin (Blood Count)',
    'VPM -- SISTEMATICO DE SANGRE': 'MPV -- Mean Platelet Volume (Blood Count)',
    'ADW -- SISTEMATICO DE SANGRE': 'RDW -- Red Cell Distribution Width (Blood Count)',
    'EOS% -- SISTEMATICO DE SANGRE': 'EOS% -- Eosinophils % (Blood Count)',
    'EOS -- SISTEMATICO DE SANGRE': 'EOS -- Eosinophils (Blood Count)',
    'FER -- FERRITINA': 'FER -- Ferritin',
    'PO2 -- GASOMETRIA ARTERIAL': 'PO2 -- Arterial Blood Gas',
    'BE(b) -- GASOMETRIA ARTERIAL': 'BE(b) -- Arterial Blood Gas',
    'BD -- BILIRRUBINA DIRECTA': 'DBIL -- Direct Bilirubin',
    'BEecf -- GASOMETRIA ARTERIAL': 'BEecf -- Arterial Blood Gas',
    'TCO2 -- GASOMETRIA ARTERIAL': 'TCO2 -- Arterial Blood Gas',
    'HCO3 -- GASOMETRIA ARTERIAL': 'HCO3 -- Arterial Blood Gas',
    'PCO2 -- GASOMETRIA ARTERIAL': 'PCO2 -- Arterial Blood Gas',
    'PH -- GASOMETRIA ARTERIAL': 'PH -- Arterial Blood Gas',
    'SO2C -- GASOMETRIA ARTERIAL': 'SO2C -- Arterial Blood Gas',
    'AMI -- AMILASA': 'AMY -- Amylase',
    'ALB -- ALBUMINA': 'ALB -- Albumin',
    'K+P -- K+': 'K+P -- K+',
    'TROPO -- TROPONINA': 'TROP -- Troponin',
    'NA+P -- NA+': 'NA+P -- NA+',
    'PT -- PROTEINAS TOTALES': 'TP -- Total Proteins',
    'CFLAG -- ALARMA HEMOGRAMA': 'CFLAG -- Hemogram Alarm',
    'PROCAL -- PROCALCITONINA': 'PCT -- Procalcitonin',
    'PO2V -- pO2': 'PO2 -- Partial Pressure of Oxygen',
    'PHV -- pH': 'PH -- pH',
    'BE(b)V -- BE (b)': 'BE(b) -- Base Excess (Venous)',
    'HCO3V -- HCO3-': 'HCO3 -- Bicarbonate (Venous)',
    'PCO2V -- pCO2': 'PCO2 -- Partial Pressure of Carbon Dioxide (Venous)',
    'BEecfV -- BEecf': 'BEecf -- Base Excess (Extracellular Fluid) (Venous)',
    'SO2CV -- sO2c (Saturación de oxígeno)': 'SO2 -- Oxygen Saturation (Venous)',
    'TCO2V -- tCO2 (B)': 'TCO2 -- Total CO2 (Venous)',
    'CA -- CALCIO': 'CA -- Calcium',
    'K+P -- IONES EN GASES': 'K+P -- Ions in Gases',
    'NA+P -- IONES EN GASES': 'NA+P -- Ions in Gases',
    'CA -- CALCIO': 'CA -- Calcium',
    'AU -- ACIDO URICO': 'UA -- Uric Acid',
    'VSG -- VSG': 'ESR -- Erythrocyte Sedimentation Rate',
    'VIHAC -- VIH AC': 'HIV AC -- HIV Antibody',
    'OBS_NULA2 -- Observaciones Bioquímica': 'OBS_NULA2 -- Biochemistry Observations',
    'G-CORONAV (RT-PCR) -- Tipo de muestra: Exudado Faríngeo/Nasofaríngeo': 'G-CORONAV (RT-PCR) -- Sample Type: Pharyngeal/Nasopharyngeal Exudate',
    'TRIGLI -- TRIGLICERIDOS': 'TRIG -- Triglycerides',
    'CKMB -- CK-MB': 'CKMB -- Creatine Kinase-MB',
    'TSH -- TSH': 'TSH -- Thyroid-Stimulating Hormone',
    'PO2V -- GASOMETRIA VENOSA': 'PO2 -- Venous Blood Gas',
    'HCO3V -- GASOMETRIA VENOSA': 'HCO3 -- Venous Blood Gas',
    'SO2CV -- GASOMETRIA VENOSA': 'SO2 -- Venous Blood Gas',
    'BE(b)V -- GASOMETRIA VENOSA': 'BE(b) -- Venous Blood Gas',
    'TCO2V -- GASOMETRIA VENOSA': 'TCO2 -- Venous Blood Gas',
    'BEecfV -- GASOMETRIA VENOSA': 'BEecf -- Venous Blood Gas',
    'PCO2V -- GASOMETRIA VENOSA': 'PCO2 -- Venous Blood Gas',
    'NEUMOORI -- AG NEUMOCOCO EN ORINA': 'NEUMOORI -- Pneumococcal Antigen in Urine',
    'PHV -- GASOMETRIA VENOSA': 'PHV -- Venous Blood Gas',
    'LEGIORI -- AG. LEGIONELA PNEUMOPHILA EN ORINA': 'LEGIORI -- Legionella Pneumophila Antigen in Urine',
    'VHBSAG -- AG. SUPERFICIE HEPATITIS B (AgHBs)': 'HBsAg -- Hepatitis B Surface Antigen',
    'VHBSAC -- AC. SUPERFICIE ANTI HEPATITIS B': 'Anti-HBs -- Hepatitis B Surface Antibody',
    'VHCAC -- AC. ANTI HEPATITIS C': 'Anti-HCV -- Hepatitis C Antibody',
    'GLUORS -- Glucosa': 'GLUORS -- Glucose',
    'LEUORS -- Leucocitos': 'LEUORS -- Leukocytes',
    'PHORS -- pH': 'PHORS -- pH',
    'CETORS -- Cuerpos cetónicos': 'KETORS -- Ketone Bodies',
    'PTORS -- Proteinas': 'PTORS -- Proteins',
    'NITORS -- Nitritos': 'NITORS -- Nitrites',
    'UROORS -- Urobilinógeno': 'UROORS -- Urobilinogen',
    'DENORS -- Densidad': 'SGORS -- Specific Gravity/Density',
    'BILORS -- Bilirrubina': 'BILORS -- Bilirubin',
    'ERIORS -- Eritrocitos': 'ERIORS -- Erythrocytes',
    'COREM -- AC. IGM ANTI HBC': 'Anti-HBc IgM -- Hepatitis B Core Antibody IgM',
    'OBS_CB -- Observaciones Coagulación': 'OBS_CB -- Coagulation Observations',
    'COL -- COLESTEROL TOTAL': 'COL -- Total Cholesterol',
    'FE -- HIERRO': 'FE -- Iron',
    'IL6 -- INTERLEUCINA 6': 'IL6 -- Interleukin 6',
    'FOL -- ACIDO FOLICO': 'FOL -- Folic Acid',
    'VITB12 -- VITAMINA B12': 'VITB12 -- Vitamin B12',
    'FRO1 --': 'SMEAR1 -- Smear',
    'HDL -- COLESTEROL HDL': 'HDL -- High-Density Lipoprotein Cholesterol',
    'PROBNP -- PEPTIDO NATRIURETICO CEREBRAL B': 'ProBNP -- B-type Natriuretic Peptide',
    'T4L -- T4 LIBRE': 'FT4 -- Free Thyroxine',
    'OBS_NULA3 -- Observaciones Hematología': 'OBS_NULA3 -- Hematology Observations',
    'CPLT -- ALARMA HEMOGRAMA': 'CPLT -- Hemogram Alarm',
    'OBS_MICRO -- Observaciones Microbiología': 'OBS_MICRO -- Microbiology Observations',
    'CLOSD -- CLOSTRIDIUM DIFFICILE (TOXINAS A/B)': 'CLOSD -- Clostridium Difficile (Toxins A/B)',
    'OBS_GASV -- Observaciones Gasometría Venosa': 'OBS_GASV -- Venous Blood Gas Observations',
    'P_ALBP -- Albúmina %': 'P_ALBP -- Albumin %',
    'P_ALB -- Albúmina': 'P_ALB -- Albumin',
    'P_ALFA1 -- Alfa 1': 'P_ALFA1 -- Alpha 1',
    'P_ALFA2 -- Alfa 2': 'P_ALFA2 -- Alpha 2',
    'P_CAG -- Albúmina/Globulina': 'P_CAG -- Albumin/Globulin',
    'VIR_TM -- VIRUS TIPO DE MUESTRA': 'VIR_ST -- Virus Sample Type',
    'P_ALFA1P -- Alfa 1 %': 'P_ALFA1P -- Alpha 1 %',
    'P_ALFA2P -- Alfa 2 %': 'P_ALFA2P -- Alpha 2 %',
    'P_BETA -- Beta': 'P_BETA -- Beta',
    'P_BETAP -- Beta %': 'P_BETAP -- Beta %',
    'P_GAMMA -- Gamma': 'P_GAMMA -- Gamma',
    'P_GAMMAP -- Gamma %': 'P_GAMMAP -- Gamma %',
    'PHORS -- SISTEMATICO': 'PHORS -- Blood Count',
    'PTORS -- SISTEMATICO': 'PTORS -- Blood Count (Proteins)',
    'LEUORS -- SISTEMATICO': 'LEUORS -- Blood Count (Leukocytes)',
    'ERIORS -- SISTEMATICO': 'ERIORS -- Blood Count (Erythrocytes)',
    'DENORS -- SISTEMATICO': 'SGORS -- Blood Count (Specific Gravity)',
    'CETORS -- SISTEMATICO': 'KETORS -- Blood Count (Ketone Bodies)',
    'BILORS -- SISTEMATICO': 'BILORS -- Blood Count (Bilirubin)',
    'GLUORS -- SISTEMATICO': 'GLUORS -- Blood Count (Glucose)',
    'NITORS -- SISTEMATICO': 'NITORS -- Blood Count (Nitrites)',
    'UROORS -- SISTEMATICO': 'UROORS -- Blood Count (Urobilinogen)',
    'T3 -- T3 TOTAL': 'T3 -- Total T3',
    'OBS_PESP -- Observaciones Pruebas especiales': 'OBS_PESP -- Special Tests Observations',
    'EGCOVID -- ESTUDIO GENETICO COVID-19': 'EGCOVID -- COVID-19 Genetic Study',
    'OBS_GASES -- Observaciones Gasometría Arterial': 'OBS_GASES -- Arterial Blood Gas Observations',
    'T4L -- T4 LIBRE': 'T4L -- Free T4',
    'G-CORONAV (RT-PCR) -- Tipo de muestra: ASPIRADO BRONCOALVEOLAR': 'G-CORONAV (RT-PCR) -- Sample Type: Bronchoalveolar Lavage',
    'TRANS -- TRANSFERRINA': 'TRANS -- Transferrin',
    'FRO1 -- FROTIS EN SANGRE PERIFERICA': 'SMEAR1 -- Peripheral Blood Smear',
    'ISTRA -- INDICE DE SATURACION DE TRANSFERRINA': 'TSI -- Transferrin Saturation Index',
    'G-CORONAV (RT-PCR) -- Tipo de muestra: BAS': 'G-CORONAV (RT-PCR) -- Sample Type: Bronchial Aspiration',
    'T4 -- T4 TOTAL (TIROXINA)': 'T4 -- Total T4 (Thyroxine)',
    'MXD -- MXD (Mono+Eos+Baso)': 'MXD -- Mixed (Mono+Eos+Baso)',
    'MXD% -- MXD (Mono+Eos+Baso) %': 'MXD% -- Mixed (Mono+Eos+Baso) %',
    'ANA -- ANA (AC. ANTINUCLEARES)': 'ANA -- ANA (Antinuclear Antibodies)',
    'ERITROP -- ERITROBLASTOS %': 'ERITROP -- Erythroblasts %',
    'IGG -- IgG (INMUNOGLOBULINA G)': 'IGG -- IgG (Immunoglobulin G)',
    'PTG2 -- PROTEINOGRAMA': 'PTG2 -- Proteinogram',
    'RETIS -- Reticulocitos Recuento': 'RET -- Reticulocyte Count',
    'RETISP -- Reticulocitos %': 'RET -- Reticulocyte %',
    'IGM -- IgM (INMUNOGLOBULINA M)': 'IGM -- IgM (Immunoglobulin M)',
    'P_GAMMA -- PROTEINOGRAMA': 'P_GAMMA -- Proteinogram',
    'P_CAG -- PROTEINOGRAMA': 'P_CAG -- Proteinogram',
    'P_ALFA2 -- PROTEINOGRAMA': 'P_ALFA2 -- Proteinogram',
    'P_ALFA1P -- PROTEINOGRAMA': 'P_ALFA1P -- Proteinogram',
    'P_GAMMAP -- PROTEINOGRAMA': 'P_GAMMAP -- Proteinogram',
    'P_BETAP -- PROTEINOGRAMA': 'P_BETAP -- Proteinogram',
    'P_BETA -- PROTEINOGRAMA': 'P_BETA -- Proteinogram',
    'P_ALFA2P -- PROTEINOGRAMA': 'P_ALFA2P -- Proteinogram',
    'P_ALB -- PROTEINOGRAMA': 'P_ALB -- Proteinogram',
    'P_ALFA1 -- PROTEINOGRAMA': 'P_ALFA1 -- Proteinogram',
    'P_ALBP -- PROTEINOGRAMA': 'P_ALBP -- Proteinogram',
    'HAPTO -- HAPTOGLOBINA': 'HAPTO -- Haptoglobin',
    'POCK -- POC POTASIO': 'POCK -- POC Potassium',
    'IGA -- IgA (INMUNOGLOBULINA A)': 'IGA -- IgA (Immunoglobulin A)',
    'POCNA -- POC SODIO': 'POCNA -- POC Sodium',
    'C4 -- COMPLEMENTO C4': 'C4 -- Complement C4',
    'C3 -- COMPLEMENTO C3': 'C3 -- Complement C3',
    'NAO -- SODIO EN ORINA AIS.': 'NAUR -- Sodium in random Urine',
    'POCCREA -- POC CREATININA': 'POCCREA -- POC Creatinine',
    'VOLOR -- VOLUMEN ORINA 24H': 'VOLUR -- 24H Urine Volume',
    'SISHEM -- SISTEMATICO DE SANGRE': 'SISHEM -- Blood Analysis',
    'OBS_SIS -- Observaciones Orina': 'OBS_SIS -- Urine Observations',
    'POCGOT -- POC GOT (AST)': 'POCGOT -- POC GOT (AST)',
    'GALACT -- GALACTOMANANO': 'GALACT -- Galactomannan',
    'IGM -- IgM  (INMUNOGLOBULINA M)': 'IGM -- IgM (Immunoglobulin M)',
    'IGG -- IgG  (INMUNOGLOBULINA G)': 'IGG -- IgG (Immunoglobulin G)',
    'IGA -- IgA  (INMUNOGLOBULINA A)': 'IGA -- IgA (Immunoglobulin A)',
    'RESUL_IFT -- Resultado': 'RESUL_IFT -- Result',
    'CORT -- CORTISOL': 'CORT -- Cortisol',
    'HBA1C -- HEMOGLOBINA GLICOSILADA (HBA1C)': 'HBA1C -- Glycated Hemoglobin (HbA1c)',
    'SUPAR -- suPAR': 'SUPAR -- suPAR',
    'RESUL_IFT -- ESTUDIO DE INMUNOFENOTIPO': 'RESUL_IFT -- Immunophenotype Study',
    'KO24C -- POTASIO EN ORINA 24H CONC.': 'KUR24C -- Potassium in 24H Urine Conc.',
    'KO24 -- POTASIO ORINA 24H': 'KUR24 -- Potassium in 24H Urine',
    'IFSUERO -- INMUNOFIJACION EN SUERO': 'IFSUERO -- Immunofixation in Serum',
    'NAO24C -- SODIO EN ORINA 24H CONC.': 'NAUR24C -- Sodium in 24H Urine Conc.',
    'CMVDNA -- DNA CITOMEGALOVIRUS': 'CMVDNA -- Cytomegalovirus DNA',
    'CHON -- CULTIVO DE HONGOS': 'CHON -- Fungal Culture',
    'NAO24 -- SODIO ORINA 24H': 'NAU24 -- Sodium in 24H Urine',
    'TM -- Tipo de muestra': 'ST -- Sample Type',
    'FRO2 -- ': 'SMEAR2 -- Peripheral Blood Smear',
    'ANCA -- ANCA (AC. ANTINEUTROFILOS)': 'ANCA -- ANCA (Antineutrophil Cytoplasmic Antibodies)',
    'CVCMV -- Carga Viral Citomegalovirus': 'VDCMV -- Cytomegalovirus Viral Load',
    'PT24 -- PROTEINAS TOTALES ORINA 24H': 'TP24 -- Total Proteins in 24H Urine',
    'FROTISC -- FROTIS POR CRITERIO': 'SMEARC -- Smear by Criterion',
    'ACLCR -- ACLARAMIENTO CREATININA': 'CRCLE -- Creatinine Clearance',
    'CREA24 -- CREATININA 24H': 'CREA24 -- Creatinine 24H',
    'CREA24C -- CREATININA EN ORINA 24H CONC.': 'CREA24C -- Creatinine in 24H Urine Conc.',
    'PT24C -- PROTEINAS 24 HORAS CONC.': 'TP24C -- Proteins 24 Hours Conc.',
    'PCR VIRUS RESPIRATORIOS -- Tipo de muestra: EXUDADO': 'Respiratory virus PCR -- Sample Type: Exudate',
    'OSMS -- OSMOLARIDAD EN SANGRE': 'BOSM -- Blood Osmolality',
    'KO -- POTASIO EN ORINA AIS.': 'KO -- Potassium in random urine',
    'TM -- ESTUDIO DE INMUNOFENOTIPO': 'TM -- Immunophenotype Study',
    'POCGPT -- POC GPT (ALT)': 'POCGPT -- POC GPT (ALT)',
    'GRAM -- TINCION DE GRAM': 'GRAM -- Gram Stain',
    'HBA1C -- HEMOGLOBINA GLICOSILADA  (HBA1C)': 'HBA1C -- Glycated Hemoglobin (HbA1c)',
    'UOR -- UREA EN ORINA AIS.': 'UUR -- Urea in random urine',
    'POCLAC -- POC LACTATO': 'POCLAC -- POC Lactate',
    'GLUOR -- GLUCOSA EN ORINA AIS.': 'GLUUR -- Glucose in random urine',
    'CMVG -- Ac. IgG ANTI CITOMEGALOVIRUS': 'CMVG -- IgG Antibodies Against Cytomegalovirus',
    'CMVM -- Ac. IgM ANTI CITOMEGALOVIRUS': 'CMVM -- IgM Antibodies Against Cytomegalovirus',
    'GASVEN -- GASOMETRIA VENOSA': 'GASVEN -- Venous Blood Gas Analysis',
    'SED1 -- ': 'SED1 -- Sediment',
    'POCU -- POC UREA': 'POCUREA -- POC Urea',
    'COOD -- COOMBS DIRECTO': 'COOD -- Direct Coombs Test',
    'OSMOR -- OSMOLARIDAD EN ORINA': 'OSMUR -- Urine Osmolality',
    'ACDNAN -- Ac. ANTI nDNA': 'ABDNAN -- Anti-nDNA Antibodies',
    'OBS_GEN2 -- OBSERVACIONES GENETICA': 'OBS_GEN2 -- Genetic Observations',
    'ALUP -- ANTICOAGULANTE LUPICO': 'LUPA -- Lupus Anticoagulant',
    'CEA -- CEA (ANTIGENO CARCINOEMBRIONARIO)': 'CEA -- CEA (Carcinoembryonic Antigen)',
    'MICODNA -- DNA MICOBACTERIUM TUBERCULOSIS': 'MICODNA -- Mycobacterium Tuberculosis DNA',
    'B2GLICOG -- Ac. IgG ANTI BETA-2-GLICOPROTEINA': 'B2GLICOG -- IgG Antibodies Against Beta-2-Glycoprotein',
    'INMUCIR -- INMUNOCOMPLEJOS CIRCULANTES': 'INMUCIR -- Circulating Immune Complexes',
    'B2GLICOM -- Ac. IgM ANTI BETA-2-GLICOPROTEINA': 'B2GLICOM -- IgM Antibodies Against Beta-2-Glycoprotein',
    'TIPOL -- TIPO DE LIQUIDO': 'TIPOF -- Type of Fluid',
    'POCGLU -- POC GLUCOSA': 'POCGLU -- POC Glucose',
    'DIGO -- DIGOXINA': 'DIGO -- Digoxin',
    'FGLO -- FILTRADO GLOMERULAR': 'GLOF -- Glomerular Filtration',
    'FR -- FACTOR REUMATOIDE': 'RF -- Rheumatoid Factor',
    'CORONA -- PCR CORONAVIRUS 2019nCoV': 'CORONA -- PCR Coronavirus 2019nCoV',
    'RAZA -- RAZA': 'RACE -- Race',
    'CARDIM -- Ac. IgM ANTICARDIOLIPINA': 'CARDIM -- IgM Antibodies Against Cardiolipin',
    'CARDIG -- Ac. IgG ANTICARDIOLIPINA': 'CARDIG -- IgG Antibodies Against Cardiolipin',
    'CA199 -- CA 19.9': 'CA199 -- CA 19.9',
    'LIPASA -- LIPASA': 'LIPASA -- Lipase',
    'AMO -- AMONIACO': 'AMO -- Ammonia',
    'GLUL -- GLUCOSA LIQUIDO': 'GLUF -- Glucose in Fluid',
    'PTL -- PROTEINAS TOTALES EN LIQUIDO': 'TPF -- Total Proteins in Fluid',
    'PSA -- PSA TOTAL': 'PSA -- Total PSA',
    'LDHL -- LDH LIQUIDO': 'LDHF -- LDH in Fluid',
    'CULT -- CULTIVO': 'CULT -- Culture',
    'PCPJ -- PCR A PNEUMOCYSTIS JIROVECI': 'PCPJ -- PCR for Pneumocystis jiroveci',
    'SED1 -- SEDIMENTO': 'SED1 -- Sediment',
    'MICODNA -- DNA MICOBACTERIUM TUBERCULOSIS': 'MICODNA -- Mycobacterium Tuberculosis DNA',
    'CRIOGLO -- CRIOGLOBULINAS': 'CRIOGLO -- Cryoglobulins',
    'PCO2 -- POC GASOMETRIA ARTERIAL': 'PCO2 -- POC Arterial Blood Gas CO2',
    'PH -- POC GASOMETRIA ARTERIAL': 'PH -- POC Arterial Blood Gas pH',
    'CREAOR -- CREATININA EN ORINA AIS.': 'CREAUR -- Creatinine in random urine',
    'PO2 -- POC GASOMETRIA ARTERIAL': 'PO2 -- POC Arterial Blood Gas PO2',
    'HCO3 -- POC GASOMETRIA ARTERIAL': 'HCO3 -- POC Arterial Blood Gas HCO3',
    'BEecf -- POC GASOMETRIA ARTERIAL': 'BEecf -- POC Arterial Blood Gas Base Excess in Extracellular Fluid',
    'TCO2 -- POC GASOMETRIA ARTERIAL': 'TCO2 -- POC Arterial Blood Gas Total CO2',
    'SO2C -- POC GASOMETRIA ARTERIAL': 'SO2C -- POC Arterial Blood Gas O2 Saturation',
    'BE(b) -- POC GASOMETRIA ARTERIAL': 'BE(b) -- POC Arterial Blood Gas Base Excess (b)',
    'CAO24C -- CALCIO EN ORINA 24H CONC.': 'CAU24C -- Calcium in 24H Urine Conc.',
    'G-CORONAV (RT-PCR) -- Tipo de muestra: ESPUTO': 'G-CORONAV (RT-PCR) -- Sample Type: Sputum',
    'COOI -- COOMBS INDIRECTO': 'ICOO -- Indirect Coombs Test',
    'EPSG -- AC. EPSTEIN-BAAR IgG': 'EPSG -- Epstein-Barr Virus IgG Antibodies',
    'SED2 -- ': 'SED2 -- Sediment',
    'EPSM -- AC. EPSTEIN-BAAR IgM': 'EPSM -- Epstein-Barr Virus IgM Antibodies',
    'ACCOVIDROC -- AC TOTALES ANTI COVID19 ROCHE': 'ABCOVIDROC -- Total antibodies against COVID-19 by Roche',
    'CMICO -- CULTIVO DE MICOBACTERIAS': 'CMICO -- Mycobacteria culture',
    'GASART -- GASOMETRIA ARTERIAL': 'ARTGAS -- Arterial blood gas',
    'CAO24 -- CALCIO ORINA 24 H': 'CAUR24 -- Calcium in 24-hour urine',
    'TREPOT -- Ac. Totales Anti Treponema pallidum': 'TREPOT -- Total antibodies against Treponema pallidum',
    'IGMCOVIDPLX -- AC IGM ANTI COVID19 PALEX': 'IGMCOVIDPLX -- IgM antibodies against COVID-19 by PALEX',
    'IGGCOVIDPLX -- AC IGG ANTI COVID19 PALEX': 'IGGCOVIDPLX -- IgG antibodies against COVID-19 by PALEX',
    'PLAQCIT -- PLAQUETAS EN CITRATO': 'PLTCIT -- Platelets in citrate',
    'HEML -- Recuento Hematíes': 'RBC -- Red blood cell count',
    'BHCG -- BETA HCG': 'BHCG -- Beta-Human Chorionic Gonadotropin',
    'PNL -- Polimorfonucleares': 'PNL -- Polymorphonuclear leukocytes',
    'FRO -- FROTIS EN SANGRE PERIFERICA': 'SMEAR -- Peripheral blood smear',
    'MNL -- Mononucleares': 'MNL -- Mononuclear cells',
    'LEUL -- Recuento de Leucocitos': 'WBC -- White blood cell (Leukocytes) count',
    'FRO2 -- FROTIS EN SANGRE PERIFERICA': 'SMEAR2 -- Peripheral blood smear',
    'MYCOG -- ANTI MYCOPLASMA PN IgG': 'MYCOG -- Anti-Mycoplasma pneumoniae IgG antibodies',
    'GRRH -- GRUPO SANGUÍNEO Y FACTOR Rh': 'BGRH -- Blood group and Rh factor',
    'OBS_SERO -- Observaciones Serología': 'OBS_SERO -- Serology observations',
    'VHS1G -- AC. ANTI HERPES SIMPLE1 IgG': 'VHS1G -- Anti-Herpes Simplex Virus 1 IgG antibodies',
    'MYCOM -- ANTI MYCOPLASMA PN IgM': 'MYCOM -- Anti-Mycoplasma pneumoniae IgM antibodies',
    'OBS_BIOO -- Observaciones Bioquímica Orina': 'OBS_BIOO -- Biochemical urine observations',
    'FRO_COMEN -- FROTIS EN SANGRE PERIFERICA': 'SMEAR_COMEN -- Peripheral blood smear',
    'VHS2G -- ANTICUERPOS IgG ANTI HERPES TIPO 2 EN SUERO': 'VHS2G -- Anti-Herpes Simplex Virus Type 2 IgG antibodies in serum',
    'POCCA++ -- POC Ca++ Gasometría': 'POCCA++ -- POC Ca++ Gasometry',
    'POCCK -- POC CK (CREATINQUINASA)': 'POCCK -- POC CK (Creatine Kinase)',
    'VARM -- ANTI VARICELA IgM': 'VARM -- Anti-Varicella IgM antibodies',
    'G-CORONAV (RT-PCR) -- Tipo de muestra: LAVADO BRONCOALVEOLAR': 'G-CORONAV (RT-PCR) -- COVID-19 RT-PCR: Bronchoalveolar lavage',
    'ANTIFXA -- ANTI FACTOR X ACTIVADO': 'ANTIFXA -- Anti-Activated Factor X antibodies',
    'VARG -- ANTI VARICELA IgG': 'VARG -- Anti-Varicella IgG antibodies',
    'VHS1M -- AC. ANTI HERPES SIMPLE1 IgM': 'VHS1M -- Anti-Herpes Simplex Virus 1 IgM antibodies',
    'GLUG+P -- Glucosa': 'GLUG+P -- Glucose',
    'SED2 -- SEDIMENTO': 'SED2 -- Sediment',
    'LAC+P -- Lactato': 'LAC+P -- Lactate',
    'VHS2M -- ANTICUERPOS IgM ANTI HERPES TIPO 2 EN SUERO': 'VHS2M -- Anti-Herpes Simplex Virus Type 2 IgM antibodies in serum',
    'CD4P -- CD4%': 'CD4P -- CD4 percentage',
    'POCTP -- POC TIEMPO DE PROTROMBINA': 'POCTP -- POC Prothrombin Time',
    'POCAP -- ACTIVIDAD DE PROTROMBINA P': 'POCAP -- POC Prothrombin Activity',
    'CA125 -- CA 125': 'CA125 -- Cancer Antigen 125',
    'RNPIN -- Ac. ANTI RNP IN': 'RNPIN -- Anti-Ribonucleoprotein antibodies',
    'POCINR -- POC INR': 'POCINR -- POC International Normalized Ratio',
    'CD8P -- CD8%': 'CD8P -- CD8 percentage',
    'SSBIN -- Ac. ANTI SSB/LA IN': 'SSBIN -- Anti-Sjögren\'s Syndrome-related antigen A/B antibodies',
    'SSAIN -- Ac. ANTI SSA/RO IN': 'SSAIN -- Anti-Sjögren\'s Syndrome-related antigen A/B antibodies',
    'FRO3 -- FROTIS EN SANGRE PERIFERICA': 'SMEAR3 -- Peripheral blood smear',
    'SMIN -- AC. ANTI SM IN': 'SMIN -- Anti-Smith antibodies',
    'CD4-CD8 -- LINFOCITOS CD4-CD8 (OKT4-OKT8)': 'CD4-CD8 -- CD4-CD8 lymphocytes',
    'B2M -- BETA2 MICROGLOBULINA                                                            ': 'B2M -- Beta-2 Microglobulin',
    'VHS2DNA -- DNA VIRUS HERPES SIMPLE 2': 'VHS2DNA -- Herpes Simplex Virus Type 2 DNA',
    'VHS1DNA -- DNA VIRUS HERPES SIMPLE 1': 'VHS1DNA -- Herpes Simplex Virus Type 1 DNA',
    'COXG -- AC. ANTI COXIELLA IgG': 'COXG -- Anti-Coxiella IgG antibodies',
    'COXM -- AC. ANTI COXIELLA IgM': 'COXM -- Anti-Coxiella IgM antibodies',
    'GLULCR -- GLUCOSA LCR': 'GLUCSF -- Glucose in CSF',
    'PNL -- RECUENTO CELULAR LIQUIDO': 'PNLF -- Total cell count (Polymorphonuclear leukocytes) in fluid',
    'POCBT -- POC BILIRRUBINA TOTAL': 'POCTB -- POC Total Bilirubin',
    'PTLCR -- PROTEINAS LCR': 'TPCSF -- Cerebrospinal fluid proteins',
    'LEUL -- RECUENTO CELULAR LIQUIDO': 'WBCF -- Total cell count (Leukocytes) in fluid',
    'ACTH -- ACTH (HORMONA ADRENOCORTICOTROPA)': 'ACTH -- Adrenocorticotropic Hormone',
    'SISOR -- SISTEMATICO': 'SISOR -- Systematic',
    'MNL -- RECUENTO CELULAR LIQUIDO': 'MNLF -- Total mononuclear cell count in fluid',
    'CA153 -- CA 15.3': 'CA153 -- Cancer Antigen 15-3',
    'IGE -- IgE (INMUNOGLOBULINA E)': 'IGE -- Immunoglobulin E',
    'AFP -- ALFA FETOPROTEINA': 'AFP -- Alpha-fetoprotein',
    'MICALB -- MICROALBUMINURIA ORINA AIS.': 'MICALB -- Microalbuminuria in random urine',
    'CH50 -- COMPLEMENTO CH50': 'CH50 -- CH50 Complement',
    'HEML -- RECUENTO CELULAR LIQUIDO': 'RBCF -- Total red blood cell count in fluid',
    'FRO_COMEN -- FROTIS EN SANGRE PERIFERICA': 'SMEAR_COMEN -- Peripheral blood smear',
    'CARDIM -- Ac. IgM ANTICARDIOLIPINA                                                        ': 'CARDIM -- Anti-Cardiolipin IgM antibodies',
    'CARDIG -- Ac. IgG ANTICARDIOLIPINA                                                        ': 'CARDIG -- Anti-Cardiolipin IgG antibodies',
    'LDL -- COLESTEROL LDL': 'LDL -- LDL Cholesterol',
    'ALB-CREA -- COCIENTE ALBUMINA-CREATININA ORINA': 'ALB-CREA -- Albumin-Creatinine Ratio in urine',
    'CHNEGIFI -- AC. ANTICHLAMYDIA PNEUMONIAE IgG IFI': 'CHNEGIFI -- Anti-Chlamydia pneumoniae IgG antibodies IFI',
    'G-CORONAV (RT-PCR) -- Tipo de muestra: BAL': 'G-CORONAV (RT-PCR) -- COVID-19 RT-PCR: Bronchoalveolar lavage',
    'IGGCOVID -- AC IGG ANTI COVID19': 'IGGCOVID -- IgG antibodies against COVID-19',
    'CHNEMIFI -- AC. ANTICHLAMYDIA PNEUMONIAE IgM IFI': 'CHNEMIFI -- Anti-Chlamydia pneumoniae IgM antibodies IFI',
    'LAMBDA -- CADENAS LAMBDA SUERO': 'LAMBDA -- Lambda chains in serum',
    'KAPPA -- CADENAS KAPPA SUERO': 'KAPPA -- Kappa chains in serum',
    'KA-LASUE -- COCIENTE KAPPA-LAMBDA SUERO': 'KA-LASUE -- Kappa-Lambda ratio in serum',
    'ASPLCRPRE -- ASPECTO LCR PRECENTRIFUGACION': 'ASPCSFPRE -- Appearance of cerebrospinal fluid pre-centrifugation',
    'PHL -- pH EN LIQUIDO': 'PHF -- pH in fluid',
    'SANHE -- SANGRE OCULTA EN HECES': 'OBLOS -- Occult blood in stool',
    'BORM -- ANTICUERPOS ANTI BORRELIA IgM': 'BORM -- Anti-Borrelia IgM antibodies',
    'TOXOG -- Ac. IgG ANTI TOXOPLASMA': 'TOXOG -- IgG antibodies against Toxoplasma',
    'BORG -- ANTICUERPOS ANTI BORRELIA IgG': 'BORG -- Anti-Borrelia IgG antibodies',
    'IGMCOVID -- AC IGM ANTI COVID19': 'IGMCOVID -- IgM antibodies against COVID-19',
    'AMIL -- AMILASA LIQUIDO': 'AMIF -- Amylase in fluid',
    'EPO -- ERITROPOYETINA': 'EPO -- Erythropoietin',
    'PREALB -- PREALBUMINA': 'PREALB -- Prealbumin',
    'ASPLCRPOST -- ASPECTO LCR POSTCENTRIFUGACION': 'ASPCSFPOST -- Appearance of cerebrospinal fluid post-centrifugation',
    'TOXOM -- Ac. IgM ANTI TOXOPLASMA': 'TOXOM -- IgM antibodies against Toxoplasma',
    'POCDD -- POC DIMERO D': 'POCDD -- POC D-Dimer',
    'K_KALALIB -- CADENAS LIGERAS LIBRES K-L SUERO': 'K_KALALIB -- Free Kappa-Lambda light chains in serum',
    'LEGIOM -- AC. ANTI LEGIONELA IgM (*)': 'LEGIOM -- Anti-Legionella IgM antibodies (*)',
    'K_LAMBLIB -- CADENAS LIGERAS LIBRES K-L SUERO': 'K_LAMBLIB -- Free Kappa-Lambda light chains in serum',
    'GLUG -- GLUCOSA (GASOMETRIA)': 'GLUG -- Glucose (Gasometry)',
    'PNLCR -- Polimorfonucleares': 'PNLCSF -- Polymorphonuclear leukocytes in CSF',
    'PCR VIRUS RESPIRATORIOS -- Tipo de muestra: BAS': 'Respiratory virus PCR: Pulmonary aspiration',
    'PCR VIRUS RESPIRATORIOS -- Tipo de muestra: ASPIRADO BRONCOALVEOLAR': 'Respiratory virus PCR: Pulmonary aspiration',
    'AGVIAB -- AG VIRUS INFLUENZA TIPO A y B': 'ABVIAB -- Influenza Virus Type A and B Antigen',
    'IGE -- IgE  (INMUNOGLOBULINA E)': 'IGE -- Immunoglobulin E',
    'LEULCR -- Recuento Leucocitos': 'WBC -- White blood cell (Leukocytes) count',
    'LEGIOG -- AC. ANTI LEGIONELA IgG (*)': 'LEGIOG -- Anti-Legionella IgG antibodies (*)',
    'VITD -- VITAMINA D (25 HIDROXICOLECALCIFEROL)': 'VITD -- Vitamin D (25-Hydroxycholecalciferol)',
    'K_KAPPLIB -- CADENAS LIGERAS LIBRES K-L SUERO': 'K_KAPPLIB -- Free Kappa-Lambda light chains in serum',
    'BTL -- BILIRRUBINA TOTAL LIQUIDO': 'TBF -- Total Bilirubin in fluid',
    'PAULB -- PAUL BUNNELL (MONONUCLEOSIS)': 'PAULB -- Paul Bunnell (Mononucleosis)',
    'HEMLCR -- Recuento Hematíes': 'RBC -- Red blood cell count',
    'BRUROSA -- BRUCELLA (ROSA DE BENGALA)': 'BRUROSA -- Brucella (Rose Bengal)',
    'K_KALALIB -- Cociente Kappa/Lambda': 'K_KALALIB -- Kappa/Lambda ratio',
    'ASPL -- ASPECTO LIQUIDO': 'ASPL -- Liquid appearance',
    'PTGOR -- PROTEINOGRAMA ORINA': 'PTGUR -- Urine Proteinogram',
    'K_KAPPLIB -- Cadenas Ligeras Libres Kappa': 'K_KAPPLIB -- Free Kappa Light Chains',
    'ANTIPLAQIN -- ANTICUERPOS ANTIPLAQUETARIOS INDIRECTOS': 'ANTIPLATIN -- Indirect Antiplatelet Antibodies',
    'AMIKAV -- AMIKACINA VALLE': 'AMIKAV -- Amikacin peak',
    'TRIPTA -- TRIPTASA': 'TRYPT -- Tryptase',
    'MNLCR -- Mononucleares': 'MNL -- Mononuclear cells',
    'ANTIPLAQD -- ANTICUERPOS ANTIPLAQUETARIOS DIRECTOS': 'ANTIPLTD -- Direct Antiplatelet Antibodies',
    'SED3 -- SEDIMENTO': 'SED3 -- Sediment',
    'PCR VIRUS RESPIRATORIOS -- Tipo de muestra: LAVADO BRONCOALVEOLAR': 'Respiratory virus PCR: Bronchoalveolar lavage',
    'CD8 -- CD8': 'CD8 -- CD8',
    'PARAS -- ESTUDIO PARASITOLÓGICO': 'PARAS -- Parasitological study',
    'MENGLO -- Ac. ANTI MEMBRANA BASAL GLOMERULAR': 'MENGLO -- Anti-Glomerular Basement Membrane antibodies',
    'CD4 -- CD4': 'CD4 -- CD4',
    'K_LAMBLIB -- Cadenas Ligeras Libres Lambda': 'K_LAMBLIB -- Free Lambda Light Chains',
    'VALP -- ACIDO VALPROICO (DEPAKINE)': 'VALP -- Valproic Acid (Depakine)',
    'TpMues -- Tipo de muestra': 'ST -- Sample Type',
    'PROTRET -- PROTEINA FIJADORA RETINOL': 'RETBIN -- Retinol Binding Protein',
    'LI -- LITIO': 'LI -- Lithium',
    'K+ -- K+ Gasometria': 'K+ -- Potassium (K+) Gasometry',
    'NA+ -- NA+ Gasometria': 'NA+ -- Sodium (Na+) Gasometry',
    'PTOR -- PROTEINAS TOTALES EN ORINA AIS.': 'TPUR -- Total Proteins in Random Urine',
    'Tecnica -- Técnica': 'Technique -- Technique',
    'SMA -- AC. ANTI MUSCULO LISO (SMA)': 'SMA -- Anti-Smooth Muscle Antibodies (SMA)',
    'AMA -- AMA (AC. ANTIMITOCONDRIALES)': 'AMA -- Anti-Mitochondrial Antibodies (AMA)',
    'PTH -- PARATHORMONA INTACTA': 'PTH -- Intact Parathyroid Hormone (PTH)',
    'CHNEGIFI -- AC. ANTICHLAMYDIA PNEUMONIAE IgG  IFI': 'CHNEGIFI -- Anti-Chlamydia pneumoniae IgG antibodies IFI',
    'IGD -- IgD (INMUNOGLOBULINA D)': 'IGD -- Immunoglobulin D',
    'Resultado -- Resultado': 'Result -- Result',
    'EPSDNA -- DNA VIRUS EPSTEIN BARR (PCR)': 'EPSDNA -- Epstein-Barr Virus DNA (PCR)',
    'ADAL -- ADENOSIN DESAMINASA (ADA) EN LCR': 'ADAL -- Adenosine Deaminase (ADA) in CSF',
    'POCTROPO -- POC TROPONINA': 'POCTROPO -- POC Troponin',
    'CHNEMIFI -- AC. ANTICHLAMYDIA PNEUMONIAE IgM IFI': 'CHNEMIFI -- Anti-Chlamydia pneumoniae IgM antibodies IFI',
    'EMB -- DIAGNOSTICO DE EMBARAZO': 'PREGNAN -- Pregnancy Diagnosis',
    'POCAMI -- POC AMILASA': 'POCAMY -- POC Amylase',
    'ERITRO -- ERITROBLASTOS': 'ERITRO -- Erythroblasts',
    'G6PDH -- GLUCOSA 6 P DESHIDROGENASA (G6PDH)': 'G6PDH -- Glucose-6-Phosphate Dehydrogenase (G6PDH)',
    'FRO3 -- FROTIS EN SANGRE PERIFERICA': 'SMEAR3 -- Peripheral Blood Smear',
    'LEULCR -- RECUENTO CELULAR LCR': 'WBCCSF -- White Blood Cell Count (Leukocytes) in CSF',
    'LAMBDAOR -- CADENAS LIGERAS LAMBDA ORINA': 'LAMBDAUR -- Lambda Light Chains in Urine',
    'VANCOV -- VANCOMICINA VALLE': 'VANCOV -- Vancomycin Trough',
    'VHCBLOT -- INMUNOBLOT VIRUS HEPATITIS C': 'VHCBLOT -- Hepatitis C Virus Immunoblot',
    'KA-LAOR -- COCIENTE KAPPA-LAMBDA ORINA': 'KA-LAUR -- Kappa-Lambda Ratio in Urine',
    'FXI -- FACTOR XI': 'FXI -- Factor XI',
    'FX -- FACTOR X': 'FX -- Factor X',
    'FVIII -- FACTOR VIII': 'FVIII -- Factor VIII',
    'FV -- FACTOR V': 'FV -- Factor V',
    'FII -- FACTOR II': 'FII -- Factor II',
    'KAPPAOR -- CADENAS LIGERAS KAPPA ORINA': 'KAPPAOR -- Kappa Light Chains in Urine',
    'FIX -- FACTOR IX': 'FIX -- Factor IX',
    'HEMLCR -- RECUENTO CELULAR LCR': 'RBCCSF -- Red blood cell count in CSF',
    'POCCKMB -- POC CK-MB': 'POCCKMB -- POC CK-MB',
    'OBS_HECES -- Observaciones Heces': 'OBS_STOOL -- Stool Observations',
    'ACPF4 -- Ac. ANTI PF4-HEPARINA': 'ACPF4 -- Anti-PF4-Heparin Antibodies',
    'CALPRO -- CALPROTECTINA HECES': 'CALPRO -- Fecal Calprotectin',
    'PCR VIRUS RESPIRATORIOS -- Tipo de muestra: ESPUTO': 'Respiratory Virus PCR: Sputum',
    'LKM -- AC. LKM': 'LKM -- Anti-Liver Kidney Microsomal Antibodies',
    'Basemol -- Base Molecular': 'Molbase -- Molecular Basis',
    'Basemol -- DNA VIRUS VARICELA-ZOSTER': 'Molbase -- Varicella-Zoster Virus DNA',
    'Resultado -- DNA VIRUS VARICELA-ZOSTER': 'Result -- Varicella-Zoster Virus DNA',
    'Tecnica -- DNA VIRUS VARICELA-ZOSTER': 'Technique -- Varicella-Zoster Virus DNA',
    'TpMues -- DNA VIRUS VARICELA-ZOSTER': 'ST -- Varicella-Zoster Virus DNA',
    'B2M -- BETA2 MICROGLOBULINA': 'B2M -- Beta-2 Microglobulin',
    'ZIELH -- TINCION DE ZIEHL-NEELSEN': 'ZIELH -- Ziehl-Neelsen Stain',
    'AMIKAP -- AMIKACINA PICO': 'AMIKAP -- Amikacin Peak',
    'IGG3 -- IGG3 (INMUNOGLOBULINA G': 'IGG3 -- Immunoglobulin G3',
    'PCP -- Fenciclidina': 'PCP -- Phencyclidine',
    'OPI -- Opiáceos': 'OPI -- Opiates',
    'OBS_DA -- Observaciones Orina': 'OBS_UR -- Urine Observations',
    'IGG1 -- IGG1 (INMUNOGLOBULINA G, SUBCLASE 1)': 'IGG1 -- Immunoglobulin G1',
    'G-CORONAV (RT-PCR) -- Tipo de muestra: ASPIRADO NASAL': 'G-CORONAV (RT-PCR) -- COVID-19 RT-PCR: Nasal Aspirate',
    'MTD -- Metadona': 'MTD -- Methadone',
    'MORF -- Morfina': 'MORF -- Morphine',
    'METANF -- Metanfetamina': 'METANF -- Methamphetamine',
    'PSAL -- PSA LIBRE': 'PSAF -- Free PSA',
    'MDMA -- Metilenedioximetanfetamina': 'MDMA -- Methylenedioxymethamphetamine',
    'BENZOOR -- Benzodiacepinas': 'BENZOOR -- Benzodiazepines',
    'ANF -- Anfetaminas': 'ANF -- Amphetamines',
    'BAROR -- Barbitúricos': 'BARUR -- Barbiturates',
    'G-CORONAV (RT-PCR) -- Tipo de muestra: MUESTRAS RESPIRATORIAS': 'G-CORONAV (RT-PCR) -- COVID-19 RT-PCR: Respiratory Samples',
    'PSAL-T -- PSALIBRE-PSATOTAL': 'PSAF -- Free PSA-Total PSA',
    'IGG3 -- IGG3 (INMUNOGLOBULINA G, SUBCLASE 3)': 'IGG3 -- Immunoglobulin G3 Subclass',
    'CRISTL -- CRISTALES EN LIQUIDO': 'CRISTF -- Crystals in Fluid',
    'FENO -- FENOBARBITAL': 'PHENO -- Phenobarbital',
    'CYFRA211 -- CYFRA 21.1': 'CYFRA211 -- CYFRA 21.1',
    'TRIC -- Antidepresivos tricíclicos': 'TRIC -- Tricyclic Antidepressants',
    'OBS_LIQ -- Observaciones Líquidos Biológicos': 'OBS_FLUID -- Biological Fluids Observations',
    'OBS_ESTCOA -- Observaciones Est. Coagulopatías': 'OBS_COA -- Coagulopathy Study Observations',
    'SED -- SEDIMENTO': 'SED -- Sediment',
    'VDRLLCR -- VDRL LCR': 'VDRLCSF -- VDRL CSF',
    'LDHLCR -- LDH LCR': 'LDHCSF -- LDH CSF',
    'VITAB1 -- VITAMINA B1 (TPP) SANGRE TOTAL': 'VITAB1 -- Vitamin B1 (TPP) Whole Blood',
    'ACTIRO -- Ac. ANTI TIROGLOBULINA': 'ABTIRO -- Anti-Thyroglobulin Antibodies',
    'MPO -- MIELOPEROXIDASA': 'MPO -- Myeloperoxidase',
    'TSI -- TSI (Ac. RECEPTORES TSH)': 'TSI -- TSI (TSH Receptor Antibodies)',
    'ADALP -- ADENOSIN DESAMINASA (ADA) EN LIQ. PLEURAL': 'ADAPF -- Adenosine Deaminase (ADA) in Pleural Fluid',
    'IFORINA -- INMUNOFIJACION ORINA': 'IFURINE -- Urine Immunofixation',
    'ECA -- ECA': 'ACE -- ACE (Angiotensin-Converting Enzyme)',
    'RICKM -- ANTI RICKETTSIA CONORII IgM (*)': 'RICKM -- Anti-Rickettsia conorii IgM (*)',
    'RICKG -- ANTI RICKETTSIA CONORII IgG (*)': 'RICKG -- Anti-Rickettsia conorii IgG (*)',
    'CHLPSM -- AC. ANTI CHLAMIDIA PSITIACI IgM': 'CHLPSM -- Anti-Chlamydia psittaci IgM Antibodies',
    'CHLPSG -- AC. ANTI CHLAMIDIA PSITIACI IgG': 'CHLPSG -- Anti-Chlamydia psittaci IgG Antibodies',
    'LEISIGM -- AC IGM ANTI LEISHMANIA DONOVANI': 'LEISIGM -- IgM Antibodies against Leishmania donovani',
    'LEISIGG -- AC IGG ANTI LEISHMANIA DONOVANI': 'LEISIGG -- IgG Antibodies against Leishmania donovani',
    'OBS_HOR -- Observaciones Hormonas': 'OBS_HOR -- Hormone Observations',
    'G-CORONAV (RT-PCR) -- Tipo de muestra: ASPIRADO BRONQUIAL': 'G-CORONAV (RT-PCR) -- Sample Type: Bronchial Aspirate',
    'VRS -- DET. Rápida DE AG DE VRS EN M. RESPIRATORIAS': 'VRS -- Rapid Detection of VRS Antigens in Respiratory Samples',
    'COODM -- COOMBS DIRECTO MONOESPECÍFICO': 'COODM -- Direct Monospecific Coombs Test',
    'MIO -- MIOGLOBINA': 'MIO -- Myoglobin',
    'BE(B)U -- BE(b) ARTERIA UMBILICAL': 'BE(B)U -- Base Excess (b) Umbilical Artery',
    'PHAU -- PH ARTERIA UMBILICAL': 'PHUA -- pH Umbilical Artery',
    'MNLCR -- RECUENTO CELULAR LCR': 'MNL -- Mononuclear cells count',
    'PNLCR -- RECUENTO CELULAR LCR': 'PNL -- Polymorphonuclear leukocytes cell count',
    'G-CORONAV (RT-PCR) -- Tipo de muestra: LCR': 'G-CORONAV (RT-PCR) -- Sample Type: CSF',
    'THC -- Tetrahidrocannabinol': 'THC -- Tetrahydrocannabinol',
    'COCA -- Cocaína': 'COCA -- Cocaine',
    'FVWCOR -- FACTOR VON WILLEBRAND COFACTOR DE LA RISTOCETINA': 'VWFCOR -- Von Willebrand Factor Ristocetin Cofactor',
    'T3L -- T3 LIBRE': 'T3F -- Free T3',
    'TMEZ -- TEST DE MEZCLAS': 'MT -- Mixing Test',
    'FXII -- FACTOR XII': 'FXII -- Factor XII',
    'MGRAMA -- MIELOGRAMA': 'MGRAMA -- Myelogram',
    'PRUEBA -- PRUEBA': 'TEST -- Test',
    'FVWAG -- FACTOR VON WILLEBRAND ANTIGÉNICO': 'VWFAG -- Von Willebrand Factor Antigen',
    'VANCOP -- VANCOMICINA PICO': 'VANCOP -- Vancomycin Peak',
    'Resultado -- DETECCION POR PCR DE VIRUS GRIPE A/GRIPE B': 'Result -- Detection of Influenza A/B Virus by PCR',
    'CROMOG -- CROMOGRANINA -A-': 'CROMOG -- Chromogranin A',
    'Tecnica -- DETECCION POR PCR DE VIRUS GRIPE A/GRIPE B': 'Technique -- Detection of Influenza A/B Virus by PCR',
    'ANTI_CCP -- Ac. ANTI CCP': 'ANTI_CCP -- Anti-CCP Antibodies',
    'TpMues -- DETECCION POR PCR DE VIRUS GRIPE A/GRIPE B': 'ST -- Detection of Influenza A/B Virus by PCR',
    'ANISA -- RAST ANISAKIS': 'ANISA -- Anisakis RAST',
    'OBS_TROM -- Observaciones Trombofilia': 'OBS_TROM -- Thrombophilia Observations',
    'G-CORONAV (RT-PCR) -- Tipo de muestra: LÖQUIDO PERICÚRDICO (Muestra no respiratoria)': 'G-CORONAV (RT-PCR) -- Sample Type: Pericardial Fluid (Non-respiratory Sample)',
    'NSE -- ENOLASA ESPEC. NEURONAL': 'NSE -- Neuron-specific Enolase',
    'MALB24C -- MICROALBUMINA 24H CONCENTRACION': 'MALB24C -- 24-hour Microalbumin Concentration',
    'OBS_BIOMOL -- OBSERVACIONES GENETICA MOLECULAR': 'OBS_BIOMOL -- Molecular Genetics Observations',
    'QFERON -- QUANTIFERON-TB': 'QFERON -- QuantiFERON-TB',
    'ALDOS -- ALDOSTERONA': 'ALDOS -- Aldosterone',
    'ALBL -- ALBUMINA EN LIQUIDO': 'ALBF -- Albumin in Fluid',
    'MALB24 -- MICROALBUMINA 24H': 'MALB24 -- 24-hour Microalbumin',
    'PCR VIRUS RESPIRATORIOS -- Tipo de muestra: LAVADO NASOFARÍNGEO': 'Respiratory virus PCR -- Sample Type: Nasopharyngeal Wash',
    'Formula -- CARIOTIPO EN MEDULA OSEA': 'KARYO -- Bone Marrow Karyotype',
    'CONFAG -- CONFIRMATORIO HBsAG': 'CONFAG -- Confirmatory HBsAg',
    'ACETRECEP -- Ac. ANTI RECEPTOR ACETILCOLINA': 'ACETRECEP -- Anti-Acetylcholine Receptor Antibodies',
    'G-CORONAVEXT -- DETECCION VIRUS CORONAVIRUS 2019nCoV EXT': 'G-CORONAVEXT -- Detection of 2019nCoV Coronavirus',
    'G-FISH -- FISH': 'G-FISH -- FISH',
    'HTCG -- Htc Gasometria': 'HTCG -- Hematocrit Gasometry',
    'MXD -- POC SISTEMATICO DE SANGRE': 'MXD -- POC Blood Count (Mono+Eos+Baso)',
    'Metafases -- CARIOTIPO EN MEDULA OSEA': 'KARYO -- Bone Marrow Karyotype',
    'ADW -- POC SISTEMATICO DE SANGRE': 'RDW -- POC Blood Count (Red Cell Distribution Width)',
    'Formula -- Fórmula cromosómica': 'KARYO -- Chromosomal Karyotype',
    'Metafases -- Metafases analizadas': 'KARYO -- Analyzed Metaphases',
    'CRBC -- ALARMA HEMOGRAMA': 'CRBC -- Hemogram Alarm',
    'VHAM -- Ac. IgM ANTI HEPATITIS A': 'VHAM -- Anti-Hepatitis A Virus IgM',
    'MXD% -- POC SISTEMATICO DE SANGRE': 'MXD% -- POC Blood Count (Mono+Eos+Baso)',
    'CD4 -- CD4': 'CD4 -- CD4',
    'CANAE -- CULTIVO DE ANAEROBIOS': 'CANAE -- Anaerobic Culture',
    'POCAPTT -- POC TIEMPO DE CEFALINA (APTT)': 'POCAPTT -- POC Activated Partial Thromboplastin Time (APTT)',
    'HGB -- POC SISTEMATICO DE SANGRE': 'HGB -- POC Blood Count (Hemoglobin)',
    'BBURGDG-LCR -- BORRELIA BURGDORFERI ANTICUERPOS IgG LÍQUIDO CEFALORRAQUÍDEO': 'BBURGDG-CSF -- Borrelia burgdorferi IgG Antibodies in CSF',
    'POCCL -- POC CLORO': 'POCCL -- POC Chloride',
    'LEUC -- POC SISTEMATICO DE SANGRE': 'LEUC -- POC Blood Count (Leukocytes)',
    'LIN -- POC SISTEMATICO DE SANGRE': 'LIN -- POC Blood Count (Lymphocytes)',
    'LIN% -- POC SISTEMATICO DE SANGRE': 'LIN% -- POC Blood Count (Lymphocytes)',
    'LAC+P -- METABOLITOS EN GASES': 'LAC+P -- Metabolites in Gases',
    'GLUG+P -- METABOLITOS EN GASES': 'GLUG+P -- Metabolites in Gases',
    'OSMOSM -- OSMOLALIDAD EN SUERO (MEDIDA)': 'OSMOSM -- Serum Osmolality (Measured)',
    'OSMOORM -- OSMOLALIDAD EN ORINA (MEDIDA)': 'OSMOURM -- Urine Osmolality (Measured)',
    'HEM -- POC SISTEMATICO DE SANGRE': 'HEM -- POC Blood Analysis (Red Blood Cells)',
    'PENIV -- RAST PENICILINA V': 'PENIV -- Penicillin V RAST',
    'HCTO -- POC SISTEMATICO DE SANGRE': 'HCTO -- POC Blood Analysis (Hematocrit)',
    'PENIG -- RAST PENICILINA G': 'PENIG -- Penicillin G RAST',
    'HCM -- POC SISTEMATICO DE SANGRE': 'HCM -- POC Blood Analysis (Mean Corpuscular Hemoglobin)',
    'G-GRIPE -- DETECCION POR PCR DE VIRUS GRIPE A/GRIPE B': 'G-INFLUENZA -- Detection of Influenza A/B Virus by PCR',
    'CHCM -- POC SISTEMATICO DE SANGRE': 'HCMC -- POC Blood Analysis (Mean Corpuscular Hemoglobin Concentration)',
    'CEFACLOR -- RAST A CEFACLOR': 'CEFACLOR -- RAST for Cefaclor',
    'AMPI -- RAST A AMPICILINA': 'AMPI -- RAST for Ampicillin',
    'AMOXI -- RAST AMOXICILINA': 'AMOXI -- RAST for Amoxicillin',
    'CLOR -- CLORO EN ORINA': 'CLOR -- Chlorine in Urine',
    'BBURGDM-LCR -- BORRELIA BURGDORFERI ANTICUERPOS IgM LÖQUIDO CEFALORRAQUÖDEO': 'BBURGDM-CSF -- Borrelia burgdorferi IgM Antibodies in CSF',
    'ZIELHM -- TINCION DE ZIEHL-NEELSEN MODIFICADA': 'ZIELHM -- Modified Ziehl-Neelsen Staining',
    'PCF -- PROTEÖNA C FUNCIONAL COAGULACIÓN': 'FPC -- Functional Protein C Coagulation',
    'Resultado -- CARIOTIPO EN MEDULA OSEA': 'Result -- Karyotype in Bone Marrow',
    'PCR VIRUS RESPIRATORIOS -- Tipo de muestra: LAVADO NASOFARINGEO': 'Respiratory virus PCR -- Sample Type: Nasopharyngeal aspirate',
    'IGD -- IgD  (INMUNOGLOBULINA D)': 'IGD -- IgD (Immunoglobulin D)',
    'DNA VIRUS HERPES 6 -- Tipo de muestra: LCR': 'DNA VIRUS HERPES 6 -- DNA VIRUS HERPES 6 in CSF',
    'JO1IN -- AC. ANTI JO-1 IN': 'JO1IN -- Anti-JO-1 Antibodies',
    'SED4 -- SEDIMENTO': 'SED4 -- Sediment',
    'Basemol -- PCR RAPIDA VIRUS CORONAVIRUS 2019nCoV': 'Molbase -- Rapid PCR for 2019nCoV Coronavirus',
    'VCM -- POC SISTEMATICO DE SANGRE': 'MCV -- POC Blood Analysis (Mean Corpuscular Volume)',
    'ADA -- ADENOSIN DESAMINASA (ADA)': 'ADA -- Adenosine Deaminase (ADA)',
    'G-CORONAV (RT-PCR) -- Tipo de muestra: MUESTRA RESPIRATORIA': 'G-CORONAV (RT-PCR) -- Sample Type: Respiratory Sample',
    'VPM -- POC SISTEMATICO DE SANGRE': 'MPV -- POC Blood Analysis (Mean Platelet Volume)',
    'Tecnica -- CARIOTIPO EN MEDULA OSEA': 'KARYO -- Karyotype in Bone Marrow',
    'CORT60 -- CORTISOL 60': 'CORT60 -- Cortisol 60',
    'ADH -- ADH (HORMONA ANTIDIURETICA': 'ADH -- ADH (Antidiuretic Hormone)',
    'ADH -- ADH (HORMONA ANTIDIURETICA, VASOPRESINA)': 'ADH -- ADH (Antidiuretic Hormone, Vasopressin)',
    'AG COVID -- ANTIGENO COVID19': 'AG COVID -- COVID19 Antigen',
    'CORET -- ANTICUERPOS TOTALES ANTI CORE VHB': 'CORET -- Total Antibodies against Hepatitis B Core',
    'FVII -- FACTOR VII': 'FVII -- Factor VII',
    'IFORINA -- INMUNOFIJACION ORINA': 'IFURINE -- Immunofixation in Urine',
    'TRANSGL -- Ac. IgA ANTI TRANSGLUTAMINASA': 'TRANSGL -- IgA Antibodies against Transglutaminase',
    'TRANSG -- TRANSGLUTAMINASA IGG': 'TRANSG -- IgG Transglutaminase',
    'RESOLIL -- RECEPTOR SOLUBLE INTERLEUCINA 2': 'RESOLIL -- Soluble Interleukin 2 Receptor',
    'C_IGGACCOVID -- Ac IgG Anti Virus COVID-19': 'C_IGGACCOVID -- IgG Antibodies against COVID-19 Virus',
    'C_IGMACCOVID -- Ac IgM Anti Virus COVID-19': 'C_IGMACCOVID -- IgM Antibodies against COVID-19 Virus',
    'Observ -- Observaciones:': 'OBS -- Observations:',
    'Tecnica -- Tcnica de bandas': 'Technique -- Banding Technique',
    'TpMues -- CARIOTIPO EN MEDULA OSEA': 'KARYO -- Karyotype in Bone Marrow',
    'EVERO -- EVEROLIMUS': 'EVERO -- Everolimus',
    'NEU -- POC SISTEMATICO DE SANGRE': 'NEU -- POC Blood Analysis (Neutrophils)',
    'PSF -- PROTEÖNA S FUNCIONAL COAGULACIÓN': 'PSF -- Functional Protein S Coagulation',
    'IFDPJ -- INMUNOFLUORESCENCIA DIRECTA PARA PNEUMOCYSTIS JIROVECI': 'IFDPJ -- Direct Immunofluorescence for Pneumocystis jiroveci',
    'OBS_FARDRO -- Observaciones F rmacos': 'OBS_DRUGS -- Drug Observations',
    'NEU% -- POC SISTEMATICO DE SANGRE': 'NEU% -- POC Blood Analysis (Neutrophils)',
    'CRYPTO -- AG. CRYPTOCOCCUS NEOFORMANS SUERO': 'CRYPTO -- Cryptococcus neoformans Antigen in Serum',
    'LISOZI -- LISOZIMA': 'LISOZI -- Lysozyme',
    'TpMues -- PCR RAPIDA VIRUS CORONAVIRUS 2019nCoV': 'ST -- Rapid PCR for 2019nCoV Coronavirus',
    'Observ -- PCR RAPIDA VIRUS CORONAVIRUS 2019nCoV': 'OBS -- PCR for 2019nCoV Coronavirus',
    'Resultado -- PCR RAPIDA VIRUS CORONAVIRUS 2019nCoV': 'Result -- PCR for 2019nCoV Coronavirus',
    'Tecnica -- PCR RAPIDA VIRUS CORONAVIRUS 2019nCoV': 'Technique -- PCR for 2019nCoV Coronavirus',
    'TRIGLIL -- TRIGLICERIDOS LIQUIDO': 'TRIGLIL -- Liquid Triglycerides',
    'COLL -- COLESTEROL LIQUIDO': 'COL -- Liquid Cholesterol',
    'Observ -- AC TOTALES ANTI COVID19': 'OBS -- Total Antibodies against COVID19',
    'C_IGMACCOVID -- AC TOTALES ANTI COVID19': 'C_IGMACCOVID -- Total IgM Antibodies against COVID19',
    'C_IGGACCOVID -- AC TOTALES ANTI COVID19': 'C_IGGACCOVID -- Total IgG Antibodies against COVID19',
    'PLAQ -- POC SISTEMATICO DE SANGRE': 'PLT -- POC Blood Analysis (Platelet)',        
    'BAS% -- SISTEMATICO DE SANGRE': 'BASO% -- Basophils % (Blood Count)',  
    'BAS -- SISTEMATICO DE SANGRE': 'BASO -- Basophils (Blood Count)', 
    'CA -- CALCIO                                                                          ': 'CA -- CALCIUM', 
    'T4L -- T4 LIBRE                                                                        ': 'T4F -- FREE T4',
    'GRRH -- GRUPO SANGUÖNEO Y FACTOR Rh': 'BGRH -- BLOOD GROUP AND Rh FACTOR', 
    'Tecnica -- Tcnica': 'Technique -- Technique',
    'VRS -- DET. RµPIDA DE AG DE VRS EN M. RESPIRATORIAS': 'RSV -- RAPID DETECTION OF RSV AB IN RESPIRATORY SAMPLES', 
    'PCR VIRUS RESPIRATORIOS -- Tipo de muestra: LAVADO NASOFARÖNGEO': 'RESPIRATORY VIRUS PCR -- Sample type: NASOPHARYNGEAL WASH', 
    'G-CORONAV (RT-PCR) -- Tipo de muestra: LÖQUIDO PERICµRDICO (Muestra no respiratoria).': 'G-CORONAV (RT-PCR) -- Sample type: PERICARDIAL FLUID (Non-respiratory sample).', 
    'OBS_LIQ -- Observaciones Liquidos Biológicos': 'OBS_LIQ -- Biological Fluids Observations', 
    'COODM -- COOMBS DIRECTO MONOESPECÖFICO': 'COODM -- Monospecific Direct Coombs',  
    'FVWAG -- FACTOR VON WILLEBRAND ANTIGNICO': 'FVWAG -- Von Willebrand Factor Antigenic',
    'IGG1 -- IGG1 (INMUNOGLOBULINA G': 'IGG1 -- IGG1 (Immunoglobulin G)', 
    'IFORINA -- INMUNOFIJACION ORINA                                                            ': 'IFORINA -- Urine Immunofixation'  
}

lab['item_lab'] = lab['item_lab'].replace(dict_item_lab)
print(lab['item_lab'].value_counts())

# Filtrar y encontrar valores únicos que contienen letras en una columna específica (por ejemplo, 'columna')
lab['val_result'] = lab['val_result'].str.replace('', 'é', regex=False)
val_result_text = lab[lab['val_result'].str.contains(r'[a-zA-Z]', na=False)]['val_result'].value_counts()

# Imprimir los valores únicos encontrados
print("\n", val_result_text)

# Crear una nueva columna 'result_text' y mover los valores con letras de 'val_result' a 'result_text'
lab.loc[lab['val_result'].str.contains(r'[a-zA-Z]', na=False), 'result_text'] = lab['val_result']

# Dejar los valores con letras en 'val_result' como NaN
lab.loc[lab['val_result'].str.contains(r'[a-zA-Z]', na=False), 'val_result'] = np.nan

dict_result_text = {
    'Negativo': 'Negative',
    'Se detecta': 'Detected',
    'No se detecta': 'Not detected',
    'GRANULOCITOS INMMADUROS': 'IMMATURE GRANULOCYTES',
    'Normal': 'Normal',
    'BLASTOS': 'BLASTS',
    'No remite muestra': 'No sample submitted',
    'Muestra hemolizada': 'Hemolyzed sample',
    'Negativo (< 2.0)': 'Negative (< 2.0)',
    'Negativo (0.04)': 'Negative (0.04)',
    'Negativo (0.07)': 'Negative (0.07)',
    '25 mg/dl': '25 mg/dl',
    'Negativo (0.17)': 'Negative (0.17)',
    '25/μl': '25/μl',
    'PLAQUETAS AGREGADAS': 'AGGREGATED PLATELETS',
    '1 mg/dl': '1 mg/dl',
    'Negativo (0.18)': 'Negative (0.18)',
    'Negativo (0.16)': 'Negative (0.16)',
    'Muestra congelada en HMS': 'Sample frozen at HMS',
    'Negativo (< 0.1)': 'Negative (< 0.1)',
    'Negativo (0.15)': 'Negative (0.15)',
    'Negativo (0.05)': 'Negative (0.05)',
    'Tubo de coagulación mal enrasado': 'Improperly filled coagulation tube',
    'Indeterminado': 'Indeterminate',
    '500/μl': '500/μl',
    'Sangre periférica': 'Peripheral blood',
    'SANGRE PERIFRICA': 'Peripheral blood',
    '250/μl': '250/μl',
    'Muestra coagulada. Rogamos envíen nueva muestra': 'Clotted sample. Please send new sample',
    'Positivo': 'Positive',
    'Negativo (0.19)': 'Negative (0.19)',
    '75 mg/dl': '75 mg/dl', 
    'Negativo (0.06)': 'Negative (0.06)',
    'POSTFILTRO': 'Post-filter',
    'Negativo (0.08)': 'Negative (0.08)',
    '150 mg/dl': '150 mg/dl',
    'Sin resultado': 'No result',
    'Procesada en HMV': 'Processed at HMV',
    'Negativo (0.2)': 'Negative (0.2)',
    '5 mg/dl': '5 mg/dl',
    'Tubo mal enrasado. Rogamos envíen nueva muestra.': 'Improperly filled tube. Please send new sample.',
    'Negativo (0.14)': 'Negative (0.14)',
    'No remite orina aislada': 'No isolated urine submitted',
    'No se detecta ADN del complejo M. tuberculosis': 'M. tuberculosis complex DNA not detected',
    '10/μl': '10/μl',
    '150/μl': '150/μl',
    '100/μl': '100/μl',
    'Muestra hemolizada. Se recomienda enviar nueva muestra para comprobar resultados': 'Hemolyzed sample. Please send new sample to verify results',
    '50/μl': '50/μl',
    'ASPIRADO BRONCOALVEOLAR': 'Bronchoalveolar lavage', 
    'Negativo Título <1/20': 'Negative Titer <1/20',
    'Resultado comprobado': 'Confirmed result',
    '50 mg/dl': '50 mg/dl',
    'Negativo (0.09)': 'Negative (0.09)',
    '4 mg/dl': '4 mg/dl',
    'No se detecta ADN de CMV.': 'CMV DNA not detected.',
    'Debido a la imagen electroforética se recomienda realizar nueva extracción para estudio de inmunofijación en suero.': 'Due to electrophoretic image, it is recommended to perform a new extraction for serum immunofixation study.',
    '15 mg/dl': '15 mg/dl',
    'Negativo (0.64)': 'Negative (0.64)',
    'Negativo (0.67)': 'Negative (0.67)',
    'Negativo (0.68)': 'Negative (0.68)',
    'El suero problema no presenta anormalidad evidente': 'The problem serum shows no apparent abnormality',
    'CONTROL PORTADOR SARM': 'MRSA carrier control',
    'Negativo (0.6)': 'Negative (0.6)',
    'Negativo (0.11)': 'Negative (0.11)',
    'Cauc sica': 'Caucasian',
    'No se detecta ADN de Citomegalovirus': 'No CMV DNA detected',
    'Negativo (0.22)': 'Negative (0.22)',
    'No procede': 'Not applicable', 
    'Negativo (0.23)': 'Negative (0.23)',
    'Negativo (0.13)': 'Negative (0.13)',
    r'Negativo\X0A\- Influenza A: No se detecta\X0A\- Influenza B: No se detecta\X0A\- Influenza H1N1: No se detecta\X0A\- Coronavirus (Cor 229, Cor 63, Cor 43 y HKU): No se detecta\X0A\- Parainfluenza (HPIV1, HPIV2, HPIV3 y HPIV4): No se detecta\X0A\- Adenovirus (HAdV): No se detecta.\X0A\- Virus Respiratorio Sincitial (HRSVA/B): No se detecta.\X0A\- Bocavirus (HBoV): No se detecta.\X0A\- Metapneumovirus (HMPV A/B): No se detecta.\X0A\- Enterovirus (EV): No se detecta.\X0A\- Rinovirus (RV): No se detecta.\X0A\- Parechovirus (HPeV): No se detecta.\X0A\- Mycoplasma pneumoniae (Mpneu): No se detecta.': r'Negative - Influenza A: Not detected, Influenza B: Not detected, H1N1 Influenza: Not detected, Coronavirus (Cor 229, Cor 63, Cor 43, and HKU): Not detected, Parainfluenza (HPIV1, HPIV2, HPIV3, and HPIV4): Not detected, Adenovirus (HAdV): Not detected, Respiratory Syncytial Virus (HRSVA/B): Not detected, Bocavirus (HBoV): Not detected, Metapneumovirus (HMPV A/B): Not detected, Enterovirus (EV): Not detected, Rhinovirus (RV): Not detected, Parechovirus (HPeV): Not detected, Mycoplasma pneumoniae (Mpneu): Not detected',
    'Negativo (0.66)': 'Negative (0.66)',
    'PLASMA': 'PLASMA',
    'Positivo (> 1000.0)': 'Positive (> 1000.0)',
    'LAVADO BRONCOALVEOLAR': 'Bronchoalveolar lavage fluid',
    'Negativo (0.7)': 'Negative (0.7)',
    'No se detectan': 'Not detected',
    'SUERO': 'Serum',
    'Muestra insuficiente. Rogamos envíen nueva muestra': 'Insufficient sample. Please send new sample',
    '1000 mg/dl': '1000 mg/dl',
    'Negativo (0.62)': 'Negative (0.62)',
    'Negativo (0.57)': 'Negative (0.57)',
    'No se observan agregados plaquetarios.': 'No platelet aggregates observed.',
    'Negativo (0.63)': 'Negative (0.63)',
    'Negativo (0.69)': 'Negative (0.69)',
    'Muestra lipémica': 'Lipemic sample',
    'Negativo (0.59)': 'Negative (0.59)',
    'Negativo (0.73)': 'Negative (0.73)',
    'No se observa nada anormal': 'No abnormalities observed',
    'Frotis sugestivo de proceso reactivo.': 'Smear suggestive of reactive process',
    'Negativo (0.72)': 'Negative (0.72)', 
    'Hematíes: de 1 a 5/c': 'Red blood cells: 1 to 5/μL',
    'Líquido pleural': 'Pleural fluid',
    '8 mg/dl': '8 mg/dl',
    '100 mg/dl': '100 mg/dl',
    'Negativo (0.65)': 'Negative (0.65)',
    '500 mg/dl': '500 mg/dl',
    'Negativo (0.54)': 'Negative (0.54)',
    'Resultados comprobados': 'Results confirmed',
    'Negativo (0.21)': 'Negative (0.21)',
    'Negativo (< 0.33)': 'Negative (< 0.33)',
    'Negativo (0.56)': 'Negative (0.56)',
    'POST-FILTRO': 'Post-filter',
    'Negativo (0.24)': 'Negative (0.24)',
    'No se observan': 'Not observed',
    'Se detecta ADN de CMV.': 'CMV DNA detected.',
    'Negativo (0.1)': 'Negative (0.1)',
    'Negativo (0.55)': 'Negative (0.55)',
    'CONTROL PORTADOR BLEE': 'ESBL carrier control',
    r'Negativo\X0A\- Influenza A: No se detecta\X0A\- Influenza B: No se detecta\X0A\- Influenza H1N1: No se detecta\X0A\- Coronavirus (Cor 229, Cor 63, Cor 43 y HKU): No se detecta\X0A\- Parainfluenza (HPIV1, HPIV2, HPIV3 y HPIV4): No se detecta\X0A\- Adenovirus (HAdV): No se detecta.\X0A\- Virus Respiratorio Sincitial (HRSVA/B): No se detecta.\X0A\- Bocavirus (HBoV): No se detecta.\X0A\- Metapneumovirus (HMPV A/B): No se detecta.\X0A\- Rinovirus (RV): No se detecta.\X0A\- Parechovirus (HPeV): No se detecta.\X0A\- Mycoplasma pneumoniae (Mpneu): No se detecta.': r'Negative - Influenza A: Not detected, Influenza B: Not detected, H1N1 Influenza: Not detected, Coronavirus (Cor 229, Cor 63, Cor 43, and HKU): Not detected, Parainfluenza (HPIV1, HPIV2, HPIV3, and HPIV4): Not detected, Adenovirus (HAdV): Not detected, Respiratory Syncytial Virus (HRSVA/B): Not detected, Bocavirus (HBoV): Not detected, Metapneumovirus (HMPV A/B): Not detected, Rinovirus (RV): Not detected, Parechovirus (HPeV): Not detected, Mycoplasma pneumoniae (Mpneu): Not detected',
    'Enviado al Hospital 12 de Octubre': 'Sent to Hospital 12 de Octubre', 
    'Aislados': 'Isolated',
    'Claro': 'Clear',
    'Negativo (0.61)': 'Negative (0.61)',
    'Fórmula leucocitaria provisional pendiente de revisión por el hematólogo.': 'Provisional leukocyte formula pending review by hematologist.',
    'Negativo - Influenza A: No se detecta - Influenza B: No se detecta - Influenza H1N1: No se detecta - Coronavirus (Cor 229': 'Negative - Influenza A: Not detected - Influenza B: Not detected - H1N1 Influenza: Not detected - Coronavirus (Cor 229',
    'Negativo - Influenza A: No se detecta - Influenza B: No se detecta - Influenza H1N1: No se detecta - Coronavirus (Cor 229, Cor 63, Cor 43 y HKU): No se detecta - Parainfluenza (HPIV1, HPIV2, HPIV3 y HPIV4): No se detecta - Adenovirus (HAdV): No se detecta. - Virus Respiratorio Sincitial (HRSVA/B): No se detecta. - Bocavirus (HBoV): No se detecta. - Metapneumovirus (HMPV A/B): No se detecta. - Enterovirus (EV): No se detecta. - Rinovirus (RV): No se detecta. - Parechovirus (HPeV): No se detecta. - Mycoplasma pneumoniae (Mpneu): No se detecta.': 'Negative - Influenza A: Not detected - Influenza B: Not detected - Influenza H1N1: Not detected - Coronavirus (Cor 229, Cor 63, Cor 43, and HKU): Not detected - Parainfluenza (HPIV1, HPIV2, HPIV3, and HPIV4): Not detected - Adenovirus (HAdV): Not detected - Respiratory Syncytial Virus (HRSVA/B): Not detected - Bocavirus (HBoV): Not detected - Metapneumovirus (HMPV A/B): Not detected - Enterovirus (EV): Not detected - Rhinovirus (RV): Not detected - Parechovirus (HPeV): Not detected - Mycoplasma pneumoniae (Mpneu): Not detected.',
    'Negativo (0.03)': 'Negative (0.03)',
    'Negativo (0.58)': 'Negative (0.58)',
    'Negativo Título <1/10': 'Negative Titer <1/10',
    'Negativo (0.12)': 'Negative (0.12)',
    'Negativo (0.27)': 'Negative (0.27)',
    'Negativo (0.74)': 'Negative (0.74)',
    'Negativo Título <1/80': 'Negative Titer <1/80',
    'Negativo (0.31)': 'Negative (0.31)',
    '20 mg/dl': '20 mg/dl',
    'Negativo Título <1/100': 'Negative Titer <1/100',
    'Negativo (0.71)': 'Negative (0.71)',
    'No se detecta ADN de VHS 2.': 'No detection of HSV-2 DNA.',
    '30 mg/dl': '30 mg/dl',
    'Negativo (0.49)': 'Negative (0.49)',
    'Negativo - Influenza A: No se detecta - Influenza B: No se detecta - Influenza H1N1: No se detecta - Coronavirus (Cor 229, Cor 63, Cor 43 y HKU': 'Negative - Influenza A: Not detected - Influenza B: Not detected - H1N1 Influenza: Not detected - Coronavirus (Cor 229, Cor 63, Cor 43, and HKU',
    'Numerosos': 'Numerous',
    'Negativo (0.79)': 'Negative (0.79)', 
    'Leucocitos: de 1 a 5/c': 'Leukocytes: 1 to 5/c',
    'Posible muestra diluida. Rogamos envíen nueva muestra': 'Possible diluted sample. Please send a new sample',
    'Negativo (0.8)': 'Negative (0.8)',
    'Negativo (0.26)': 'Negative (0.26)',
    'Rogamos envien nueva muestra para comprobar resultados. Valorar extracción.': 'Please send a new sample to verify results. Consider extraction.',
    'Negativo (0.34)': 'Negative (0.34)',
    'No remite orina de 24 h': 'Does not send 24-hour urine',
    'Se observan neutrófilos con refuerzo en la granulación.': 'Neutrophils with reinforcement in granulation observed.',
    'Posible interferencia por presencia de macroCK.': 'Possible interference due to presence of macroCK.',
    'SANGRE PERIFÉRICA': 'PERIPHERAL BLOOD',
    'Bacteriuria': 'Bacteriuria',
    'Negativo (0.77)': 'Negative (0.77)',
    'CONTROL PORTADOR BLEE EPC': 'ESBL EPC CARRIER CONTROL',
    'Pruebas no disponibles': 'Tests not available',
    'Negativo (0.75)': 'Negative (0.75)',
    'Negativo (0.02)': 'Negative (0.02)',
    'Negativo (0.29)': 'Negative (0.29)',
    'Estudio citomorfológico sin alteraciones de interés en las tres series.': 'Cytomorphological study without alterations of interest in the three series.',
    'Negativo (0.52)': 'Negative (0.52)',
    'O Positivo': 'O Positive',
    'No se detecta ADN de VHS 1.': 'No detection of HSV-1 DNA.',
    'Hematíes: de 5 a 10/c': 'Red blood cells: 5 to 10/c',
    'Negativo (0.51)': 'Negative (0.51)',
    'Negativo (0.76)': 'Negative (0.76)', 
    'El suero problema presenta una banda débil de características inmunoglobulina G Kappa (IgG-K)': 'The problem serum presents a weak band of immunoglobulin G Kappa (IgG-K) characteristics',
    '10 mg/dl': '10 mg/dl',
    'Negativo (0.25)': 'Negative (0.25)',
    'EXUDADO': 'EXUDATE',
    'No remite muestra REMITE NUEVA MUESTRA CON NUMERO XXXXXXX': 'No sample sent SEND NEW SAMPLE WITH NUMBER X',
    'An lisis cualitativo del ADN del VZV en muestras clínicas por amplificación Real Time (RT-PCR) de la región del gen ORF 29 de VZV.': 'Qualitative analysis of VZV DNA in clinical samples by Real Time (RT-PCR) amplification of the VZV ORF 29 gene region.',
    'Indeterminado (se solicita nueva muestra, si es posible BAL o BAS).': 'Indeterminate (new sample requested, if possible BAL or BAS).',
    'Muestra insuficiente para VSG': 'Insufficient sample for ESR',
    'No se detecta ADN de VZV Límite detección: 2 copias/μl': 'No detection of VZV DNA Detection limit: 2 copies/μl',
    'Determinación realizada en número XXXXXXX': 'Determination made in number X',
    'Determinación realizada en número XXXXXXX': 'Determination made in number X',
    'Determinación realizada en número XXXXXXX': 'Determination made in number X',
    'Negativo (0.3)': 'Negative (0.3)',
    'Negativo (0.53)': 'Negative (0.53)',
    'Negativo (0.32)': 'Negative (0.32)',
    'El herpesvirus varicela-zóster (VZV) es un virus de ADN lineal de cadena doble que pertenece a la familia Herpesviridae. El VZV se caracteriza por su capacidad de permanecer en estado latente en el interior del organismo humano.': 'Varicella-zoster virus (VZV) is a linear double-stranded DNA virus belonging to the Herpesviridae family. VZV is characterized by its ability to remain latent inside the human body.',
    'Indeterminado (Si persiste sospecha diagnóstica, se recomienda remitir nueva muestra, si es posible BAL o BAS)': 'Indeterminate (If diagnostic suspicion persists, it is recommended to send a new sample, if possible BAL or BAS)',
    'Postfiltro': 'Post-filter',
    'El ADN obtenido de la muestra recibida no ha sido de calidad óptima para la PCR (RT-PCR). Se recomienda una nueva toma de muestra.': 'The DNA obtained from the received sample has not been of optimal quality for PCR (RT-PCR). A new sample collection is recommended.',
    'Determinación realizada en N§ XXXXXXX': 'Determination made in No. X',
    'Turbio': 'Turbid',
    'No se detectan (título inferior a 1:20)': 'Not detected (title less than 1:20)',
    'Negativo (0.46)': 'Negative (0.46)', 
    'Negativo (0.4)': 'Negative (0.4)',
    'MUESTRA INSUFICIENTE PARA VSG': 'Insufficient sample for ESR',
    'muestra ictrica': 'Icteric sample',
    'Muestra ictérica': 'Icteric sample',
    'Se observan linfocitos de aspecto estimulado.': 'Lymphocytes with stimulated appearance observed.',
    'Negativo (0.38)': 'Negative (0.38)',
    'LCR': 'CSF (Cerebrospinal Fluid)',
    'Se observan neutrófilos con refuerzo en la granulación y desviación izquierda de posible origen reactivo.': 'Neutrophils with reinforced granulation and left shift suggestive of reactive origin observed.',
    'Negativo (0.41)': 'Negative (0.41)',
    'MUESTRA MAL ENRASADA': 'Sample improperly filled',
    'Negativo (< 0.8)': 'Negative (< 0.8)',
    'Leucocitos: de 15 a 20/c': 'Leukocytes: 15 to 20/c',
    '70 mg/dl': '70 mg/dl',
    'Sin alteraciones citomorfológicas de interés en las tres series.': 'No cytological changes of interest in the three series.',
    'La muestra recibida no ha sido de calidad óptima para la PCR. Se recomienda una nueva toma de muestra.': 'The sample received has not been of optimal quality for PCR. A new sample collection is recommended.',
    'Proteinograma realizado en número XXXXXXX': 'Proteinogram performed in number X',
    'Determinación realizada en número XXXXXXX': 'Determination made in number X',
    'El suero problema presenta una banda muy débil de características inmunoglobulina G Kappa (IgG-K)': 'The problem serum presents a very weak band of immunoglobulin G Kappa (IgG-K) characteristics.',
    'No se detectan (< 0.1)': 'Not detected (< 0.1)',
    'Negativo (0.43)': 'Negative (0.43)',
    'Leucocitos: de 60 a 70/c': 'Leukocytes: 60 to 70/c',
    'Procesado en HMV': 'Processed at HMV',
    'Positivo (> 500.0)': 'Positive (> 500.0)',
    'Determinación realizada en número XXXXXXX': 'Determination made in number X',
    'Determinación realizada en número XXXXXXX': 'Determination made in number X',
    'ENVIADO RYC': 'SENT RYC', 
    'Leucocituria': 'Leukocyturia',
    'Negativo (0.36)': 'Negative (0.36)',
    'Estudio citomorfológico sin alteraciones rese¤ables.': 'Cytomorphological study without remarkable alterations.',
    'Negativo (< 0.15)': 'Negative (< 0.15)',
    'El suero problema presenta una banda de características inmunoglobulina G Kappa (IgG-K)': 'The problem serum presents a band of immunoglobulin G Kappa (IgG-K) characteristics.',
    '2 mg/dl': '2 mg/dl',
    'Muestra remitida en condiciones inadecuadas. Se ruega nueva muestra': 'Sample sent under inadequate conditions. Please send new sample.',
    'Determinación realizada en número XXXXXXX': 'Determination made in number X',
    'Negativo (0.47)': 'Negative (0.47)',
    'Indeterminado (se solicita nueva muestra transcurridos 2 días, si persisten síntomas).': 'Indeterminate (new sample requested after 2 days if symptoms persist).',
    'Control Portador SARM': 'Carrier Control MRSA',
    'PREFILTRO': 'Prefilter',
    'CRIBADO EPC': 'EPC Screening',
    'No se detecta ADN de Epstein-Barr.': 'Epstein-Barr DNA not detected.',
    '3 mg/dl': '3 mg/dl',
    'Negativo (0.33)': 'Negative (0.33)',
    'postfiltro': 'Post-filter',
    'Positivo (> 1.5)': 'Positive (> 1.5)',
    'ENVIADO A RAMON Y CAJAL': 'SENT TO RAMON Y CAJAL',
    'Negativo (0.01)': 'Negative (0.01)',
    'Rogamos envíen nueva muestra': 'Please send new sample',
    'Frotis sugestivo de proceso reactivo inflamatorio/infeccioso.': 'Smear suggestive of reactive inflammatory/infectious process.',
    'Indeterminado (se solicita nueva muestra': 'Indeterminate (new sample requested)',
    'ELISA reactivo (124.7)': 'ELISA reactive (124.7)', 
    'Se observan varios eliptocitos. Desviación izquierda con hipersegmentación nuclear en neutrófilos.': 'Several elliptocytes observed. Left shift with nuclear hypersegmentation in neutrophils.',
    'Prueba ya solicitada en fecha XXXX-XX-XX en muestra XXXXXXX': 'Test already requested',
    'Negativo (0.0)': 'Negative (0.0)',
    'Prueba ya solicitada en fecha XXXX-XX-XX en muestra XXXXXXX': 'Test already requested',
    'Frotis informado en muestra No. XXXXXXX': 'Smear reported in sample No. X',
    'Negativo (0.94)': 'Negative (0.94)',
    'MUESTRA INSUFICIENTE': 'INSUFFICIENT SAMPLE',
    'Valorar realizar nueva extracción': 'Consider performing a new extraction',
    'Prueba ya solicitada en fecha XXXX-XX-XX en muestra XXXXXXX': 'Test already requested',
    'Prueba ya solicitada en fecha XXXX-XX-XX en muestra XXXXXXX': 'Test already requested',
    'GASOMETRÍA INFORMADA EN XXXXXXX': 'BLOOD GAS ANALYSIS REPORTED IN X',
    'REMITE NUEVA MUESTRA CON NUMERO XXXXXXX': 'SEND NEW SAMPLE WITH NUMBER X',
    'Anisocitosis de serie roja. Trombopenia leve comprobada. No se observan rasgos displ sicos.': 'Red cell anisocytosis. Mild thrombocytopenia confirmed. No dysplastic features observed.',
    'Tubo mal enrasado.': 'Tube improperly filled.',
    'CONTROL PORTADOR BLEE, EPC': 'ESBL CARRIER CONTROL, EPC',
    'Hematuria': 'Hematuria',
    'Frotis revisado por Hematólogo. Se observa leucocitosis con neutrofilia y desviación izquierda.': 'Smear reviewed by hematologist. Leukocytosis with neutrophilia and left shift observed.',
    'Trombopenia leve comprobada. Resto de series sin alteraciones morfológicas rese¤ables.': 'Mild thrombocytopenia confirmed. Rest of series without remarkable morphological alterations.',
    '6 mg/dl': '6 mg/dl',
    'Presencia de burbujas en jeringa de gasometría': 'Presence of bubbles in blood gas syringe',
    'Se realiza la determinación en N§ XXXXXXX': 'Determination made in No. X',
    'Hematíes: de 30 a 50/c': 'Red blood cells: 30 to 50/c',
    'Se recomienda remitir nueva muestra para confirmar estos resultados': 'It is recommended to send a new sample to confirm these results', 
    'Se detecta ADN de VHS 1.': 'HSV 1 DNA detected.',
    'Muestra insuficiente': 'Insufficient sample',
    'Negativo (0.39)': 'Negative (0.39)',
    'Positivo (10.0)': 'Positive (10.0)',
    'Positivo (331.0)': 'Positive (331.0)',
    'SUERO MUY HEMOLIZADO': 'VERY HEMOLYZED SERUM',
    'Líquido Ascítico': 'Ascitic Fluid',
    'Positivo (23.37)': 'Positive (23.37)',
    'Reacción leucoeritrobl stica sugestiva de proceso reactivo inflamatorio/infeccioso severo.': 'Leukoerythroblastic reaction suggestive of severe inflammatory/infectious reactive process.',
    'Positivo (166.3)': 'Positive (166.3)',
    '75/μl': '75/μl',
    'ELISA reactivo (91.44)': 'Reactive ELISA (91.44)',
    'BAS': 'BAS',
    'Detección de virus Gripe A/B An lisis cualitativo de material genético de virus respiratorios por Real-Time PCR (RT-PCR)': 'Detection of Influenza A/B viruses Qualitative analysis of respiratory virus genetic material by Real-Time PCR (RT-PCR)',
    'A Positivo': 'A Positive',
    'Trombopenia comprobada. Se evidencian núcleos en apoptosis.': 'Thrombocytopenia confirmed. Apoptotic nuclei observed.',
    'No remite muestra para crioglobulinas': 'No sample submitted for cryoglobulins',
    'Determinaciones técnicamente comprobadas. Valorar extracción': 'Technically verified determinations. Consider extraction',
    'Hipocromía con presencia de ovalocitos y eliptocitos. Se observan linfocitos de aspecto estimulado. Neutrófilos vacuolados.': 'Hypochromia with presence of ovalocytes and elliptocytes. Stimulated lymphocytes observed. Vacuolated neutrophils.',
    'Informado en el número XXXXXXX': 'Reported in number X',
    'Leucocitos: de 20 a 30/c': 'Leukocytes: 20 to 30/c',
    'Componente monoclonal estimado: 0.6 g/dL (10%)': 'Estimated monoclonal component: 0.6 g/dL (10%)', 
    'Positivo (70.53)': 'Positive (70.53)',
    'Positivo (73.1)': 'Positive (73.1)',
    'LIQUIDO PLEURAL': 'PLEURAL FLUID',
    'Se observan neutrófilos con refuerzo en la granulación. Serie roja con Hipocromía severa.': 'Neutrophils with enhanced granulation observed. Red series with severe hypochromia.',
    'Cifra de plaqueas confirmada: posible trombocitosis reactiva': 'Platelet count confirmed: possible reactive thrombocytosis',
    'Se observan linfocitos de aspecto estimulado. Neutrófilos vacuolados con granulación tóxica y picnosis nuclear. Serie roja con anisocromía moderada.': 'Stimulated lymphocytes observed. Vacuolated neutrophils with toxic granulation and nuclear pyknosis. Red series with moderate anisochromia.',
    'ELISA reactivo (51.86)': 'Reactive ELISA (51.86)',
    'Componente monoclonal estimado 0.1 g/dL (3.2%)': 'Estimated monoclonal component 0.1 g/dL (3.2%)',
    'Serie roja con aniscromía con presencia de hipocromía moderada y policromasia. Se observan desviación izquierda y neutrófilos con granulación tóxica e hipersegmentación nuclear.': 'Red series with anisochromia, moderate hypochromia, and polychromasia. Left shift and neutrophils with toxic granulation and nuclear hypersegmentation observed.',
    'Se recomienda solicitar nuevamente el estudio y correlacionar con antecedentes familiares y personales de coagulopatía. Estudio sugestivo de déficit de FXI (hemofilia C).': 'It is recommended to request the study again and correlate with family and personal history of coagulopathy. Study suggestive of FXI deficiency (hemophilia C).',
    'La orina problema presenta una imagen electroforética compatible con tipo glomerular.': 'The problem urine shows an electrophoretic image compatible with the glomerular type.',
    'Positivo (383.0)': 'Positive (383.0)',
    'Frotis sugestivo de proceso reactivo infeccioso/inflamatorio.': 'Smear suggestive of reactive infectious/inflammatory process.',
    'Serie roja con tendencia a rouleaux. Se observa algún dianocito. Desviación izquierda. Trombopenia comprobada.': 'Red series with a tendency to rouleaux. Some target cells observed. Left shift. Thrombocytopenia confirmed.',
    'ELISA reactivo (47.15)': 'Reactive ELISA (47.15)',
    'Discreta hipocromía en la serie roja': 'Mild hypochromia in the red series',
    'Drenaje': 'Drainage',
    'Frotis revisado por Hematólogo. Anisocitosis e hipocromía en serie roja. No observo esquistocitos. Algunos microagregados plaquetarios.': 'Smear reviewed by Hematologist. Anisocytosis and hypochromia in red series. No schistocytes observed. Some platelet microaggregates.',
    'Serie roja con hipocromía. Presencia de ovalocitos. Linfocitos activados. Neutrófilos con refuerzo de la granulación.': 'Red series with hypochromia. Presence of ovalocytes. Activated lymphocytes. Neutrophils with enhanced granulation.',
    'Determinaciones informadas en muestra XXXXXXX': 'Determinations reported in sample X',
    'Indeterminado (0.75)': 'Indeterminate (0.75)',
    'IgG positivo +4': 'IgG positive +4', 
    'Positivo (61.09)': 'Positive (61.09)',
    'Serie roja con anisocromía y anisocitosis. Resto de series sin alteraciones rese¤ables.': 'Red series with anisochromia and anisocytosis. Rest of the series without notable alterations.',
    'Control portador SARM': 'MRSA carrier control',
    'Determinación realizada en número XXXXXXX': 'Determination made in number X',
    'Serie roja con Anisocromia e hipocromía. Se observan frecuentes ovalocitos. Resto de series sin alteraciones morfológicas rese¤ables.': 'Red series with anisochromia and hypochromia. Frequent ovalocytes observed. Rest of the series without notable morphological alterations.',
    'Prueba ya solicitada en fecha XXXX-XX-XX en muestra XXXXXXX. Deben transcurrir al menos 72h desde la última petición': 'Test already requested. At least 72 hours must pass since the last request',
    'ESCARA SACRA.': 'SACRAL ESCAR',
    'Negativo (< 0.13)': 'Negative (< 0.13)',
    'Positivo (1.28)': 'Positive (1.28)',
    'Se observan neutrófilos con refuerzo en la granulación. Serie roja no valorable por presencia de artefacto en la muestra.': 'Neutrophils with enhanced granulation observed. Red series not assessable due to artifact presence in the sample.',
    'Se observan anisocitosis y macro ovalocitos. Presencia de linfocitos activados. Desviación izquierda y neutrófilos con refuerzo de la granulación.': 'Anisocytosis and macro ovalocytes observed. Presence of activated lymphocytes. Left shift and neutrophils with enhanced granulation.',
    'Glucosa en n§ petición XXXXXXX': 'Glucose in request number X',
    'Recuento manual: 55% seg, 23% linfo, 11% eos, 9% mono, 2% cay. Se observan neutrófilos con refuerzo de la granulación.': 'Manual count: 55% seg, 23% lymph, 11% eos, 9% mono, 2% band. Neutrophils with enhanced granulation observed.',
    'HERIDA SACRO': 'SACRAL WOUND',
    'Negativo (0.5)': 'Negative (0.5)',
    'Se recomienda valorar nueva extracción': 'It is recommended to consider a new extraction',
    'Se observan linfocitos de aspecto estimulado. Trombopenia comprobada. Resto de series sin alteraciones rese¤ables.': 'Stimulated lymphocytes observed. Thrombocytopenia confirmed. Rest of the series without notable alterations.',
    'Presencia de abundantes levaduras': 'Presence of abundant yeasts',
    'Positivo (13.03)': 'Positive (13.03)',
    '300 mg/dl': '300 mg/dl',
    '18 copias/mL': '18 copies/mL',
    'Sin alteraciones citomorfológicas de interés en el resto de las series: serie roja sin alteraciones y segmentados correctamente segmentados y granulados.': 'No cytomorphological alterations of interest in the rest of the series: red series without alterations and correctly segmented and granulated.',
    'Resultado no valorable. Se recomienda realizar nueva extracción venosa': 'Result not assessable. It is recommended to perform a new venous extraction',
    '298 copias/mL': '298 copies/mL', 
    'Positivo (2.69)': 'Positive (2.69)',
    'Recuento manual: 50% seg, 10% cay, 27 % eos, 10% linfo, 3% mono. Hipocromía moderada con presencia de ovalocitos.': 'Manual count: 50% seg, 10% band, 27% eos, 10% lymph, 3% mono. Moderate hypochromia with the presence of ovalocytes.',
    'Control portador EPC': 'EPC carrier control',
    'Gasometría arterial basal': 'Baseline arterial blood gas',
    'Vmax 50%': 'Vmax 50%',
    'Positivo (152.2)': 'Positive (152.2)',
    'Positivo (1.52)': 'Positive (1.52)',
    'Determinación realizada en número XXXXXXX': 'Determination made in number X',
    'Positivo (6.74)': 'Positive (6.74)',
    'Muestra insuficiente para realizar sedimento urinario.': 'Insufficient sample to perform urine sediment.',
    'Prueba ya solicitada en fecha XXXX-XX-XX en muestra XXXXXXX. Deben transcurrir al menos 72h desde la última petición.': 'Test already requested. At least 72 hours must pass since the last request.',
    'Positivo (226.0)': 'Positive (226.0)',
    'Se observa desviación izquierda. Presencia de neutrófilos vacuolados con granulación tóxica. Serie roja con abundantes equinocitos (probable artefacto en la muestra)': 'Left shift observed. Presence of vacuolated neutrophils with toxic granulation. Red series with abundant echinocytes (probable artifact in the sample)',
    'Determinación realizada en número XXXXXXX': 'Determination made in number X',
    'Positivo (32.28)': 'Positive (32.28)',
    'CONTROL BLEE + EPC': 'BLEE CONTROL + EPC',
    'Muestra muy diluída. No es posible realizar el estudio solicitado.': 'Sample very diluted. It is not possible to perform the requested study.',
    'Muestras de hemograma y coagulación mal enrasadas. Solicitadas nuevas muestras': 'Poorly leveled hemogram and coagulation samples. New samples requested',
    'El suero problema presenta una banda muy débil de características inmunoglobulina G Lambda (IgG-L)': 'The problem serum shows a very weak band of immunoglobulin G Lambda (IgG-L) characteristics',
    'Negativo (0.35)': 'Negative (0.35)',
    'Se observa 1 eritroblastos/100 leucocitos': '1 erythroblast/100 leukocytes observed',
    'Positivo (891.9)': 'Positive (891.9)',
    'Prueba ya solicitada en fecha XXXX-XX-XX en muestra XXXXXXX': 'Test already requested',
    'Desviación izquierda. Se observan neutrófilos con gran refuerzo en la granulación.': 'Left shift. Neutrophils with marked granulation enhancement observed.',
    'Se observa desviación izquierda. Neutrófilos con refuerzo de la granulación.': 'Left shift observed. Neutrophils with granulation enhancement.', 
    'No remite muestra para Calcio y Cloro': 'No sample sent for Calcium and Chlorine',
    'Hematíes: de 40 a 50/c': 'Red blood cells: 40 to 50/c',
    'CONTROL PORTADORES EPC BLEE': 'EPC BLEE CARRIERS CONTROL',
    'CATTER SUBCLAVIA DERECHA': 'RIGHT SUBCLAVIAN CATHETER',
    'Líquido Sinovial': 'Synovial Fluid',
    'Se observan linfocitos de aspecto estimulado. Serie roja con hipocromía. Frecuentes ovalocitos.': 'Stimulated-appearing lymphocytes observed. Red series with hypochromia. Frequent ovalocytes.',
    '30/μl': '30/μl',
    'Hematíes: de 110 a 115/c': 'Red blood cells: 110 to 115/c',
    'Se observan neutrófilos vacuolados y agregados plaquetarios. Serie roja no valorable por artefacto.': 'Vacuolated neutrophils and platelet aggregates observed. Red series not assessable due to artifact.',
    'Aspirada bronquial: muestra muy escasa': 'Bronchial aspirate: very scant sample',
    'Muestra insuficiente. Rogamos envíen nueva muestra.': 'Insufficient sample. Please send a new sample.',
    'Control portador EPC .': 'EPC carrier control.',
    'Muestra mal enrasada': 'Poorly leveled sample',
    'Frotis revisado por Hematólogo. Recuento celular diferencial confirmado. No observo agregados de plaquetas. No se observan células inmaduras.': 'Smear reviewed by Hematologist. Differential cell count confirmed. No platelet aggregates observed. No immature cells observed.',
    'Médula Ósea': 'Bone Marrow',
    'Pruebas informadas en petición XXXXXXX de hoy': 'Tests reported in today\'s request X',
    'Estudio citomorfológico sin alteraciones de interés.': 'Cytomorphological study without relevant findings.',
    'POTSFILTRO': 'POSTFILTER',
    'Serie roja con moderada hipocromía, presencia de dianocitos. Serie blanca con desviación izquierda, refuerzo de la granulación.': 'Red series with moderate hypochromia, presence of target cells. White series with left shift, granulation enhancement.',
    'El suero problema presenta una banda muy débil de características inmunoglobulina M Kappa (IgM-K)': 'The problem serum shows a very weak band of immunoglobulin M Kappa (IgM-K) characteristics',
    'Se observa desviación izquierda. Neutrófilos con granulación tóxica. Se observan frecuentes ovalocitos y eliptocitos.': 'Left shift observed. Neutrophils with toxic granulation. Frequent ovalocytes and elliptocytes observed.',
    'Procesado en XXXXXXX': 'Processed in X',
    'Indeterminado (Si persiste sospecha diagnóstica': 'Indeterminate (If diagnostic suspicion persists', 
    'HERIDA DE éLCERA SACRA': 'SACRAL ULCER WOUND',
    'PORTADOR PSEUDOMONA MR': 'MR PSEUDOMONAS CARRIER',
    'Recuento manual: 74% seg, 6% cay, 8% linfo, 12% mono. Neutrófilos con refuerzo de la granulación. Hipocromía moderada con presencia de eliptocitos.': 'Manual count: 74% seg, 6% cay, 8% lymph, 12% mono. Neutrophils with granulation reinforcement. Moderate hypochromia with elliptocytes present.',
    'Se observa desviación izquierda. Neutrófilos con refuerzo de la granulación. Presencia de agregados plaquetarios.': 'Left shift observed. Neutrophils with granulation reinforcement. Presence of platelet aggregates.',
    'Anisocromía con policromasia. Presencia de ovalocitos. Se observan desviación izquierda y refuerzo de la granulación neutrofílica. Se observan agregados plaquetarios.': 'Anisochromia with polychromasia. Presence of ovalocytes. Left shift and neutrophilic granulation reinforcement observed. Platelet aggregates observed.',
    'CONTROL PORTADOR BLEE + EPC': 'CONTROL BLEE + EPC',
    'Muestra XXXXXXX': 'Sample X',
    'Serie roja con hipocromía moderada, anisocitosis con microcitosis. Se observan algunos dianocitos. Trombopenia comprobada.': 'Red series with moderate hypochromia, anisocytosis with microcytosis. Some target cells observed. Thrombopenia confirmed.',
    'Se observa anisocitosis e hipocromía. Se observan frecuentes ovalocitos y algunos eliptocitos.': 'Anisocytosis and hypochromia observed. Frequent ovalocytes and some elliptocytes observed.',
    'Frotis sugestivo de reacción leucoeritroblástica.': 'Smear suggestive of leukoerythroblastic reaction.',
    'Se observa desviación izquierda con neutrófilos vacuolados y con refuerzo de la granulación.': 'Left shift observed with vacuolated neutrophils and granulation reinforcement.',
    'Rogamos envíen nueva muestra para confirmar resultados. Valorar extracción': 'Please send a new sample to confirm results. Consider extraction',
    'Se observa anisopoiquilocitosis. Presencia de equinocitos y acantocitos. Desviación izquierda. Presencia de neutrófilos vacuolados con granulación tóxica. Macrotrombocitos con granulación normal y dilataciones vacuolares.': 'Anisopoikilocytosis observed. Presence of echinocytes and acanthocytes. Left shift. Presence of vacuolated neutrophils with toxic granulation. Macrothrombocytes with normal granulation and vacuolar dilations.',
    'MDULA ÓSEA': 'BONE MARROW',
    'MDULA ÓSEA': 'Bone Marrow',
    'SISTMICO': 'Systemic',
    'Prueba ya solicitada en fecha XXXX-XX-XX en muestra XXXXXXX. Deben transcurrir al menos 72h desde la última petición.': 'Test already requested. At least 72 hours must pass since the last request.',
    'Muestra congelada en HMS con número XXXXXXX': 'Sample frozen in HMS',
    'Determinación realizada en número XXXXXXX': 'Determination made in number X',
    'Control Portador EPC blee': 'EPC BLEE Carrier Control',
    'NEFROSTOMIA DERECHA': 'RIGHT NEPHROSTOMY',
    'NEFROSTOMIA IZQUIERDA': 'LEFT NEPHROSTOMY',
    'UROSTOMIA DERECHA': 'RIGHT UROSTOMY',
    'UROSTOMIA IZQUIERDA': 'LEFT UROSTOMY',
    'UPP SACRO.': 'SACRAL ULCER.', 
    'Se observan abundantes células rotas y sombras nucleares. Linfocitos heterogéneos algunos con núcleo de morfología activada e irregular. Se recomienda ampliar inmunofenotipo a distancia de cuadro infeccioso.': 'Abundant broken cells and nuclear shadows observed. Heterogeneous lymphocytes, some with activated and irregular nuclear morphology. Recommend extending immunophenotype away from infectious episode.',
    'Serie roja con moderada hipocromía, punteado basófilo. Se observan frecuentes dianocitos, algún equinocito y ovalocito. Trombopenia comprobada.': 'Red series with moderate hypochromia, basophilic stippling. Frequent target cells, some echinocytes, and ovalocytes observed. Thrombopenia confirmed.',
    'Osmolaridad calculada en orina aislada': 'Calculated osmolality in isolated urine',
    'Serie roja con moderada hipocromía': 'Red series with moderate hypochromia',
    'Valorar nueva extracción para comprobar resultados': 'Consider new extraction to verify results',
    'Determinaciones anuladas p.o. médica.': 'Determinations canceled per medical order.',
    'Enviado a H Ramón y Cajal': 'Sent to H Ramón y Cajal',
    'La orina problema presenta una imagen electroforética con bandas de albúmina y globulinas.': 'Problem urine presents an electrophoretic pattern with albumin and globulin bands.',
    'Prueba ya solicitada en fecha XXXX-XX-XX en muestra XXXXXXX. Deben transcurrir al menos 72h desde la última petición.': 'Test already requested. At least 72 hours must pass since the last request.',
    '12 mg/dl': '12 mg/dl',
    'Indeterminado (se solicita nueva muestra transcurridos 2 días': 'Indeterminate (new sample requested after 2 days)',
    'Muestra coagulada. Se ruega envíen nueva muestra': 'Coagulated sample. Please send a new sample',
    'Resultado comprobado Rogamos envien nueva muestra.': 'Result verified. Please send a new sample.',
    'POST FILTRO': 'POST FILTER',
    'SISTMICO': 'SYSTEMIC',
    'CALCIO POSTFILTRO': 'POST FILTER CALCIUM',
    'NO REMITE MUESTRA': 'NO SAMPLE SENT',
    'Hematuria macroscópica': 'Macroscopic hematuria',
    'Frotis revisado por Hematólogo. Anisocitosis serie roja. Algunas plaquetas grandes. No observo agregados plaquetarios. No observo esquistocitos.': 'Smear reviewed by Hematologist. Red series anisocytosis. Some large platelets. No platelet aggregates observed. No schistocytes observed.',
    'Resultado comprobado Valorar extracción': 'Result verified. Consider extraction',
    'Positivo Título 1/400': 'Positive Titer 1/400',
    'No remite muestra para realizar calcio y cloro': 'No sample sent for calcium and chlorine analysis',
    'No remite muestra para realizar el Magnesio': 'No sample sent for magnesium analysis',
    'Serie roja con moderada hipocromía. Neutrófilos con refuerzo de la granulación.': 'Red series with moderate hypochromia. Neutrophils with granulation reinforcement.',
    'El suero problema presenta una banda de características inmunoglobulina M Lambda (IgM-L)': 'The problem serum presents a band characteristic of immunoglobulin M Lambda (IgM-L)',
    'Serie roja con tendencia a rouleaux e hipocromía moderada. Se observan ovalocitos y linfocitos de aspecto activado.': 'Red series with rouleaux tendency and moderate hypochromia. Ovalocytes and activated-appearing lymphocytes observed.',
    'LACTATO INFORMADO EN EL XXXXXXX': 'LACTATE REPORTED IN X',
    'Hem tico': 'Hematic',
    'Líquido Peric rdico': 'Pericardial Fluid',
    'Positivo (3.26)': 'Positive (3.26)',
    'Negativo (0.78)': 'Negative (0.78)',
    'Anisocitosis de serie roja sin presencia de esquistocitos ni otras alteraciones de forma que sugieran hemólisis. Serie blanca de aspecto reactivo a proceso inflamatorio o infeccioso.': 'Red series anisocytosis without schistocytes or other shape alterations suggesting hemolysis. White series appears reactive to inflammatory or infectious process.',
    'No se detectan (título inferior a 1:192)': 'Not detected (titer below 1:192)',
    'La orina problema no presenta anormalidad evidente.': 'Problem urine shows no evident abnormality.',
    'No se detectan (título inferior a 1:40)': 'Not detected (titer below 1:40)',
    'Positivo (24.65)': 'Positive (24.65)',
    'Indeterminado (0.86)': 'Indeterminate (0.86)',
    'Positivo (314.0)': 'Positive (314.0)',
    'TB1: <0.1 TB2: <0.1': 'TB1: <0.1 TB2: <0.1',
    'No se detectan (título inferior a 1:12)': 'Not detected (titer below 1:12)',
    'No se detectan (título inferior a 1:64)': 'Not detected (titer below 1:64)',
    'No se detectan (título inferior a 1:100)': 'Not detected (titer below 1:100)',
    'No se detectan (título inferior a 1:320)': 'Not detected (titer below 1:320)',
    'Componente monoclonal estimado: 0.2 g/dL (4.8%)': 'Estimated monoclonal component: 0.2 g/dL (4.8%)',
    'Positivo (13.18)': 'Positive (13.18)',
    'ELISA reactivo (141.4)': 'Reactive ELISA (141.4)',
    'CATTER VIA BILIAR': 'BILIARY CATHETER',
    'prefiltro': 'pre-filter',
    'Líquido biliar': 'Biliary fluid',
    'Negativo (2.28)': 'Negative (2.28)', 
    'Positivo (14.71)': 'Positive (14.71)',
    '- Influenza A (Gripe A): No se detecta - Influenza B (Gripe B): No se detecta': '- Influenza A (Flu A): Not detected - Influenza B (Flu B): Not detected',
    'Muestra no valida. Se precisa BAL.': 'Invalid sample. BAL required.',
    'Positivo (26.9)': 'Positive (26.9)',
    'Positivo (129.5)': 'Positive (129.5)',
    'Negativo (0.98)': 'Negative (0.98)',
    'Positivo (118.4)': 'Positive (118.4)',
    'Drogas de Abuso': 'Drug abuse',
    'ELISA reactivo (1.18)': 'Reactive ELISA (1.18)',
    'Positivo (16.65)': 'Positive (16.65)',
    'FORMULA PROVISIONAL PENDIENTE DE REVISION DE FROTIS POR EL HEMATOLOGO': 'Provisional formula pending review by hematologist',
    'Positivo (16.97)': 'Positive (16.97)',
    'Positivo (10.37)': 'Positive (10.37)',
    'Positivo (22.7)': 'Positive (22.7)',
    'Negativo (0.96)': 'Negative (0.96)',
    'Posible confusión de paciente. Resultados anulados': 'Possible patient mix-up. Results canceled',
    'Positivo (353.7)': 'Positive (353.7)',
    'Negativo (7.0)': 'Negative (7.0)',
    'Muestra insuficiente VSG': 'Insufficient sample ESR',
    'Positivo (83.35)': 'Positive (83.35)',
    'Hematies: de 50 a 60/c': 'Red blood cells: 50 to 60/c',
    'Positivo (242.4)': 'Positive (242.4)',
    'Frotis con alteraciones morfológicas superponibles a las del frotis solicitado en la muestra XXXXXXX del día XX.XX.': 'Smear with morphological alterations overlapping those of the smear requested in sample X.', 
    'Positivo (5.78)': 'Positive (5.78)',
    'Positivo (43.65)': 'Positive (43.65)',
    'Positivo (2.27)': 'Positive (2.27)',
    'PORTADOR SARM': 'MRSA carrier',
    'PORTADOR BLEE EPC': 'ESBL EPC carrier',
    'Nivel bajo (1.33)': 'Low level (1.33)',
    'Anisocromía con hipocromía. Se observan desviación izquierda y granulación tóxica en neutrofilos. Presencia de linfocitos activados.': 'Anisocytosis with hypochromia. Left shift and toxic granulation in neutrophils. Presence of activated lymphocytes.',
    'Positivo (78.1)': 'Positive (78.1)',
    'Muestra congelada en HMN': 'Sample frozen in HMN',
    'TP:12.0s AP:89% INR:1.07 APTT:40.5s': 'PT: 12.0s AP: 89% INR: 1.07 APTT: 40.5s',
    'Se observa anisocitosis e hipocromía moderada, algún dianocito y anulocito. Presencia de agregados plaquearios.': 'Anisocytosis with moderate hypochromia, some dianocytes and anulocytes. Presence of platelet aggregates.',
    'Positivo (6.3)': 'Positive (6.3)',
    'Positivo (9.38)': 'Positive (9.38)',
    'La orina problema presenta una débil banda de características de tipo cadenas ligeras Lambda (L).De manera adicional la imagen presenta perfil glomerular.Para un estudio completo es indispensable an lisis simult neo de suero y orina por inmunofijación.': 'The urine problem presents a weak band of characteristics of Lambda light chains (L). Additionally, the image presents a glomerular profile. For a complete study, simultaneous analysis of serum and urine by immunofixation is essential.',
    '35 copias/mL': '35 copies/mL',
    '255 copias/mL': '255 copies/mL',
    '1847 copias/mL': '1847 copies/mL',
    'Incontables': 'Countless',
    'No se realizan pruebas de serología IgG e IgM SARS Cov2': 'No IgG and IgM SARS-CoV-2 serology tests performed',
    'Positivo (46.31)': 'Positive (46.31)',
    'Negativo (0.81)': 'Negative (0.81)',
    'ELISA reactivo (56.2)': 'Reactive ELISA (56.2)', 
    'Se observan neutrófilos hipersegmentados y vacuolados. Serie roja con presencia de ovalocitos. Resto de series sin lateraciones rese¤ables.': 'Hypersegmented and vacuolated neutrophils. Red series with presence of ovalocytes. Other series without notable alterations.',
    'Deben transcurrir 72 horas mínimo desde la última petición': 'At least 72 hours must elapse since the last request.',
    'Determinación realizada en número XXXXXXX': 'Determination made on number X',
    '21 copias/mL': '21 copies/mL',
    'Se observa desviación izquierda. Neutrófilos con refuerzo de la granulación e hipersegmentación nuclear. Presencia de linfocitos activados.': 'Left shift observed. Neutrophils with granulation reinforcement and nuclear hypersegmentation. Presence of activated lymphocytes.',
    '6 copias/mL': '6 copies/mL',
    'Positivo (7.45)': 'Positive (7.45)',
    'Frotis de aspecto reactivo.': 'Reactive appearance smear.',
    'Zona limite (0.89)': 'Borderline zone (0.89)',
    'Positivo (4.32)': 'Positive (4.32)',
    'Positivo (974.0)': 'Positive (974.0)',
    'Zona limite (0.99)': 'Borderline zone (0.99)',
    'Leucocitos: de 10 a 15/c': 'Leukocytes: 10 to 15/c',
    'Positivo (18.24)': 'Positive (18.24)',
    'Anisocitosis. Presencia de ovalocitos. Se observa desviación izquierda en serie blanca. Trombopenia comprobada.': 'Anisocytosis. Presence of ovalocytes. Left shift observed in white series. Confirmed thrombocytopenia.',
    'Abundantes fosfatos amorfos': 'Abundant amorphous phosphates',
    'Cristales de oxalato c lcico': 'Calcium oxalate crystals',
    'HERIDA DE TRAQUEOTOMÍA': 'TRACHEOTOMY WOUND',
    'Líquido Cefalorraquídeo': 'Cerebrospinal Fluid',
    'Positivo (45.92)': 'Positive (45.92)',
    'Negativo (0.84)': 'Negative (0.84)',
    'ELISA reactivo (66.83)': 'Reactive ELISA (66.83)',
    'Positivo (4.96)': 'Positive (4.96)',
    'TIPO DE MUESTRA: BAS': 'SAMPLE TYPE: BAS', 
    'GTL': 'GTL',
    'Componente monoclonal estimado: 0.4 g/dL (7.1%)': 'Monoclonal component estimated: 0.4 g/dL (7.1%)',
    'Sin alteraciones citomorfológicas de interés en el resto de las series.': 'No cytomorphological alterations of interest in the rest of the series.',
    'Negativo (2.02)': 'Negative (2.02)',
    'SUBCLASE 1)': 'SUBCLASS 1)',
    'SUBCLASE 3)': 'SUBCLASS 3)',
    'Sin resultado.': 'No result.',
    'Negativo (0.85)': 'Negative (0.85)',
    'No se observan cristales': 'No crystals observed',
    'Negativo (4.38)': 'Negative (4.38)',
    'Positivo (194.0)': 'Positive (194.0)',
    'No remite nueva muestra': 'No new sample sent',
    'Serie roja con tendencia a rouleaux. Hipocromía moderada. Presencia de eliptocitos y ovalocitos. Se observan neutrófilos con refuerzo en la granulación.': 'Red series with tendency to rouleaux. Moderate hypochromia. Presence of elliptocytes and ovalocytes. Neutrophils observed with granulation reinforcement.',
    'Frotis altamente sugestivo de proceso reactivo infeccioso/inflamatorio. Se recomienda control de frotis a distancia.': 'Smear highly suggestive of reactive infectious/inflammatory process. Follow-up smear recommended.',
    'Trombopenia confirmada. No se observan agregados plaquetarios. No observo esquistocitos.': 'Confirmed thrombocytopenia. No platelet aggregates observed. No schistocytes observed.',
    'Positivo (6.2)': 'Positive (6.2)',
    'No remite BAS': 'No BAS sent',
    'Se observan neutrófilos vacuolados con refuerzo en la granulación. Hipocromía, con algún eliptocito.': 'Vacuolated neutrophils observed with granulation reinforcement. Hypochromia, with some elliptocyte.',
    'Negativo (0.45)': 'Negative (0.45)',
    'Negativo (0.44)': 'Negative (0.44)',
    'Negativo (0.86)': 'Negative (0.86)',
    'No remite hemocultivos.': 'No blood cultures sent.',
    'No se realiza IgG e IgM a Covid19': 'No IgG and IgM testing for Covid19 performed',
    'Positivo (1.94)': 'Positive (1.94)', 
    'Recuento manual: 78% seg, 8% cay, 8% metamielo, 3% mielocito, 3% mono. Se observan algunos eritroblastos, neutrófios vacuolados con granulación tóxica y algunos núcleos picnóticos. Serie roja con policromasia y punteado basófilo.': 'Manual count: 78% seg, 8% cay, 8% metamyelocyte, 3% myelocyte, 3% mono. Some erythroblasts observed, vacuolated neutrophils with toxic granulation and some pyknotic nuclei. Red series with polychromasia and basophilic stippling.',
    'Se observan': 'Observed',
    'Dimero realizado en la analitica XXXXXXX': 'D-dimer performed on analysis X',
    'Positivo (11.9)': 'Positive (11.9)',
    'Muestra hemolizada e insuficiente. Rogamos envíen nueva muestra.': 'Sample hemolyzed and insufficient. Please send new sample.',
    'Analítica anulada': 'Analysis canceled',
    'Sistematico de orina dentro de la normalidad': 'Systematic urine within normal limits',
    'CONGELADO EN HMS': 'Frozen in HMS',
    'Células epiteliales escamosas': 'Squamous epithelial cells',
    'Población analizada: Linfocitaria (8.5%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (61.39%)': 'Population analyzed: Lymphocytic (8.5%). The following subpopulations are identified: T lymphocytes CD3+ (61.39%)',
    'Población analizada: Linfocitaria (4.8%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (54.76%)': 'Population analyzed: Lymphocytic (4.8%). The following subpopulations are identified: T lymphocytes CD3+ (54.76%)',
    'En la serie roja se observa anisopoiquilocitosis con presencia de hipocromía y eliptociotos.': 'In the red series, anisopoikilocytosis is observed with presence of hypochromia and elliptocytes.',
    'Se observan neutrófilos con refuerzo en la granulación y desviación izquierda, de posible origen reactivo.': 'Neutrophils with granulation reinforcement and left shift observed, possibly reactive origin.',
    'Fórmula manual: Metamielocitos 1%, Cayados 9%,segmentados 88%': 'Manual formula: Metamyelocytes 1%, Bands 9%, Segmented 88%',
    'Población analizada: Linfocitaria (10.08%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (46.48%)': 'Population analyzed: Lymphocytic (10.08%). The following subpopulations are identified: T lymphocytes CD3+ (46.48%)',
    'Población analizada: Linfocitaria (10.08%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (46.48%), 93 cels/μL - Linfocitos T CD4+ (47.6%), 44 cels/μL - Linfocitos T CD8+ (48.8%), 45 cels/μL Linfocitos B CD19+ CD20+ (16.2%), 32 cels/μL Linfocitos NK T CD3+ CD56+ (6%), 12 cels/μL Células NK CD3- CD56+ (26.62%), 53 cels/μL': 'Population analyzed: Lymphocytic (10.08%). The following subpopulations are identified: T lymphocytes CD3+ (46.48%), 93 cells/μL - T lymphocytes CD4+ (47.6%), 44 cells/μL - T lymphocytes CD8+ (48.8%), 45 cells/μL B lymphocytes CD19+ CD20+ (16.2%), 32 cells/μL NK T cells CD3+ CD56+ (6%), 12 cells/μL NK cells CD3- CD56+ (26.62%), 53 cells/μL',
    'Fórmula manual: segmentados 92%': 'Manual formula: Segmented 92%',
    'Se observa desviación izquierda, neutrófilos con refuerzo en la granulación. Serie roja con anisocromía.': 'Left shift observed, neutrophils with granulation reinforcement. Red series with anisochromia.',
    'Procesado en petición XXXXXXX': 'Processed on request X',
    'Población analizada: Linfocitaria (3.57%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (42.86%)': 'Population analyzed: Lymphocytic (3.57%). The following subpopulations are identified: T lymphocytes CD3+ (42.86%)',
    'Se observa desviación izquierda': 'Left shift observed',
    'Fórmula manual: segmentados 70%': 'Manual formula: Segmented 70%',
    'CONTROL PORTADOR E.COLI BLEE': 'CONTROL CARRIER E.COLI BLEE', 
    'Población analizada: Linfocitaria (3.57%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (42.86%), 120 cels/μL - Linfocitos T CD4+ (49.46%), 59 cels/μL - Linfocitos T CD8+ (47.88%), 57 cels/μL Linfocitos B CD19+ CD20+ (22.98%), 64 cels/μL Linfocitos NK T CD3+ CD56+ (3.9%), 11 cels/μL Células NK CD3- CD56+ (23.7%), 66 cels/μL': 'Population analyzed: Lymphocytic (3.57%). The following subpopulations are identified: T lymphocytes CD3+ (42.86%), 120 cells/μL - T lymphocytes CD4+ (49.46%), 59 cells/μL - T lymphocytes CD8+ (47.88%), 57 cells/μL B lymphocytes CD19+ CD20+ (22.98%), 64 cells/μL NK T cells CD3+ CD56+ (3.9%), 11 cells/μL NK cells CD3- CD56+ (23.7%), 66 cells/μL',
    'Muestra insuficiente, determinación realizada en número XXXXXXX': 'Insufficient sample, determination made on number X',
    'Recuento manual: 815 seg, 1% eos, 13% linfo, 5% mono. Se observan hipersegmentación nuclear y refuerzo de la granulación en neutrófilos. Resto de series sin alteraciones.': 'Manual count: 815 seg, 1% eos, 13% linfo, 5% mono. Nuclear hypersegmentation and granulation reinforcement observed in neutrophils. Rest of series without alterations.',
    'Población analizada: Linfocitaria (5.56%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (50.26%)': 'Population analyzed: Lymphocytic (5.56%). The following subpopulations are identified: T lymphocytes CD3+ (50.26%)',
    'Recuento manual: 73% seg, 20% cay, 2% eos, 1% linfo, 4% mono. Se visualizan neutrófilos vacuolados algunos con figuras apoptóticas. Serie roja con marcada hipocromía, tendencia a rouleax de los hematíes.': 'Manual count: 73% seg, 20% cay, 2% eos, 1% linfo, 4% mono. Vacuolated neutrophils observed, some with apoptotic figures. Red series with marked hypochromia, tendency to rouleaux of erythrocytes.',
    'Población analizada: Linfocitaria (5.56%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (50.26%), 115 cels/μL - Linfocitos T CD4+ (53.44%), 62 cels/μL - Linfocitos T CD8+ (43.79%), 50 cels/μL Linfocitos B CD19+ CD20+ (17.9%), 41 cels/μL Linfocitos NK T CD3+ CD56+ (4.1%), 9 cels/μL Células NK CD3- CD56+ (21.2%), 49 cels/μL': 'Population analyzed: Lymphocytic (5.56%). The following subpopulations are identified: T lymphocytes CD3+ (50.26%), 115 cells/μL - T lymphocytes CD4+ (53.44%), 62 cells/μL - T lymphocytes CD8+ (43.79%), 50 cells/μL B lymphocytes CD19+ CD20+ (17.9%), 41 cells/μL NK T cells CD3+ CD56+ (4.1%), 9 cells/μL NK cells CD3- CD56+ (21.2%), 49 cells/μL',
    'NO REMITE MUESTRA DE BAS': 'DOES NOT SEND BAS SAMPLE',
    'Serie roja con hipocromía leve y tendencia a rouleaux. Se observan algunos queratocitos yneutrófilos con refuerzo de la granulación. . Trombopenia comprobada.': 'Red series with mild hypochromia and tendency to rouleaux. Some keratocytes and neutrophils with granulation reinforcement observed. Confirmed thrombocytopenia.',
    'Procesado en XXXXXXX': 'Processed at X',
    'Recuento manual: 77% seg, 1% eos, 1% cay, 16% linfo, 55 mono. Hipersegmentación nuclear de los neutrófilos.': 'Manual count: 77% seg, 1% eos, 1% cay, 16% linfo, 55 mono. Nuclear hypersegmentation of neutrophils.',
    'Población analizada: Linfocitaria (10.85%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (49.92%)': 'Population analyzed: Lymphocytic (10.85%). The following subpopulations are identified: T lymphocytes CD3+ (49.92%)',
    'Se observan linfocitos de aspecto estimulado. Serie roja con moderada hipocromía': 'Lymphocytes with stimulated appearance observed. Red series with moderate hypochromia',
    'Se observan linfocitos de aspecto estimulado. Serie roja con moderada hipocromía, algunos hematíes policrom ticos. Frecuentes eliptocitos.': 'Lymphocytes with stimulated appearance observed. Red series with moderate hypochromia, some polychromatic erythrocytes. Frequent elliptocytes.',
    'Población analizada: Linfocitaria (10.85%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (49.92%), 524 cels/μL - Linfocitos T CD4+ (54.99%), 288 cels/μL - Linfocitos T CD8+ (41.1%), 215 cels/μL Linfocitos B CD19+ CD20+ (35.43%), 372 cels/μL Linfocitos NK T CD3+ CD56+ (2.33%), 24 cels/μL Células NK CD3- CD56+ (8.96%), 94 cels/μL': 'Population analyzed: Lymphocytic (10.85%). The following subpopulations are identified: T lymphocytes CD3+ (49.92%), 524 cells/μL - T lymphocytes CD4+ (54.99%), 288 cells/μL - T lymphocytes CD8+ (41.1%), 215 cells/μL B lymphocytes CD19+ CD20+ (35.43%), 372 cells/μL NK T cells CD3+ CD56+ (2.33%), 24 cells/μL NK cells CD3- CD56+ (8.96%), 94 cells/μL',
    '- Coronavirus SARS-CoV2: INDETERMINADO (se recomienda repetir determinación) - Influenza A: No se detecta - Influenza B: No se detecta - Influenza H1N1: No se detecta - Coronavirus (Cor 229': '- Coronavirus SARS-CoV2: INDETERMINATE (retest recommended) - Influenza A: Not detected - Influenza B: Not detected - Influenza H1N1: Not detected - Coronavirus (Cor 229',
    'Frotis revisado por Hematólogo. Anisocitosis en serie roja. No observo agregados de plaquetas.': 'Smear reviewed by Hematologist. Anisocytosis in red series. No platelet aggregates observed.',
    'Muestra coagulada': 'Clotted sample', 
    'Recuento manual: 84% seg, 25 cay, 2%mono, 7% cay, 5% mono. Neutrófilos con refuerzo de la granulación y vacuolización citoplasm tica. Serie roja no valorable por artefactos (abundantes equinocitos). Trombopenia comprobada.': 'Manual count: 84% seg, 25 cay, 2% mono, 7% cay, 5% mono. Neutrophils with granulation reinforcement and cytoplasmic vacuolization. Red series not evaluable due to artifacts (abundant echinocytes). Confirmed thrombocytopenia.',
    'Recuento manual: 43% seg, 7% cay, 11% mielocitos, 18% metamielocitos, 8% lindo, 13% mono. Se observa desviación izquierda, neutrófilos con refuerzo de la granulación. Satelitismo plaquetario.': 'Manual count: 43% seg, 7% cay, 11% myelocytes, 18% metamyelocytes, 8% lindo, 13% mono. Left shift observed, neutrophils with granulation reinforcement. Platelet satellitism.',
    'Recuento manual: 69% seg, 1% eos, 14% linfo, 6% Mono, 7% Cay, 8% Metamielo. Hipocromía moderada. Presencia de ovalocitos. Trombopenia comprobada. Desviación izquierda.': 'Manual count: 69% seg, 1% eos, 14% linfo, 6% mono, 7% cay, 8% metamielo. Moderate hypochromia. Presence of ovalocytes. Confirmed thrombocytopenia. Left shift.',
    'Se observan neutrófilos vacuolados. Serie roja con marcada hipocromía y rouleaux. Presencia de ovalocitos': 'Neutrophils with vacuolation observed. Red series with marked hypochromia and rouleaux. Presence of ovalocytes.',
    'Se observan neutrófilos vacuolados. Serie roja con marcada hipocromía y rouleaux. Presencia de ovalocitos, eliptocitos, algún equinocito.': 'Neutrophils with vacuolation observed. Red series with marked hypochromia and rouleaux. Presence of ovalocytes, elliptocytes, some echinocytes.',
    'Se observan neutrófilos con refuerzo en la granulación. Trombopenia comprobada.': 'Neutrophils observed with reinforcement in granulation. Confirmed thrombocytopenia.',
    'Serie roja con anisocitosis y policromasia, se observan frecuentes ovalocitos. Desviación izquierda. Neutrófilos con presencia de granulación tóxica e hipersegmentación nuclear. Se observan agregados plaquetarios.': 'Red series with anisocytosis and polychromasia, frequent ovalocytes observed. Left shift. Neutrophils with presence of toxic granulation and nuclear hypersegmentation. Platelet aggregates observed.',
    'Neutrófilos vacuolados con refuerzo de la granulación. Anisocitosis y anisocromía con hipocromía. Tendencia a rouleaux en hematíes.': 'Neutrophils vacuolated with reinforcement of granulation. Anisocytosis and anisochromia with hypochromia. Tendency to rouleaux in erythrocytes.',
    'Fórmula comprobada. Discreta desviación izquierda. Granulación tóxica y vacuolización en neutrófilos. Anisocromía. Trombopenia comprobada.': 'Confirmed formula. Slight left shift. Toxic granulation and vacuolization in neutrophils. Anisochromia. Confirmed thrombocytopenia.',
    'Recuento manual: 78% seg, 18% cay, 3% linfo, 1% mono. Neutrófilos vacuolados con granulación tóxica.': 'Manual count: 78% seg, 18% cay, 3% linfo, 1% mono. Neutrophils vacuolated with toxic granulation.',
    'Procesado en liquido ascítico': 'Processed in ascitic fluid',
    '40 mg/dl': '40 mg/dL',
    'Se observan neutrófilos con refuerzo en la granulación y algúnos linfocitos de aspecto activado.': 'Neutrophils observed with reinforcement in granulation and some lymphocytes with activated appearance.',
    'Determinación enviada en N§ 620015384': 'Determination sent in Nº X', 
    'Recuento manua: 42% seg, 9% cay, 8% eos, 31% linfo, 10% mono. Hipocromía moderada. Refuerzo de la granulación neutrofílica.': 'Manual count: 42% seg, 9% cay, 8% eos, 31% linfo, 10% mono. Moderate hypochromia. Neutrophilic granulation reinforcement.',
    'Población analizada: Linfocitaria (5.5%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (67%), 328 cels/μL - Linfocitos T CD4+ (48.7%), 160 cels/μL - Linfocitos T CD8+ (48.7%), 160 cels/μL Linfocitos B CD19+ CD20+ (8.05%), 39 cels/μL Linfocitos NK T CD3+ CD56+ (13.1%), 64 cels/μL Células NK CD3- CD56+ (8.7%), 42 cels/μL': 'Population analyzed: Lymphocytic (5.5%). The following subpopulations are identified: T lymphocytes CD3+ (67%), 328 cells/μL - T lymphocytes CD4+ (48.7%), 160 cells/μL - T lymphocytes CD8+ (48.7%), 160 cells/μL B lymphocytes CD19+ CD20+ (8.05%), 39 cells/μL NK T cells CD3+ CD56+ (13.1%), 64 cells/μL NK cells CD3- CD56+ (8.7%), 42 cells/μL',
    'Población analizada: Linfocitaria (5.5%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (67%)': 'Population analyzed: Lymphocytic (5.5%). The following subpopulations are identified: T lymphocytes CD3+ (67%)',
    'No es posible obtener m s resultados. Se ruega envíen nueva muestra': 'Unable to obtain more results. Please send a new sample.',
    'Recuento manual: 41% seg, 39% linfo, 20% mono. Se visualizan neutrófilos vacuolados y linfocitos de aspecto activado. En ausencia de causa reactiva, se recomienda seguimiento hematológico.': 'Manual count: 41% seg, 39% linfo, 20% mono. Vacuolated neutrophils and activated lymphocytes observed. In the absence of reactive cause, hematological follow-up is recommended.',
    'AB Positivo': 'AB Positive',
    'Doble población eritrocitaria, una de ellas microcitica e hipocroma.': 'Double erythrocyte population, one of them microcytic and hypochromic.',
    'En la serie roja se observa anisopoiquilocitosis con microcitosis e hipocromía.': 'Red series shows anisopoikilocytosis with microcytosis and hypochromia.',
    'Serie roja con rouleaux e hipocromía. Frecuentes ovalocitos. Fórmula comprobada': 'Red series with rouleaux and hypochromia. Frequent ovalocytes. Confirmed formula.',
    'Serie roja con rouleaux e hipocromía. Frecuentes ovalocitos. Fórmula comprobada, no se observan blastos. Neutrófilos con refuerzo de la granulación y cariorrexis nuclear.': 'Red series with rouleaux and hypochromia. Frequent ovalocytes. Confirmed formula, no blasts observed. Neutrophils with granulation reinforcement and nuclear caryorrhexis.',
    'BASAL': 'BASAL',
    'Discreta microcitosis, sin otras alteraciones morfológicas destacables.': 'Mild microcytosis, without other notable morphological alterations.',
    'Presencia de anticuerpos inespecíficos que impiden la determinación de chlamydia pneumonie IgM por IFI': 'Presence of nonspecific antibodies that prevent the determination of chlamydia pneumoniae IgM by IFI',
    'Muestra hemolizada. Se recomienda enviar nueva muestra para comprobar resultados Resultado comprobado valorar extracción': 'Hemolyzed sample. It is recommended to send a new sample to verify results. Confirmed result, consider re-extraction.',
    'Se visualizan neutrófilos vacuolados y varios linfocitos activados.': 'Vacuolated neutrophils and several activated lymphocytes observed.',
    'Muestra mal enrasada. Se recomienda enviar nueva muestra para comprobar resultados': 'Misaligned sample. It is recommended to send a new sample to verify results.',
    'suero muy hemolizado, valorar resultados o enviar nueva muestra': 'serum very hemolyzed, evaluate results or send new sample',
    r'No se detecta ADN de HHV6.\X0A\Límite de detección: 2 copias/μL': r'HHV6 DNA not detected.\X0A\Detection limit: 2 copies/μL',
    'Muestra hemolizada NECESITAMOS NUEVA MUESTRA PARA COMPROBAR RESULTADOS': 'Hemolyzed sample. WE NEED A NEW SAMPLE TO VERIFY RESULTS.',
    'Catéter Shaldom': 'Shaldom catheter',
    'Estudio morfológico sin alteraciones rese¤ables en las tres series.': 'Morphological study without notable alterations in the three series.',
    'NO REMITE MUESTRA DE SUERO PARA REALIZAR UREA Y CREATININA.': 'DOES NOT SEND SERUM SAMPLE FOR UREA AND CREATININE DETERMINATION.',
    'enviado a salud pública': 'sent to public health',
    'Leucocitosis con desviación izquierda. Presencia de linfocitos heterogéneos de aspecto estimulado. Serie roja no valorable por artefacto en la muestra.': 'Leukocytosis with left shift. Presence of heterogeneous lymphocytes with stimulated appearance. Red series not assessable due to artifact in the sample.',
    'Se recomienda nueva extracción para comprobar resultados, muestra de via': 'A new extraction is recommended to verify results, sample de via',
    'Neutrófilos hipersegmentados con refuerzo de la granulación. Desviación izquierda. Trombopenia comprobada, sin agregados plaquetarios.': 'Neutrophils hypersegmented with granulation reinforcement. Left shift. Confirmed thrombocytopenia, without platelet aggregates.',
    'La muestra no coagula': 'The sample does not clot',
    'No coagula. Hablado con Hematología.': 'Does not clot. Spoken with Hematology.',
    'Neutrófilos vacuolados. Linfocitos de aspecto estimulado y algún linfocito grande granular.': 'Vacuolated neutrophils. Lymphocytes with stimulated appearance and some large granular lymphocyte.',
    'Muestra hemolizada SE RECOMIENDA NUEVA EXTRACCIÓN': 'Hemolyzed sample NEW EXTRACTION RECOMMENDED',
    'Se observan neutrófilos vacuolados y refuerfo de la granulación. Desviación izquierda.': 'Vacuolated neutrophils and granulation reinforcement observed. Left shift.',
    'Fórmula manual: Metamielocitos 5%, Cayados 9%, segmentados 84%': 'Manual formula: Metamyelocytes 5%, Stabs 9%, segmented 84%',
    'Síndrome leucoeritrobl stico, a correlacionar con la clínica de la paciente.': 'Leukoerythroblastic syndrome, to be correlated with patient\'s clinical presentation.',
    'Anisocromía con hipocromía, anisocitosis. Resto de series sin alteraciones.': 'Anisocytosis with hypochromia, anisocytosis. Rest of series without alterations.',
    'Anisocromía con marcada hipocromía. Anisocitosis. Macrocitos con punteado basófilo. Algún dacriocito.': 'Anisocytosis with marked hypochromia. Anisocytosis. Macrocytes with basophilic stippling. Some dacryocytes.',
    'Hipocromía,algunos eliptocitos. Desviación izquierda. Se visualizan neutrófilos vacuolados, algunos linfocitos activados y agregados plaquetarios.': 'Hypochromia, some elliptocytes. Left shift. Vacuolated neutrophils, some activated lymphocytes, and platelet aggregates observed.',
    'Se observa desviación izquierda a expensas de segmentados y cayados. Neutrófilos con granulacion tóxica e hipersegmentación nuclear.': 'Left shift observed at the expense of segmented and stabs. Neutrophils with toxic granulation and nuclear hypersegmentation.',
    'Recuento manual: 36% seg, 5% cay, 35 baso, 42% linfo, 11% mono, 2% baso. Neutrófilos vacuolados y desprovistos de granulación. Se observan linfocitos de aspecto estimulados algunos con núcleos picnóticos y 3% de células de con relación núcleo citoplasm tica alta, de cromatina laxa con algún nucleolo visible de aspecto inmaduro. Se observan varios eritroblastos.': 'Manual count: 36% seg, 5% cay, 35 baso, 42% linfo, 11% mono, 2% baso. Vacuolated neutrophils devoid of granulation. Stimulated lymphocytes observed, some with picnotic nuclei and 3% of cells with high nucleocytoplasmic ratio, loose chromatin with some visible nucleolus of immature appearance. Several erythroblasts observed.',
    'Recuento manual: 60% seg, 2% cay, blastos 7%, 4% eos, 19% linfo, 5% LGG 1% baso. Se observan células de peque¤o tama¤o de escaso citoplasma basófilo y coromatina fina en la que se visualizan 1-2 nucléolos, sugestivas de blastos.': 'Manual count: 60% seg, 2% cay, blasts 7%, 4% eos, 19% linfo, 5% LGG 1% baso. Small-sized cells with scarce basophilic cytoplasm and fine chromatin in which 1-2 nucleoli are visualized, suggestive of blasts.',
    'Recuento manual: 84% seg, 6% cay, 8% linfo, 2% mono. Neutrófilos vacuolados con refuerzo de la granulación neutrofílica. Presencia de linfocitos activados.': 'Manual count: 84% seg, 6% cay, 8% linfo, 2% mono. Vacuolated neutrophils with neutrophilic granulation reinforcement. Presence of activated lymphocytes.',
    'Población analizada: Linfocitaria (9.5%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (79.87%)': 'Analyzed population: Lymphocytic (9.5%). The following subpopulations are identified: T lymphocytes CD3+ (79.87%)',
    'No remite muestra GASOMETRÍA REALIZADA CON NUMERO XXXXXXX': 'No sends sample GASOMETRY PERFORMED WITH NUMBER X',
    'post-filtro': 'post-filter',
    'Se observan neutrófilos vacuolados con refuerzo de la granulación. Presencia de linfocitos activados.': 'Vacuolated neutrophils observed with granulation reinforcement. Presence of activated lymphocytes.',
    'Recuento manual: 91% seg, 4% cay, 3% metamielo, 2% linfo. Desviación izquierda. Neutrófilos con granulación tóxica y vacuolización citoplasm tica.': 'Manual count: 91% seg, 4% cay, 3% metamyelocytes, 2% linfo. Left shift. Neutrophils with toxic granulation and cytoplasmic vacuolization.',
    'Leucocitosis con desviación izquierda, neutrófilos vacuolados y con granulación tóxica. Se observan también linfocitos de aspecto estimulados.': 'Leukocytosis with left shift, vacuolated neutrophils with toxic granulation. Also observed are lymphocytes with stimulated appearance.',
    'Población analizada: Linfocitaria (9.5%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (79.87%), 902 cels/μL - Linfocitos T CD4+ (73.47%), 663cels/μL - Linfocitos T CD8+ (21.81%), 197 cels/μL Linfocitos B CD19+ CD20+ (6.96%), 79 cels/μL Linfocitos NK T CD3+ CD56+ (3.12%), 35 cels/μL Células NK CD3- CD56+low (8.84%), 100 cels/μL': 'Population analyzed: Lymphocytic (9.5%). The following subpopulations are identified: T lymphocytes CD3+ (79.87%), 902 cells/μL - T lymphocytes CD4+ (73.47%), 663 cells/μL - T lymphocytes CD8+ (21.81%), 197 cells/μL B lymphocytes CD19+ CD20+ (6.96%), 79 cells/μL NK T cells CD3+ CD56+ (3.12%), 35 cells/μL NK cells CD3- CD56+low (8.84%), 100 cells/μL',
    'Resultado comprobado Valorar extraccion': 'Result checked Consider extraction',
    'Recuento manual: 77% seg, 2% cay, 19% linfo, 2% mono. Neutrófilos con refuerzo de la granulación e hipersegmentación nuclear.': 'Manual count: 77% seg, 2% cay, 19% linfo, 2% mono. Neutrophils with granulation reinforcement and nuclear hypersegmentation.',
    'Población analizada: Linfocitaria (6.6%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (71.23%)': 'Population analyzed: Lymphocytic (6.6%). The following subpopulations are identified: T lymphocytes CD3+ (71.23%)',
    'Población analizada: Linfocitaria (6.6%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (71.23%), 655 cels/μL - Linfocitos T CD4+ (71.89%), 471cels/μL - Linfocitos T CD8+ (21.34%), 140 cels/μL Linfocitos B CD19+ CD20+ (8.86%), 82 cels/μL Linfocitos NK T CD3+ CD56+ (2.88%), 26 cels/μL Células NK CD3- CD56+low (14.43%), 133 cels/μL': 'Population analyzed: Lymphocytic (6.6%). The following subpopulations are identified: T lymphocytes CD3+ (71.23%), 655 cells/μL - T lymphocytes CD4+ (71.89%), 471 cells/μL - T lymphocytes CD8+ (21.34%), 140 cells/μL B lymphocytes CD19+ CD20+ (8.86%), 82 cells/μL NK T cells CD3+ CD56+ (2.88%), 26 cells/μL NK cells CD3- CD56+low (14.43%), 133 cells/μL',
    'Población analizada: Linfocitaria (8.28%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (59.46%)': 'Population analyzed: Lymphocytic (8.28%). The following subpopulations are identified: T lymphocytes CD3+ (59.46%)',
    'Población analizada: Linfocitaria (8.28%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (59.46%), 470 cels/μL - Linfocitos T CD4+ (59.99%), 282 cels/μL - Linfocitos T CD8+ (31.82%), 150 cels/μL Linfocitos B CD19+ CD20+ (5.49%), 43 cels/μL Linfocitos NK T CD3+ CD56+ (3.16%), 25 cels/μL Células NK CD3- CD56+low (28.93%), 229 cels/μL': 'Population analyzed: Lymphocytic (8.28%). The following subpopulations are identified: T lymphocytes CD3+ (59.46%), 470 cells/μL - T lymphocytes CD4+ (59.99%), 282 cells/μL - T lymphocytes CD8+ (31.82%), 150 cells/μL B lymphocytes CD19+ CD20+ (5.49%), 43 cells/μL NK T cells CD3+ CD56+ (3.16%), 25 cells/μL NK cells CD3- CD56+low (28.93%), 229 cells/μL',
    'Población analizada: Linfocitaria (17.7%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (81.03%)': 'Population analyzed: Lymphocytic (17.7%). The following subpopulations are identified: T lymphocytes CD3+ (81.03%)',
    'Población analizada: Linfocitaria (4.8%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (54.76%), 191 cels/μL - Linfocitos T CD4+ (52.07%), 100 cels/μL - Linfocitos T CD8+ (44.67%), 85 cels/μL Linfocitos B CD19+ CD20+ (11.8%), 41 cels/μL Linfocitos NK T CD3+ CD56+ (5.29%), 18 cels/μL Células NK CD3- CD56+ (22.84%), 80 cels/μL': 'Population analyzed: Lymphocytic (4.8%). The following subpopulations are identified: T lymphocytes CD3+ (54.76%), 191 cells/μL - T lymphocytes CD4+ (52.07%), 100 cells/μL - T lymphocytes CD8+ (44.67%), 85 cells/μL B lymphocytes CD19+ CD20+ (11.8%), 41 cells/μL NK T cells CD3+ CD56+ (5.29%), 18 cells/μL NK cells CD3- CD56+ (22.84%), 80 cells/μL',
    'Población analizada: Linfocitaria (12.4%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (75.40%)': 'Population analyzed: Lymphocytic (12.4%). The following subpopulations are identified: T lymphocytes CD3+ (75.40%)',
    'Se observan neutrófilos vacuolados con refuerzo en la granulación. Hipocromía': 'Vacuolated neutrophils observed with reinforcement in granulation. Hypochromia',
    r'Recuento manual: 52% seg, 2% mielo, 7% metamielo, 9% cay, 19% linfo, 1% eos, 10% mono. \X0A\Se observa anisopoiquilocitosis con policromasia, punteado basófilo. Presencia de eritroblastos, acantocitos, algún hematíe sen l grima. \X0A\Se observan signos de dismielopoyesis (neutrófilos con núcelo hiposegmentado y en anillo). Linfocitos activados.': r'Manual count: 52% seg, 2% myelocytes, 7% metamyelocytes, 9% cay, 19% linfo, 1% eos, 10% mono. \X0A\Anisopoikilocytosis observed with polychromasia, basophilic stippling. Presence of erythroblasts, acanthocytes, some teardrop-shaped red blood cells. \X0A\Signs of dysmyelopoiesis observed (neutrophils with hyposegmented and ring nuclei). Activated lymphocytes.',
    'Serie roja con hipocromía': 'Red blood cells with hypochromia',
    'Serie roja con hipocromía, tendencia a rouleaux. Punteado basófilo. Frecuentes ovalocitos.': 'Red blood cells with hypochromia, tendency to rouleaux. Basophilic stippling. Frequent ovalocytes.',
    'Se observa anisopoiquilocitosis con presencia de ovalocitos, equinocitos y eliptocitos. Desviación izquierda.': 'Anisopoikilocytosis observed with presence of ovalocytes, echinocytes, and elliptocytes. Left shift.',
    'Recuento manual: 67% seg, 5% cay, 18% linfo, 8% mono, 2% eos. Se visualizan linfocitos de aspecto activado y refuerzo de la granulación neutrofílica. Resto de serie sin alteraciones.': 'Manual count: 67% seg, 5% cay, 18% linfo, 8% mono, 2% eos. Activated lymphocytes and reinforcement of neutrophilic granulation observed. Rest of the series without alterations.',
    'Recuento maual: 63% seg, 14% cay, 13% linfo, 10% mono. Hipocromía leve. Resto de serie sin alteraciones.': 'Manual count: 63% seg, 14% cay, 13% linfo, 10% mono. Mild hypochromia. Rest of the series without alterations.',
    'Se observa desviación izquierda y neutrófilos con granulación tóxica. Algunos linfocitos activados.': 'Left shift observed with neutrophils showing toxic granulation. Some activated lymphocytes.',
    'Población analizada: Linfocitaria (27.8%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (77.86%)': 'Population analyzed: Lymphocytic (27.8%). The following subpopulations are identified: T lymphocytes CD3+ (77.86%)',
    'Debido a la imagen electroforética se recomienda realizar nueva extracción para estudio de inmunofijación en suero. Componente monoclonal estimado: 0.2 g/dL (4,6%)': 'Due to the electrophoretic image, it is recommended to perform a new extraction for serum immunofixation study. Estimated monoclonal component: 0.2 g/dL (4.6%)',
    'Población analizada: Linfocitaria (27.8%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (77.86%), 1144 cels/μL - Linfocitos T CD4+ (69.73%), 798 cels/μL - Linfocitos T CD8+ (28.56%), 326 cels/μL Linfocitos B CD19+ CD20+ (5.91%), 87 cels/μL Linfocitos NK T CD3+ CD56+ (1.35%), 20 cels/μL Células NK CD3- CD56+low (13.98%), 205 cels/μL': 'Population analyzed: Lymphocytic (27.8%). The following subpopulations are identified: T lymphocytes CD3+ (77.86%), 1144 cells/μL - T lymphocytes CD4+ (69.73%), 798 cells/μL - T lymphocytes CD8+ (28.56%), 326 cells/μL B lymphocytes CD19+ CD20+ (5.91%), 87 cells/μL NK T cells CD3+ CD56+ (1.35%), 20 cells/μL NK cells CD3- CD56+low (13.98%), 205 cells/μL',
    'Población analizada: Linfocitaria (22.43%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (76.07%)': 'Population analyzed: Lymphocytic (22.43%). The following subpopulations are identified: T lymphocytes CD3+ (76.07%)',
    'Población analizada: Linfocitaria (28.1%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (74.37%)': 'Population analyzed: Lymphocytic (28.1%). The following subpopulations are identified: T lymphocytes CD3+ (74.37%)',
    'Población analizada: Linfocitaria (28.1%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (74.37%), 885 cels/μL - Linfocitos T CD4+ (68.98%), 610 cels/μL - Linfocitos T CD8+ (29.51%), 261 cels/μL Linfocitos B CD19+ CD20+ (6.73%), 80 cels/μL Linfocitos NK T CD3+ CD56+ (3.19%), 38 cels/μL Células NK CD3- CD56+low (14.31%), 170 cels/μL': 'Population analyzed: Lymphocytic (28.1%). The following subpopulations are identified: T lymphocytes CD3+ (74.37%), 885 cells/μL - T lymphocytes CD4+ (68.98%), 610 cells/μL - T lymphocytes CD8+ (29.51%), 261 cells/μL B lymphocytes CD19+ CD20+ (6.73%), 80 cells/μL NK T cells CD3+ CD56+ (3.19%), 38 cells/μL NK cells CD3- CD56+low (14.31%), 170 cells/μL',
    'Población analizada: Linfocitaria (28.2%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (76.29%), 1205 cels/μL - Linfocitos T CD4+ (64.66%), 779 cels/μL - Linfocitos T CD8+ (33.43%), 403 cels/μL Linfocitos B CD19+ CD20+ (4.82%), 76 cels/μL Linfocitos NK T CD3+ CD56+ (2.17%), 34 cels/μL Células NK CD3- CD56+low (15.52%), 245 cels/μL': 'Population analyzed: Lymphocytic (28.2%). The following subpopulations are identified: T lymphocytes CD3+ (76.29%), 1205 cells/μL - T lymphocytes CD4+ (64.66%), 779 cells/μL - T lymphocytes CD8+ (33.43%), 403 cells/μL B lymphocytes CD19+ CD20+ (4.82%), 76 cells/μL NK T cells CD3+ CD56+ (2.17%), 34 cells/μL NK cells CD3- CD56+low (15.52%), 245 cells/μL',
    'Población analizada: Linfocitaria (22.43%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (76.07%), 1194 cels/μL - Linfocitos T CD4+ (39.16%), 467 cels/μL - Linfocitos T CD8+ (58.9%), 703 cels/μL Linfocitos B CD19+ CD20+ (9.2%), 144 cels/μL Linfocitos NK T CD3+ CD56+ (3.4%), 53 cels/μL Células NK CD3- CD56+ (7.63%), 120 cels/μL': 'Population analyzed: Lymphocytic (22.43%). The following subpopulations are identified: T lymphocytes CD3+ (76.07%), 1194 cells/μL - T lymphocytes CD4+ (39.16%), 467 cells/μL - T lymphocytes CD8+ (58.9%), 703 cells/μL B lymphocytes CD19+ CD20+ (9.2%), 144 cells/μL NK T cells CD3+ CD56+ (3.4%), 53 cells/μL NK cells CD3- CD56+ (7.63%), 120 cells/μL',   
    'Debido a la imagen electroforética se recomienda realizar nueva extracción para estudio de inmunofijación en suero. Componente monoclonal estimado: 0.2 g/dL (4': 'Due to the electrophoretic image, it is recommended to perform a new extraction for serum immunofixation study. Estimated monoclonal component: 0.2 g/dL (4',
    'Fórmula manual: neutrófilos 90%, linfocitos 8%, monocitos 2%. Serie granulocítica con desviación izquierda y formas inmaduras (cayados, metamielocitos, mielocitos). 12 eritroblastos por cada 100 leucocitos. Anisocitosis marcada en serie roja, ocasionales acantocitos y variantes. Frotis de aspecto reactivo a proceso agudo inflamatorio o infeccioso (paciente crítico).': 'Manual formula: neutrophils 90%, lymphocytes 8%, monocytes 2%. Granulocytic series with left shift and immature forms (band forms, metamyelocytes, myelocytes). 12 erythroblasts per 100 leukocytes. Marked anisocytosis in red series, occasional acanthocytes and variants. Smear reactive to acute inflammatory or infectious process (critical patient).',
    'Población analizada: Linfocitaria (5.93%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (49.56%)': 'Population analyzed: Lymphocytic (5.93%). The following subpopulations are identified: T lymphocytes CD3+ (49.56%)',
    'Con mascarilla reservorio': 'With reservoir mask',
    'Recuento manual: 62% seg, 7% cay, 1% metamielo, 1% mielo, 3% mono, 12% linfo. Se observan desviación izquierda y neutrófilos con refuerzo de la granulación. Llama la atención una célula con relación núcleo citoplasma elevada, de cromatina fina, sugestiva de célula inmadura.': 'Manual count: 62% seg, 7% cay, 1% metamyelocytes, 1% myelocytes, 3% mono, 12% linfo. Left shift observed with neutrophils showing reinforcement of granulation. A cell with high nucleus to cytoplasm ratio, fine chromatin, suggestive of immature cell draws attention.',
    r'Muestra hemolizada \X0A\CA++ SACADO DE GASOMETRIA DEL DIA XX.XX XXXXXXX': r'Hemolyzed sample \X0A\CA++ TAKEN FROM GASOMETRY X',
    'Hipocromía con presencia de dianocitos. Recuento manual: 72% seg, 95 cay, 13% linfo, 6% mono.': 'Hypochromia with presence of dianocytes. Manual count: 72% seg, 95 cay, 13% linfo, 6% mono.',
    'No se puede determinar el valor de APTT': 'APTT value cannot be determined',
    'No se puede determinar el valor de APTT, envíen nueva muestra': 'APTT value cannot be determined, send new sample',
    'HORA PARTO 07:45': 'BIRTH TIME 07:45',
    'Desviación izquierda. Se visualizan neutrófilos vacuolados con granulación tóxica. Neutropenia comprobada.': 'Left shift. Vacuolated neutrophils with toxic granulation observed. Confirmed neutropenia.',
    'Mu¤eca derecha': 'Right wrist',
    'Leucocitosis con desviación izquierda. Neutrófilos hipersegmentados con presencia de granulación tóxica.': 'Leukocytosis with left shift. Neutrophils with hypersegmentation and presence of toxic granulation.',
    'Recuento manual: 40% seg, 22% cay, 7% metamielocitos, 6% mielocitos, 4% mono, 21% linfo. Se observa desviación izquierda y refuerzo de la granulación neutrofílica.': 'Manual count: 40% seg, 22% cay, 7% metamyelocytes, 6% myelocytes, 4% mono, 21% linfo. Left shift and reinforcement of neutrophilic granulation observed.',
    'Se observan 40 % de células de aspecto bl stico (células de mediano tamaño con núcleo irregular, plegado y algunos de aspecto monocitoide con citoplasma amplio y desprovistos de granulación, cromatina laxa visualizándose hasta 3 nucleolos). Hallazgos compatibles con leucemia aguda.': '40% of blast-like cells observed (medium-sized cells with irregular, folded nuclei, some with monocytoid appearance, abundant cytoplasm devoid of granulation, loose chromatin with up to 3 nucleoli visible). Findings consistent with acute leukemia.',
    'HERIDA PIE DERECHO': 'RIGHT FOOT WOUND',
    'No se detecta (título inferior a 1:4)': 'Not detected (titer less than 1:4)',
    'Fórmula manual: neutrófilos 90%': 'Manual formula: neutrophils 90%',
    'Población analizada: Linfocitaria (5.93%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (49.56%), 411 cels/μL - Linfocitos T CD4+ (53.69%), 221 cels/μL - Linfocitos T CD8+ (44.76%), 184 cels/μL Linfocitos B CD19+ CD20+ (35.55%), 295 cels/μL Linfocitos NK T CD3+ CD56+ (3.98%), 33 cels/μL Células NK CD3- CD56+ (6.11%), 51 cels/μL': 'Population analyzed: Lymphocytic (5.93%). The following subpopulations are identified: T lymphocytes CD3+ (49.56%), 411 cells/μL - T lymphocytes CD4+ (53.69%), 221 cells/μL - T lymphocytes CD8+ (44.76%), 184 cells/μL B lymphocytes CD19+ CD20+ (35.55%), 295 cells/μL NK T cells CD3+ CD56+ (3.98%), 33 cells/μL NK cells CD3- CD56+ (6.11%), 51 cells/μL',
    'Población analizada: Linfocitaria (12.3%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (63.69%), 1178 cels/μL - Linfocitos T CD4+ (57.06%), 678 cels/μL - Linfocitos T CD8+ (41.51%), 488 cels/μL Linfocitos B CD19+ CD20+ (21.54%), 398 cels/μL Linfocitos NK T CD3+ CD56+ (4.09%), 76 cels/μL Células NK CD3- CD56+ (8.81%), 163 cels/μL': 'Population analyzed: Lymphocytic (12.3%). The following subpopulations are identified: T lymphocytes CD3+ (63.69%), 1178 cells/μL - T lymphocytes CD4+ (57.06%), 678 cells/μL - T lymphocytes CD8+ (41.51%), 488 cells/μL B lymphocytes CD19+ CD20+ (21.54%), 398 cells/μL NK T cells CD3+ CD56+ (4.09%), 76 cells/μL NK cells CD3- CD56+ (8.81%), 163 cells/μL',
    'Hora de parto 03:25': 'Delivery time 03:25',
    'serie roja artefactada, sin alteraciones morfológicas especificas. Haremos control evolutivo.': 'Artifactual red series, without specific morphological alterations. Evolutionary control will be performed.',
    'Recuento manual: 12% seg, 87% linfo, 1% mono. Linfocitosis a expensas de linfocitos de aspecto estimulado y otros linfocitos de peque¤a talla con cromatina madura. Se observan aisladas manchas de gumprecht. Se recomienda ampliar inmunofenotipo y estudio hematológico.': 'Manual count: 12% seg, 87% linfo, 1% mono. Lymphocytosis due to stimulated lymphocytes and other small-sized lymphocytes with mature chromatin. Isolated Gumprecht\'s shadows observed. Further immunophenotyping and hematological study recommended.',
    'Fórmula manual: segmentados 98%; linfocitos 2%; monocitos 0%; eosinófilos 0%; basófilos 0%.': 'Manual formula: segmented 98%; lymphocytes 2%; monocytes 0%; eosinophils 0%; basophils 0%.',
    'Fórmula manual: segmentados 98%': 'Manual formula: segmented 98%',
    'Valorar realizar nueva extracción venosa para comprobar estos resultados': 'Consider performing a new venous extraction to verify these results',
    'Fórmula manual: segmentados 80%; linfocitos 13%; monocitos 3%; eosinófilos 4%; basófilos 0%.': 'Manual formula: segmented 80%; lymphocytes 13%; monocytes 3%; eosinophils 4%; basophils 0%.',
    'Fórmula manual: segmentados 80%': 'Manual formula: segmented 80%',
    'Recuento manual: 83% seg, 9% cay, 1% eos, 4% linfo, 3%mono. No se observan alteraciones morfológicas de interés.': 'Manual count: 83% seg, 9% cay, 1% eos, 4% linfo, 3% mono. No morphological alterations of interest observed.',
    'Se observa leucocitosis a expensas de segmentados con desviación izquierda. Anisocitosis en serie roja.': 'Leukocytosis due to segmented left shift. Anisocytosis in red series.',
    'CA  RELIZADO DE GASOMETRIA XXXXXXX': 'CA DONE FROM GASOMETRY X',
    'Población analizada: Linfocitaria (69%). Se detectan las siguientes subpoblaciones: - Linfocitos T CD3+ (1.25%) - Linfocitos B CD19+ (67.3%). Incluyen: - Linfocitos B clonales (100%). Presentan el siguiente fenotipo patológico: CD19+lo CD20- CD5- CD10- CD20- CD200+ CD11c- CD22- CD23-/+ (35%) CD81- FMC7- CD38- CD45+lo sIgKappa- sIgLambda-. Representan el 46.4 % de la población leucocitaria total analizada. Compatible con SLP-B, probable LLC con inmunofenotipo atípico.': 'Population analyzed: Lymphocytic (69%). The following subpopulations are detected: - T lymphocytes CD3+ (1.25%) - B lymphocytes CD19+ (67.3%). They include: - Clonal B lymphocytes (100%). They exhibit the following pathological phenotype: CD19+lo CD20- CD5- CD10- CD20- CD200+ CD11c- CD22- CD23-/+ (35%) CD81- FMC7- CD38- CD45+lo sIgKappa- sIgLambda-. They represent 46.4% of the total leukocyte population analyzed. Compatible with SLP-B, likely LLC with atypical immunophenotype.',
    'Frotis revisado por Hematólogo. Linfocitos 62%; Monocitos 1%; Neutrófilos 37%. Linfocitosis a expensas de linfocitos de peque¤o tama¤o y aspecto maduro': 'Blood smear reviewed by Hematologist. Lymphocytes 62%; Monocytes 1%; Neutrophils 37%. Lymphocytosis with small-sized and mature-looking lymphocytes.',
    'Frotis revisado por Hematólogo. Linfocitos 62%': 'Blood smear reviewed by Hematologist. Lymphocytes 62%',
    'Se observan linfocitos de aspecto estimulado, neutrófilos vacuolados con refuerzo de la granulación e hiperesegmentación nuclear. Hipocromía leve, tendencia a rouleaux en hematíes.': 'Stimulated-appearing lymphocytes observed, vacuolated neutrophils with granulation reinforcement and nuclear hypersegmentation. Mild hypochromia, tendency to rouleaux in erythrocytes.',
    'Recuento celular manual: Linfocitos 38%; Monocitos 2%; Neutrófilos 60%. Recomendamos control evolutivo.': 'Manual cell count: Lymphocytes 38%; Monocytes 2%; Neutrophils 60%. Evolutionary control recommended.',
    'Población analizada: Linfocitaria (28.2%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (76.29%)': 'Population analyzed: Lymphocytic (28.2%). The following subpopulations are identified: T lymphocytes CD3+ (76.29%)',
    'Población analizada: Linfocitaria (27.4%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (77.25%), 1244 cels/μL - Linfocitos T CD4+ (69.71%), 867 cels/μL - Linfocitos T CD8+ (28.40%), 353 cels/μL Linfocitos B CD19+ CD20+ (5.93%), 74 cels/μL Linfocitos NK T CD3+ CD56+ (2.19%), 35 cels/μL Células NK CD3- CD56+low (13.70%), 220 cels/μL': 'Population analyzed: Lymphocytic (27.4%). The following subpopulations are identified: T lymphocytes CD3+ (77.25%), 1244 cells/μL - T lymphocytes CD4+ (69.71%), 867 cells/μL - T lymphocytes CD8+ (28.40%), 353 cells/μL B lymphocytes CD19+ CD20+ (5.93%), 74 cells/μL NK T lymphocytes CD3+ CD56+ (2.19%), 35 cells/μL NK cells CD3- CD56+low (13.70%), 220 cells/μL',
    'Población analizada: Linfocitaria (26.55%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (75.67%)': 'Population analyzed: Lymphocytic (26.55%). The following subpopulations are identified: T lymphocytes CD3+ (75.67%)',
    'Población analizada: Linfocitaria (26.55%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (75.67%), 1067 cels/μL - Linfocitos T CD4+ (68.07%), 726 cels/μL - Linfocitos T CD8+ (30%), 320 cels/μL Linfocitos B CD19+ CD20+ (7.08%), 100 cels/μL Linfocitos NK T CD3+ CD56+ (2.52%), 35 cels/μL Células NK CD3- CD56+low (13.63%), 192 cels/μL': 'Population analyzed: Lymphocytic (26.55%). The following subpopulations are identified: T lymphocytes CD3+ (75.67%), 1067 cells/μL - T lymphocytes CD4+ (68.07%), 726 cells/μL - T lymphocytes CD8+ (30%), 320 cells/μL B lymphocytes CD19+ CD20+ (7.08%), 100 cells/μL NK T lymphocytes CD3+ CD56+ (2.52%), 35 cells/μL NK cells CD3- CD56+low (13.63%), 192 cells/μL',
    'Población analizada: Linfocitaria (27.4%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (77.25%)': 'Population analyzed: Lymphocytic (27.4%). The following subpopulations are identified: T lymphocytes CD3+ (77.25%)',
    'Población analizada: Linfocitaria (12.3%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (63.69%)': 'Population analyzed: Lymphocytic (12.3%). The following subpopulations are identified: T lymphocytes CD3+ (63.69%)',
    'Población analizada: Linfocitaria (30.2%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (79.09%), 1060 cels/μL - Linfocitos T CD4+ (51.78%), 549 cels/μL - Linfocitos T CD8+ (46.73%), 495 cels/μL Linfocitos B CD19+ CD20+ (13.38%), 179 cels/μL Linfocitos NK T CD3+ CD56+ (2.84%), 38 cels/μL Células NK CD3- CD56+ (3.08%), 41 cels/μL': 'Population analyzed: Lymphocytic (30.2%). The following subpopulations are identified: T lymphocytes CD3+ (79.09%), 1060 cells/μL - T lymphocytes CD4+ (51.78%), 549 cells/μL - T lymphocytes CD8+ (46.73%), 495 cells/μL B lymphocytes CD19+ CD20+ (13.38%), 179 cells/μL NK T lymphocytes CD3+ CD56+ (2.84%), 38 cells/μL NK cells CD3- CD56+ (3.08%), 41 cells/μL',
    'Se observan linfocitos de aspecto estimulado.Serie roja con hipocromía': 'Stimulated-appearing lymphocytes observed. Red series with hypochromia',
    'Se recomienda nueva extracción para comprobar resultados.': 'New extraction recommended to verify results.',
    'Se observan linfocitos de aspecto estimulado.Serie roja con hipocromía, presencia de ovalocitos y eliptocitos, algún dianocito. Trombopenia comprobada.': 'Stimulated-appearing lymphocytes observed. Red blood cells show hypochromia, presence of ovalocytes and elliptocytes, some dianocytes. Confirmed thrombocytopenia.',
    'Población analizada: Linfocitaria (25.1%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (78.97%), 734 cels/μL - Linfocitos T CD4+ (45.95%), 337 cels/μL - Linfocitos T CD8+ (52.46%), 385 cels/μL Linfocitos B CD19+ CD20+ (11.05%), 103 cels/μL Linfocitos NK T CD3+ CD56+ (3.57%), 33 cels/μL Células NK CD3- CD56+ (4.93%), 46 cels/μL': 'Population analyzed: Lymphocytic (25.1%). The following subpopulations are identified: T lymphocytes CD3+ (78.97%), 734 cells/μL - T lymphocytes CD4+ (45.95%), 337 cells/μL - T lymphocytes CD8+ (52.46%), 385 cells/μL B lymphocytes CD19+ CD20+ (11.05%), 103 cells/μL NK T lymphocytes CD3+ CD56+ (3.57%), 33 cells/μL NK cells CD3- CD56+ (4.93%), 46 cells/μL',
    'Población analizada: Linfocitaria (25.1%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (78.97%)': 'Population analyzed: Lymphocytic (25.1%). The following subpopulations are identified: T lymphocytes CD3+ (78.97%)',
    'Población analizada: Linfocitaria (24.8%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (75.29%), 1054 cels/μL - Linfocitos T CD4+ (68.62%), 723 cels/μL - Linfocitos T CD8+ (29.64%), 312 cels/μL Linfocitos B CD19+ CD20+ (6.10%), 85 cels/μL Linfocitos NK T CD3+ CD56+ (3.18%), 44 cels/μL Células NK CD3- CD56+low (14.08%), 197 cels/μL': 'Population analyzed: Lymphocytic (24.8%). The following subpopulations are identified: T lymphocytes CD3+ (75.29%), 1054 cells/μL - T lymphocytes CD4+ (68.62%), 723 cells/μL - T lymphocytes CD8+ (29.64%), 312 cells/μL B lymphocytes CD19+ CD20+ (6.10%), 85 cells/μL NK T lymphocytes CD3+ CD56+ (3.18%), 44 cells/μL NK cells CD3- CD56+low (14.08%), 197 cells/μL',
    'Población analizada: Linfocitaria (28.2%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (64.41%)': 'Population analyzed: Lymphocytic (28.2%). The following subpopulations are identified: T lymphocytes CD3+ (64.41%)',
    'Población analizada: Linfocitaria (24.8%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (75.29%)': 'Population analyzed: Lymphocytic (24.8%). The following subpopulations are identified: T lymphocytes CD3+ (75.29%)',
    'Recuento manual: 84% seg, 2% cay, 7% linfo, 6% mono, 1% metamielocitos. Se observa refuerzo de la granulación neutrofílica.': 'Manual count: 84% segmented neutrophils, 2% band neutrophils, 7% lymphocytes, 6% monocytes, 1% metamyelocytes. Neutrophil granulation reinforcement observed.',
    'Se visualizan neutrófilos vacuolados y algún linfocito de aspecto activado. Serie roja no valorable por artefacto en la muestra.': 'Vacuolated neutrophils and some activated-appearing lymphocytes observed. Red blood cell series not assessable due to artifact in the sample.',
    'Sangre 1¦ muestra= proximal, Sangre 2¦ muestra= medial, Sangre 3¦ muestra= distal, Sangre 4¦ muestra= arterial': 'Blood 1st sample= proximal, Blood 2nd sample= medial, Blood 3rd sample= distal, Blood 4th sample= arterial',
    'Población analizada: Linfocitaria (22.1%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (82.3%)': 'Population analyzed: Lymphocytic (22.1%). The following subpopulations are identified: T lymphocytes CD3+ (82.3%)',
    'Muestra lipémica Y Hemolizada.': 'Lipemic and Hemolyzed sample.',
    'Fórmula manual: segmentados 74%': 'Manual differential count: segmented neutrophils 74%',
    'Población analizada: Linfocitaria (19.3%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (80.77%)': 'Population analyzed: Lymphocytic (19.3%). The following subpopulations are identified: T lymphocytes CD3+ (80.77%)',
    'Población analizada: Linfocitaria (19.3%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (80.77%), 1042 cels/μL - Linfocitos T CD4+ (82.34%), 858 cels/μL - Linfocitos T CD8+ (14.01%), 146 cels/μL Linfocitos B CD19+ CD20+ (8.62%), 111 cels/μL Linfocitos NK T CD3+ CD56+ (3.04%), 39 cels/μL Células NK CD3- CD56+ (5.4%), 70 cels/μL': 'Population analyzed: Lymphocytic (19.3%). The following subpopulations are identified: T lymphocytes CD3+ (80.77%), 1042 cells/μL - T lymphocytes CD4+ (82.34%), 858 cells/μL - T lymphocytes CD8+ (14.01%), 146 cells/μL B lymphocytes CD19+ CD20+ (8.62%), 111 cells/μL NK T lymphocytes CD3+ CD56+ (3.04%), 39 cells/μL NK cells CD3- CD56+ (5.4%), 70 cells/μL',
    'Población analizada: Linfocitaria (22.3%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (82.17%)': 'Lymphocytic population (22.3%). Subpopulations identified: CD3+ T lymphocytes (82.17%)',
    'Población analizada: Linfocitaria (22.3%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (82.17%), 1421 cels/μL - Linfocitos T CD4+ (84.96%), 1207 cels/μL - Linfocitos T CD8+ (12.03%), 171 cels/μL Linfocitos B CD19+ CD20+ (9.22%), 159 cels/μL Linfocitos NK T CD3+ CD56+ (2.49%), 43 cels/μL Células NK CD3- CD56+ (3.07%), 53 cels/μL': 'Lymphocytic population (22.3%). Subpopulations identified: CD3+ T lymphocytes (82.17%), 1421 cells/μL - CD4+ T lymphocytes (84.96%), 1207 cells/μL - CD8+ T lymphocytes (12.03%), 171 cells/μL CD19+ CD20+ B lymphocytes (9.22%), 159 cells/μL CD3+ CD56+ NK T cells (2.49%), 43 cells/μL CD3- CD56+ NK cells (3.07%), 53 cells/μL',
    'Se observan neutrófilos con refuerzo en la granulación y linfocitos de aspecto activado.': 'Neutrophils with enhanced granulation and activated lymphocytes are observed.',
    'Hemodilución. Reclamada nueva muestra': 'Hemodilution. A new sample is requested.',
    'Población analizada: Linfocitaria (12.4%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (75.40%), 875 cels/μL - Linfocitos T CD4+ (75.18%), 657 cels/μL - Linfocitos T CD8+ (22.14%), 194 cels/μL Linfocitos B CD19+ CD20+ (7.58%), 88 cels/μL Linfocitos NK T CD3+ CD56+ (5.34%), 62 cels/μL Células NK CD3- CD56+ (9.18%), 106 cels/μL': 'Lymphocytic population (12.4%). Subpopulations identified: CD3+ T lymphocytes (75.40%), 875 cells/μL - CD4+ T lymphocytes (75.18%), 657 cells/μL - CD8+ T lymphocytes (22.14%), 194 cells/μL CD19+ CD20+ B lymphocytes (7.58%), 88 cells/μL CD3+ CD56+ NK T cells (5.34%), 62 cells/μL CD3- CD56+ NK cells (9.18%), 106 cells/μL',
    'Población analizada: Linfocitaria (15.1%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (77.3%)': 'Lymphocytic population (15.1%). Subpopulations identified: CD3+ T lymphocytes (77.3%)',
    'Muestra hemolizada Y Lipemica.': 'Hemolyzed and lipemic sample.',
    'Población analizada: Linfocitaria (15.1%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (77.3%), 827 cels/μL - Linfocitos T CD4+ (81.6%), 675 cels/μL - Linfocitos T CD8+ (14.98%), 123 cels/μL Linfocitos B CD19+ CD20+ (6.34%), 68 cels/μL Linfocitos NK T CD3+ CD56+ (4.13%), 44 cels/μL Células NK CD3- CD56+ (7.31%),78 cels/μL': 'Lymphocytic population (15.1%). Subpopulations identified: CD3+ T lymphocytes (77.3%), 827 cells/μL - CD4+ T lymphocytes (81.6%), 675 cells/μL - CD8+ T lymphocytes (14.98%), 123 cells/μL CD19+ CD20+ B lymphocytes (6.34%), 68 cells/μL CD3+ CD56+ NK T cells (4.13%), 44 cells/μL CD3- CD56+ NK cells (7.31%), 78 cells/μL',
    'Población analizada: Linfocitaria (13.6%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (75.78%)': 'Lymphocytic population (13.6%). Subpopulations identified: CD3+ T lymphocytes (75.78%)',
    'Población analizada: Linfocitaria (13.6%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (75.78%), 689 cels/μL - Linfocitos T CD4+ (82.36%), 568 cels/μL - Linfocitos T CD8+ (14.68%), 101 cels/μL Linfocitos B CD19+ CD20+ (7.98%), 72 cels/μL Linfocitos NK T CD3+ CD56+ (4.06%), 37 cels/μL Células NK CD3- CD56+ (9.89%), 90 cels/μL': 'Lymphocytic population (13.6%). Subpopulations identified: CD3+ T lymphocytes (75.78%), 689 cells/μL - CD4+ T lymphocytes (82.36%), 568 cells/μL - CD8+ T lymphocytes (14.68%), 101 cells/μL CD19+ CD20+ B lymphocytes (7.98%), 72 cells/μL CD3+ CD56+ NK T cells (4.06%), 37 cells/μL CD3- CD56+ NK cells (9.89%), 90 cells/μL',
    'MUESTRA MUY HEMOLIZADA': 'Very hemolyzed sample',
    'SE PROCESA CON N§ XXXXXXX': 'Processed with request number X',
    'Población analizada: Linfocitaria (22.1%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (82.3%), 1391 cels/μL - Linfocitos T CD4+ (85.8%), 1193 cels/μL - Linfocitos T CD8+ (12.07%), 168 cels/μL Linfocitos B CD19+ CD20+ (8.16%), 138 cels/μL Linfocitos NK T CD3+ CD56+ (2.45%), 41 cels/μL Células NK CD3- CD56+ (4.16%), 70 cels/μL': 'Lymphocytic population (22.1%). Subpopulations identified: CD3+ T lymphocytes (82.3%), 1391 cells/μL - CD4+ T lymphocytes (85.8%), 1193 cells/μL - CD8+ T lymphocytes (12.07%), 168 cells/μL CD19+ CD20+ B lymphocytes (8.16%), 138 cells/μL CD3+ CD56+ NK T cells (2.45%), 41 cells/μL CD3- CD56+ NK cells (4.16%), 70 cells/μL',
    'Anisocitosis de serie roja, sin alteraciones que sugieran hemólisis o causa central de la anemia. Leucocitosis leve con neutrofilia de aspecto reactivo.': 'Red cell anisocytosis without alterations suggesting hemolysis or central cause of anemia. Mild leukocytosis with reactive neutrophilia.',
    'Se observan linfocitos de aspecto estimulado, neutrófilos vacuolados con refuerzo de la granulación. Elementos celulares con figuras apoptóticas. Frotis sugestivo de proceso reactivo.': 'Stimulated lymphocytes observed, vacuolated neutrophils with granulation reinforcement. Cellular elements with apoptotic figures. Smear suggestive of reactive process.',
    'Hemograma y gasometría informados en XXXXXXX de XX/XX': 'Blood count and blood gas analysis reported under number X',
    'Petición anulada': 'Request canceled',
    'Determinaciones realizadas en N§ XXXXXXX': 'Determinations made at number X',
    'No remite 2¦ muestra.': 'No second sample submitted.',
    'Recuento maual: 78% seg, 15% linfo, 3% mono, 4% eos. Anisocromía , se visualizan eliptocitos.Neutrófilos vacuolados con refuerzo de la granulación. En ausencia de de causa reactiva se recomienda estudio hematológico.': 'Manual count: 78% seg, 15% linfo, 3% mono, 4% eos. Anisochromia, elliptocytes observed. Vacuolated neutrophils with granulation reinforcement. In the absence of reactive cause, hematological study is recommended.',
    'Recuento manual: 93% segm 2% cay, 5% linfo. Se observa leucocitosis con desviación izquierda, a expensas de neutrófilos vacuolados con refuerzo de la granulación.': 'Manual count: 93% segm, 2% cay, 5% linfo. Left shift leukocytosis observed, due to vacuolated neutrophils with granulation reinforcement.',
    'Se observan linfocitos de aspecto estimulado. Neutrófilos vacuolados y con refuerzo de la granulación. Núcleos picnóticos. Trombopenia comprobada.': 'Stimulated lymphocytes observed. Vacuolated neutrophils with granulation reinforcement. Picnotic nuclei. Confirmed thrombocytopenia.',
    'Procesado en petición XXXXXXX': 'Processed under request number X',
    'Se observan linfocitos de aspecto estimulado. Elemento celulares con núcleos en cariorrexis. Neutrófilos vacuolados.': 'Stimulated lymphocytes observed. Cellular elements with karyorrhexis nuclei. Vacuolated neutrophils.',
    'O Negativo': 'O Negative',
    'Serie roja con hipocromía moderada': 'Red series with moderate hypochromia',
    'Proecesada en HMV': 'Processed at HMV', 
    'Muestra insuficiente para VSG.': 'Insufficient sample for ESR (Erythrocyte Sedimentation Rate).',
    'Serie roja con hipocromía. Presencia de algunos eliptocitos': 'Red blood cells with hypochromia. Presence of some elliptocytes.',
    'Serie roja con hipocromía. Presencia de algunos eliptocitos, dianocitos y algún equinocito. Se observan agregados plaquetarios.': 'Red blood cells with hypochromia. Presence of some elliptocytes, dacrocytes, and occasional echinocytes. Platelet aggregates are observed.',
    'Serie roja con marcada anisocromía y poiquilocitosis, se observan frecuentes dianocitos y algunos estomatocitos. Policromasia e hipocromía, con presencia de punteado basófilo. Trombopenia comprobada. Neutrófilos vacuolados con refuerzo de la granulación.': 'Red blood cells with marked anisocytosis and poikilocytosis, frequent dacrocytes and some stomatocytes observed. Polychromasia and hypochromia, with presence of basophilic stippling. Confirmed thrombocytopenia. Vacuolated neutrophils with granulation reinforcement.',
    'ERROR DE IDENTIFICACION DE PACIENTE': 'PATIENT IDENTIFICATION ERROR',
    'Fórmula manual: segmentados 45%': 'Manual differential count: segmented neutrophils 45%',
    'Se visualizan neutrófilos vacuolados. Serie roja no valorable por que la muestra est  artefactada (abundantes equinocitos).': 'Vacuolated neutrophils observed. Red blood cell count not evaluable due to sample artifact (abundant echinocytes).',
    'Nueva muestra XXXXXXX': 'New sample X',
    'Se observa desviación izquierda, con presencia de neutrófilos con granulación tóxica. Linfocitos heterogéneos de aspecto estimulado, algunos linfocitos hendidos. Trombopenia leve comprobada.': 'Left shift observed, with presence of neutrophils with toxic granulation. Heterogeneous stimulated lymphocytes, some cleaved lymphocytes. Mild thrombocytopenia confirmed.',
    'PEDIDA NUEVA MUESTRA': 'NEW SAMPLE REQUESTED',
    r'Población analizada: Linfocitaria (6.7%). Se distinguen las siguientes subpoblaciones:\X0A\Linfocitos T CD3+ (83%), 531 cels,/uL\X0A\    - Linfocitos T CD4+ (35.3%), 187 cels/uL\X0A\    - Linfocitos T CD8+ (61.2%), 325 cels/uL \X0A\Linfocitos B CD19+ (0.2%), 1 cel/uL\X0A\Células NK CD3- CD56+ (16.2%), 104 cels/uL': r'Lymphocytic population (6.7%). The following subpopulations are distinguished: CD3+ T lymphocytes (83%), 531 cells/μL - CD4+ T lymphocytes (35.3%), 187 cells/μL - CD8+ T lymphocytes (61.2%), 325 cells/μL CD19+ B lymphocytes (0.2%), 1 cell/μL CD3- CD56+ NK cells (16.2%), 104 cells/μL',
    'Recuento manual: 92% seg, 1% lindo, 2% mono, 1% eos, 4% cay. Neutrófilos vacuolados con refuerzo de la granulación e hipersegmentación nuclear.': 'Manual differential count: 92% segmented neutrophils, 1% band cells, 2% monocytes, 1% eosinophils, 4% lymphocytes. Neutrophils with vacuolation and nuclear hypersegmentation.',
    'Potasio comprobado': 'Potassium confirmed.',
    'Se observa anisocitosis e hipocromía moderada. Presencia de ovalocitos, algún eliptocito y dacricito. Neutrófilos con refuerzo de la granulación.': 'Moderate anisocytosis and hypochromia observed. Presence of ovalocytes, some elliptocytes, and dacryocytes. Neutrophils with granulation reinforcement.',
    'Se observa anisocitosis e hipocromía moderada. Presencia de ovalocitos': 'Moderate anisocytosis and hypochromia observed. Presence of ovalocytes.',
    'Determinación realizada en N§ XXXXXXX': 'Determination made at number X',
    'Leucocitosis con desviación izquierda. Se observan neutrófilos vacuolados con refuerzo en la granulación. Policromasia.': 'Leukocytosis with left shift. Vacuolated neutrophils with granulation reinforcement observed. Polychromasia.',
    'CALCIO PLASMµTICO': 'PLASMA CALCIUM', 
    'Estudio morfológico sin alteraciones citomorfológicas rese¤ables en las tres series.': 'Morphological study without notable cytological alterations in the three series.',
    'Se observa leucocitosis con desviación izquierda. Neutrófilos vacuolados con presencia de grnaulación tóxica. Serie roja escasamente valorable por artefacto en la muestra, se observa poiquilocitosis con múltiples equinocitos.': 'Leukocytosis with left shift observed. Neutrophils vacuolated with presence of toxic granulation. Red blood cell series scarcely evaluable due to artifact in the sample, poikilocytosis with multiple echinocytes observed.',
    'Fórmula manual: segmentados 48%': 'Manual differential count: segmented neutrophils 48%',
    'Se observa anisocitosis e hipocromía moderada': 'Moderate anisocytosis and hypochromia observed',
    'Neutrófilos con refuerzo de la granulación y desviación izquierda de posible origen reactivo.': 'Neutrophils with granulation reinforcement and left shift possibly of reactive origin.',
    'Leucocitosis con desviación izquierda. Se observa neutrófilos con refuerzo de la granulación.': 'Leukocytosis with left shift. Neutrophils observed with granulation reinforcement.',
    'Este resultado sugiere probable infección pasada por SARS-CoV-2.El resultado debe interpretarse con cautela puesto que no hay evidencia que permita asegurar que la presencia de IgG confiera protección ni la duración de la supuesta inmunidad protectora.Si existe sospecha diagnóstica de infección por SARS-CoV-2, se recomienda consultar con médico para valorar la realización del estudio de confirmación mediante PCR': 'This result suggests probable past infection with SARS-CoV-2. The result should be interpreted cautiously as there is no evidence to confirm that the presence of IgG provides protection or the duration of supposed protective immunity. If there is a diagnostic suspicion of SARS-CoV-2 infection, it is recommended to consult with a physician to consider performing confirmatory PCR testing.',
    'Este resultado sugiere probable infección pasada por SARS-CoV-2.El resultado debe interpretarse con cautela puesto que no hay evidencia que permita asegurar que la presencia de IgG confiera protección ni la duración de la supuesta inmunidad protectora.Si existe sospecha diagnóstica de infección por SARS-CoV-2': 'This result suggests probable past infection with SARS-CoV-2. The result should be interpreted cautiously as there is no evidence to confirm that the presence of IgG provides protection or the duration of supposed protective immunity. If there is a diagnostic suspicion of SARS-CoV-2 infection',
    'Positivo. Se observan bandas correspondientes a las proteínas C1': 'Positive. Bands corresponding to proteins C1 observed.',
    'Positivo. Se observan bandas correspondientes a las proteínas C1; C2; E2 y NS3': 'Positive. Bands corresponding to proteins C1; C2; E2; and NS3 observed.',
    'Fórmula manual: segmentados 77%': 'Manual differential count: segmented neutrophils 77%',
    'CON ALTO FLUJO': 'WITH HIGH FLOW',
    'Fórmula manual: segmentados 48%; linfocitos 40%; monocitos 8%; eosinófilos 4%; basófilos 0%.': 'Manual differential count: segmented neutrophils 48%; lymphocytes 40%; monocytes 8%; eosinophils 4%; basophils 0%.',
    'Recuento manual: 57% seg, 2% cay, 27% linfo, 10% mono, 1% metamielo, 3% eos. Se visualizan linfocitos de aspecto activado. Serie roja con hipocromía moderada. Desviación izquierda.': 'Manual differential count: 57% segmented neutrophils, 2% band cells, 27% lymphocytes, 10% monocytes, 1% metamyelocytes, 3% eosinophils. Activated-appearing lymphocytes observed. Red blood cell series with moderate hypochromia. Left shift.',
    'Fórmula manual: segmentados 42%': 'Manual differential count: segmented neutrophils 42%',
    'Leucocitosis con desviación izquierda. Neutrófilos con refuerzo de la granulación. Linfocitos de aspecto estimulado y algún infocito grande granular.': 'Leukocytosis with left shift. Neutrophils with granulation reinforcement. Stimulated-appearing lymphocytes and some large granular lymphocytes observed.',
    'Se observa desviación izquierda. Neutrófilos con refuerzo de la granulación. Poiquilocitosis con presencia de algunos dacriocitos, ovalocitos y eliptocitos.': 'Left shift observed. Neutrophils with granulation reinforcement. Poikilocytosis with presence of some dacryocytes, ovalocytes, and elliptocytes.',
    'Neutrófilos vacuolados con refuerzo de la granulación neutrofílica. Desviación izquierda.': 'Vacuolated neutrophils with neutrophilic granulation reinforcement. Left shift.', 
    'Se observan linfocitos de aspecto estimulado Y neutrófilos con refuerzo en la granulación.': 'Stimulated-appearing lymphocytes and neutrophils with granulation reinforcement observed.',
    'Población analizada: Linfocitaria (28.2%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (64.41%), 393 cels/μL - Linfocitos T CD4+ (40.65%), 160 cels/μL - Linfocitos T CD8+ (57.80%), 227 cels/μL Linfocitos B CD19+ CD20+ (20.62%), 126 cels/μL Linfocitos NK T CD3+ CD56+ (3.45%), 21 cels/μL Células NK CD3- CD56+ (9.64%), 59 cels/μL': 'Population analyzed: Lymphocytic (28.2%). The following subpopulations are identified: CD3+ T lymphocytes (64.41%, 393 cells/μL) - CD4+ T lymphocytes (40.65%, 160 cells/μL) - CD8+ T lymphocytes (57.80%, 227 cells/μL) - CD19+ CD20+ B lymphocytes (20.62%, 126 cells/μL) - CD3+ CD56+ NK T lymphocytes (3.45%, 21 cells/μL) - CD3- CD56+ NK cells (9.64%, 59 cells/μL)',
    'Serie roja con anisopoiquilocitosis e hipocromía, con frecuentes eliptocitos, algún equinocito y acantocito. Serie blanca con desviación izquierda y refuerzo de la granulación. Linfocitos activados. Trombopenia comprobada.': 'Red blood cell series with anisopoikilocytosis and hypochromia, with frequent elliptocytes, some echinocytes, and acanthocytes. White blood cell series with left shift and granulation reinforcement. Activated lymphocytes. Confirmed thrombocytopenia.',
    'Netrofilia con refuerzo de la granulación. Linfocitos de aspecto maduro. Control evolutivo': 'Neutrophilia with granulation reinforcement. Mature-appearing lymphocytes. Evolutionary control.',
    'Positivo (1.3)': 'Positive (1.3)',
    'Enviar muestra en tubo de citrato para comprobar recuento plaquetario.': 'Send sample in citrate tube to verify platelet count.',
    'POSITIVO': 'POSITIVE',
    'Negativo (3.56)': 'Negative (3.56)',
    'Positivo (0.13)': 'Positive (0.13)',
    '7 copias/mL': '7 copies/mL',
    'Positivo (27.18)': 'Positive (27.18)',
    'ELISA reactivo (11.18)': 'ELISA reactive (11.18)',
    'ELISA reactivo (48.54)': 'ELISA reactive (48.54)',
    'SE MANDA A RAMON Y CAJAL': 'SENT TO RAMON Y CAJAL',
    'Frotis altamente sugestivo de proceso reactivo.': 'Smear highly suggestive of reactive process.',
    'Anisocitosis de serie roja': 'Anisocytosis of red blood cells',
    'Positivo (138.4)': 'Positive (138.4)',
    r'POSITIVO\X0A\- Influenza A: No se detecta\X0A\- Influenza B: No se detecta\X0A\- Influenza H1N1: No se detecta\X0A\- Coronavirus (Cor 229, Cor 63, Cor 43 y HKU): No se detecta\X0A\- Parainfluenza (HPIV1, HPIV2, HPIV3 y HPIV4): No se detecta\X0A\- Adenovirus (HAdV): SE DETECTA\X0A\- Virus Respiratorio Sincitial (HRSVA/B): No se detecta.\X0A\- Bocavirus (HBoV): No se detecta.\X0A\- Metapneumovirus (HMPV A/B): No se detecta.\X0A\- Rinovirus (RV): No se detecta.\X0A\- Parechovirus (HPeV): No se detecta.\X0A\- Mycoplasma pneumoniae (Mpneu): No se detecta.': r'POSITIVE\X0A\- Influenza A: Not detected\X0A\- Influenza B: Not detected\X0A\- Influenza H1N1: Not detected\X0A\- Coronavirus (Cor 229, Cor 63, Cor 43, and HKU): Not detected\X0A\- Parainfluenza (HPIV1, HPIV2, HPIV3, and HPIV4): Not detected\X0A\- Adenovirus (HAdV): DETECTED\X0A\- Respiratory Syncytial Virus (HRSVA/B): Not detected.\X0A\- Bocavirus (HBoV): Not detected.\X0A\- Metapneumovirus (HMPV A/B): Not detected.\X0A\- Rhinovirus (RV): Not detected.\X0A\- Parechovirus (HPeV): Not detected.\X0A\- Mycoplasma pneumoniae (Mpneu): Not detected.',
    'ERROR': 'ERROR',
    'Abundantes células epiteliales escamosas': 'Abundant squamous epithelial cells',
    'sangre guardada': 'stored blood',
    'enviado 12 octubre': 'sent October 12',
    'Se observa anisopoiquilocitosis.': 'Anisopoikilocytosis observed.', 
    'Positivo (21.56)': 'Positive (21.56)',
    'Positivo (1.7)': 'Positive (1.7)',
    'Se observan plaquetas grandes, por lo que la cifra de plaquetas puede estar infraestimada.': 'Large platelets observed, hence platelet count may be underestimated.',
    'Positivo (1.34)': 'Positive (1.34)',
    'Componente monoclonal estimado: 0.4 g/dL (6.5%)': 'Estimated monoclonal component: 0.4 g/dL (6.5%)',
    'Negativo (2.77)': 'Negative (2.77)',
    'Recuento manual: 69% seg': 'Manual count: 69% seg',
    '36 copias/mL': '36 copies/mL',
    'Positivo (7.44)': 'Positive (7.44)',
    'Positivo (4.56)': 'Positive (4.56)',
    'Serie roja con anisocitosis y policromasia': 'Red blood cell series with anisocytosis and polychromasia',
    'Positivo (6.55)': 'Positive (6.55)',
    'Positivo (7.85)': 'Positive (7.85)',
    'Algunas plaquetas grandes. No se observan agregados plaquetarios.': 'Some large platelets. No platelet aggregates observed.',
    'Positivo (1.46)': 'Positive (1.46)',
    'Positivo (6.36)': 'Positive (6.36)',
    'Positivo (5.5)': 'Positive (5.5)',
    'Positivo (9.32)': 'Positive (9.32)',
    'Se detecta Ct: 34': 'Ct detected: 34', 
    'Positivo (1.96)': 'Positive (1.96)',
    'Positivo (43.51)': 'Positive (43.51)',
    'Positivo (2.63)': 'Positive (2.63)',
    'Componente monoclonal estimado: 0.6 g/dL (9.7%)': 'Estimated monoclonal component: 0.6 g/dL (9.7%)',
    'Recuento manual: 60% seg': 'Manual count: 60% seg',
    ' VASOPRESINA)': 'VASOPRESSIN)',
    'Leucocitos: de 5 a 10/c': 'Leukocytes: 5 to 10/c',
    'Positivo (992.2)': 'Positive (992.2)',
    r'Positivo\X0A\- Influenza A: No se detecta\X0A\- Influenza B: No se detecta\X0A\- Influenza H1N1: SE DETECTA.\X0A\- Coronavirus (Cor 229, Cor 63, Cor 43 y HKU): No se detecta\X0A\- Parainfluenza (HPIV1, HPIV2, HPIV3 y HPIV4): No se detecta\X0A\- Adenovirus (HAdV): No se detecta.\X0A\- Virus Respiratorio Sincitial (HRSVA/B): No se detecta.\X0A\- Bocavirus (HBoV): No se detecta.\X0A\- Metapneumovirus (HMPV A/B): No se detecta.\X0A\- Rinovirus (RV): SE DETECTA\X0A\- Parechovirus (HPeV): No se detecta.\X0A\- Mycoplasma pneumoniae (Mpneu): No se detecta.': r'Positive\X0A\- Influenza A: Not detected\X0A\- Influenza B: Not detected\X0A\- Influenza H1N1: DETECTED.\X0A\- Coronavirus (Cor 229, Cor 63, Cor 43, and HKU): Not detected\X0A\- Parainfluenza (HPIV1, HPIV2, HPIV3, and HPIV4): Not detected\X0A\- Adenovirus (HAdV): Not detected.\X0A\- Respiratory Syncytial Virus (HRSVA/B): Not detected.\X0A\- Bocavirus (HBoV): Not detected.\X0A\- Metapneumovirus (HMPV A/B): Not detected.\X0A\- Rhinovirus (RV): DETECTED\X0A\- Parechovirus (HPeV): Not detected.\X0A\- Mycoplasma pneumoniae (Mpneu): Not detected.',
    'Positivo (18.9)': 'Positive (18.9)',
    'Positivo (10.43)': 'Positive (10.43)',
    'Positivo (9.65)': 'Positive (9.65)',
    'Recuento celular manual: Linfocitos 38%': 'Manual cell count: Lymphocytes 38%',
    'Recuento manual: 55% seg': 'Manual count: 55% seg',
    'Niveles medidos en la muestra tomada el XX.XX.XX, XX:XXh': 'Levels measured in the sample taken previously',
    'Negativo (0.28)': 'Negative (0.28)',
    'No procede Gripe A y B por PCR COVID-19 Positivo': 'Not applicable Influenza A and B by PCR COVID-19 Positive',
    'Recuento manual: 50% seg': 'Manual count: 50% seg',
    'Positivo (22.5)': 'Positive (22.5)', 
    'Zona limite (0.98)': 'Borderline zone (0.98)',
    'Negativo (5.24)': 'Negative (5.24)',
    'Positivo (5.1)': 'Positive (5.1)',
    'Negativo (0.42)': 'Negative (0.42)',
    'Positivo (178.2)': 'Positive (178.2)',
    'serie roja artefactada': 'Red blood cells artifacted',
    'Se observa anisopoiquilocitosis con presencia de ovalocitos': 'Anisopoikilocytosis observed with presence of ovalocytes',
    'No se observan agregados plaquetarios. Se observan plaquetas de gran talla.': 'No platelet aggregates observed. Large-sized platelets observed.',
    'Positivo (4576.0)': 'Positive (4576.0)',
    'Positivo (10.12)': 'Positive (10.12)',
    'Positivo (9.15)': 'Positive (9.15)',
    'Negativo (4.11)': 'Negative (4.11)',
    'ELISA reactivo (1.61)': 'ELISA reactive (1.61)',
    'ELISA reactivo (78.05)': 'ELISA reactive (78.05)',
    'Positivo (13.13)': 'Positive (13.13)',
    'Negativo (6.7)': 'Negative (6.7)',
    'Positivo (10.63)': 'Positive (10.63)',
    'Positivo (8.0)': 'Positive (8.0)',
    'Positivo (9.49)': 'Positive (9.49)',
    'Positivo (9.16)': 'Positive (9.16)', 
    'Se ruega enviar nueva en citrato muestra para comprobar recuento plaquetario.': 'Please send a new sample in citrate to verify platelet count.',
    'Recuento manual: 73% seg, 1% eos, 5% cay, 16% linfo, 5% mono. Se observan linfocitos de aspecto estimulado. Algunos macrotrombocitos y presencia de agregados plaquetarios.': 'Manual count: 73% seg, 1% eos, 5% cay, 16% linfo, 5% mono. Stimulated lymphocytes observed. Some large platelets and presence of platelet aggregates.',
    'Ct 34': 'Ct 34',
    'Positivo (9.98)': 'Positive (9.98)',
    'Positivo (6.77)': 'Positive (6.77)',
    'Presencia de linfocitos de aspecto activado. Se observan agregados plaquetarios. Se ruega enviar muestra de hemograma en citrato para confirmar recuento de plaquetas.': 'Presence of activated lymphocytes. Platelet aggregates observed. Please send citrated blood sample to confirm platelet count.',
    'Positivo (240.0)': 'Positive (240.0)',
    'Indeterminado (0.88)': 'Indeterminate (0.88)',
    'Recuento manual: 62% seg': 'Manual count: 62% seg',
    'Positivo (10.33)': 'Positive (10.33)',
    'Positivo (4.47)': 'Positive (4.47)',
    'Frotis altamente sugestivo de proceso reactivo infeccioso/inflamatorio.': 'Smear highly suggestive of reactive infectious/inflammatory process.',
    'Positivo (32.75)': 'Positive (32.75)',
    'Positivo (426.1)': 'Positive (426.1)',
    'Positivo (224.2)': 'Positive (224.2)',
    'Positivo (57.4)': 'Positive (57.4)',
    'Fórmula manual: segmentados 73%; linfocitos 20%; monocitos 7%; eosinófilos 0%; basófilos 0%.': 'Manual differential count: segmented 73%; lymphocytes 20%; monocytes 7%; eosinophils 0%; basophils 0%.',
    'Positivo (638.4)': 'Positive (638.4)',
    'ELISA reactivo (51.64)': 'ELISA reactive (51.64)',
    'Positivo (435.4)': 'Positive (435.4)',
    'ELISA reactivo (14.83)': 'ELISA reactive (14.83)',
    'ELISA reactivo (156.6)': 'ELISA reactive (156.6)',
    'Positivo (114.3)': 'Positive (114.3)', 
    'BAL': 'Bronchoalveolar lavage (BAL)',
    'Positivo (31.56)': 'Positive (31.56)',
    'Recuento manual: 74% seg': 'Manual count: 74% seg',
    'Positivo (16.77)': 'Positive (16.77)',
    'Positivo (14.56)': 'Positive (14.56)',
    'Componente monoclonal estimado: 0.5 g/dL (9.7%)': 'Estimated monoclonal component: 0.5 g/dL (9.7%)',
    'POSITIVO - Influenza A: No se detecta - Influenza B: No se detecta - Influenza H1N1: No se detecta - Coronavirus (Cor 229, Cor 63, Cor 43 y HKU): No se detecta - Parainfluenza (HPIV1, HPIV2, HPIV3 y HPIV4): No se detecta - Adenovirus (HAdV): No se detecta. - Virus Respiratorio Sincitial (HRSVA/B): No se detecta. - Bocavirus (HBoV): No se detecta. - Metapneumovirus (HMPV A/B): No se detecta. - Enterovirus (EV): No se detecta. - Rinovirus (RV): SE DETECTA - Parechovirus (HPeV): No se detecta. - Mycoplasma pneumoniae (Mpneu): No se detecta.': 'POSITIVE - Influenza A: Not detected - Influenza B: Not detected - Influenza H1N1: Not detected - Coronavirus (Cor 229, Cor 63, Cor 43, and HKU): Not detected - Parainfluenza (HPIV1, HPIV2, HPIV3, and HPIV4): Not detected - Adenovirus (HAdV): Not detected - Respiratory Syncytial Virus (HRSVA/B): Not detected - Bocavirus (HBoV): Not detected - Metapneumovirus (HMPV A/B): Not detected - Enterovirus (EV): Not detected - Rhinovirus (RV): DETECTED - Parechovirus (HPeV): Not detected - Mycoplasma pneumoniae (Mpneu): Not detected.',
    'POSITIVO - Influenza A: No se detecta - Influenza B: No se detecta - Influenza H1N1: No se detecta - Coronavirus (Cor 229': 'POSITIVE - Influenza A: Not detected - Influenza B: Not detected - Influenza H1N1: Not detected - Coronavirus (Cor 229)',
    'No valorable por material genético insuficiente en la muestra remitida': 'Not evaluable due to insufficient genetic material in the submitted sample',
    'Recuento manual: 70% sge, 12% cay, 2% eos, 9% linfo, 7% mono. Se visualizan varios linfocitos de aspecto activado y macrotrombocitos.': 'Manual count: 70% seg, 12% cay, 2% eos, 9% linfo, 7% mono. Several activated lymphocytes and large platelets observed.',
    'Se ruega enviar nueva muestra en tubo de citrato para comprobar recuento plaquetario.': 'Please send a new sample in citrate tube to verify platelet count.',
    'Anisocitosis con presencia de macrocitos y ovalocitos. Se observan varios linfocitos heterogéneos con citoplasma amplio de aspecto activado. Trombopenia comprobada.': 'Anisocytosis with presence of macrocytes and ovalocytes. Several heterogeneous lymphocytes observed with broad cytoplasm and activated appearance. Confirmed thrombocytopenia.',
    'No se observan agregados plaquetarios. Se observan algunas plaquetas grandes de gran talla': 'No platelet aggregates observed. Some large-sized platelets observed.',
    'Positivo (9.53)': 'Positive (9.53)',
    'Positivo (10.49)': 'Positive (10.49)',
    'Positivo (53.39)': 'Positive (53.39)',
    'ESPUTO': 'Sputum',
    'Cifra de plaquetas infravalorada por presencia de plaquetas de gran talla y peque¤os agregados.': 'Platelet count underestimated due to presence of large-sized platelets and small aggregates.',
    'Positivo (349.9)': 'Positive (349.9)',
    'Positivo (1.14)': 'Positive (1.14)',
    'BASAL. Test de Synacthen (1¦ muestra)': 'BASAL. Synacthen test (1st sample)',
    'Test de Synacthen (2¦ muestra)': 'Synacthen test (2nd sample)',
    'Positivo (612.5)': 'Positive (612.5)', 
    'Positivo (11.45)': 'Positive (11.45)',
    '25 copias/mL': '25 copies/mL',
    '4.164 copias/mL': '4.164 copies/mL',
    '14.086 copias/mL': '14.086 copies/mL',
    'Negativo (0.82)': 'Negative (0.82)',
    'Positivo (3.01)': 'Positive (3.01)',
    'Positivo (3.36)': 'Positive (3.36)',
    'Negativo (6.77)': 'Negative (6.77)',
    'Positivo (154.3)': 'Positive (154.3)',
    'Negativo (6.0)': 'Negative (6.0)',
    'Se observa anisopoiquilocitosis': 'Anisopoikilocytosis observed',
    'Positivo (15.31)': 'Positive (15.31)',
    'Positivo (14.05)': 'Positive (14.05)',
    'Componente monoclonal estimado: 0.4 g/dL (8.6%)': 'Estimated monoclonal component: 0.4 g/dL (8.6%)',
    'Recuento manual: 85% seg, 14% cay, 1% linfo. Abundantes células rotas y equinocitos, por probable muestra artefactada.': 'Manual count: 85% seg, 14% cay, 1% linfo. Abundant broken cells and echinocytes, likely due to artifacted sample.',
    'Positivo (43.58)': 'Positive (43.58)',
    'Positivo (186.0)': 'Positive (186.0)',
    'Positivo (6.25)': 'Positive (6.25)',
    'Positivo (8.8)': 'Positive (8.8)',
    'Positivo (487.0)': 'Positive (487.0)',
    'Positivo (9.08)': 'Positive (9.08)',
    'Positivo (6.64)': 'Positive (6.64)', 
    'Positivo (31.17)': 'Positive (31.17)',
    'enviado RYC': 'Sent RYC (Receiving and Confirmation)',
    'Positivo (697.0)': 'Positive (697.0)',
    'ELISA reactivo (117.1)': 'ELISA reactive (117.1)',
    'Positivo (1.33)': 'Positive (1.33)',
    'Positivo (9.55)': 'Positive (9.55)',
    'Positivo (330.5)': 'Positive (330.5)',
    'NO REMITE ORINA AISLADA NI ORINA DE 24H': 'Does not submit isolated urine or 24-hour urine',
    'Negativo (4.52)': 'Negative (4.52)',
    'Recuento manual: 33% seg, 45 cay, 53% linfo, 2% LGG, 7% mono, 1% eos. Neutropenia comprobada. Presencia de linfocitos de aspecto activado. No se observan blastos.': 'Manual count: 33% seg, 45 cay, 53% linfo, 2% LGG, 7% mono, 1% eos. Confirmed neutropenia. Presence of activated lymphocytes. No blasts observed.',
    'Positivo (181.2)': 'Positive (181.2)',
    'Recuento celular diferencial manual: Linfocitos 28%': 'Manual differential cell count: Lymphocytes 28%',
    'Positivo (88.38)': 'Positive (88.38)',
    'Positivo (9.22)': 'Positive (9.22)',
    'Frotis informado en muestra No XXXXXXX': 'Smear reported in sample No X',
    'Positivo (23.59)': 'Positive (23.59)',
    'Positivo (136.0)': 'Positive (136.0)',
    'Positivo (246.0)': 'Positive (246.0)',
    'Positivo (36.46)': 'Positive (36.46)',
    'En la serie roja se observan dianocitos.': 'Schistocytes observed in red cell series.',
    'Positivo (407.5)': 'Positive (407.5)', 
    '14.8 Resultado comprobado.': '14.8 Confirmed result.',
    'Se ruega enviar nueva muestra para confirmar recuento de plaquetas.': 'Please send a new sample to confirm platelet count.',
    'Se visualizan agregados plaquetarios.': 'Platelet aggregates observed.',
    'Negativo (5.95)': 'Negative (5.95)',
    'Tras cultivo celular, todas las metafases analizadas mediante bandas GTL, presentaron 46 cromosomas sin que se observaran alteraciones estructurales.': 'After cell culture, all metaphases analyzed by GTL bands showed 46 chromosomes without structural alterations.',
    'Tras cultivo celular': 'After cell culture',
    'Se anula FISH dado que ni el estudio realizado': 'FISH is canceled since neither the study was performed',
    'Positivo (262.0)': 'Positive (262.0)',
    'Positivo (225.4)': 'Positive (225.4)',
    'ELISA reactivo (1962.0)': 'ELISA reactive (1962.0)',
    'Frotis sugestiva de proceso reactivo.': 'Smear suggestive of reactive process.',
    'Positivo (11.38)': 'Positive (11.38)',
    'Positivo (9.87)': 'Positive (9.87)',
    'Positivo (8.99)': 'Positive (8.99)',
    'Positivo (702.1)': 'Positive (702.1)',
    'Positivo (10.16)': 'Positive (10.16)',
    'Positivo (9.61)': 'Positive (9.61)',
    'Negativo (0.87)': 'Negative (0.87)',
    r'Negativo\X0A\- Influenza A: No se detecta\X0A\- Influenza B: No se detecta\X0A\- Influenza H1N1: No se detecta\X0A\- Coronavirus (Cor 229, Cor 63, Cor 43 y HKU): No se detecta\X0A\- Parainfluenza (HPIV1, HPIV2, HPIV3 y HPIV4): No se detecta\X0A\- Adenovirus (HAdV): No se detecta.\X0A\- Virus Respiratorio Sincitial (HRSVA/B): No se detecta.\X0A\- Bocavirus (HBoV): No se detecta.\X0A\- Metapneumovirus (HMPV A/B): No se detecta.\X0A\- Rinovirus (RV): No se detecta.\X0A\- Parechovirus (HPeV): No se detecta.\X0A\- Mycoplasma pneumoniae (Mpneu): No se detecta': r'Negative\n- Influenza A: Not detected\n- Influenza B: Not detected\n- Influenza H1N1: Not detected\n- Coronavirus (Cor 229, Cor 63, Cor 43, and HKU): Not detected\n- Parainfluenza (HPIV1, HPIV2, HPIV3, and HPIV4): Not detected\n- Adenovirus (HAdV): Not detected\n- Respiratory Syncytial Virus (HRSVA/B): Not detected\n- Bocavirus (HBoV): Not detected\n- Metapneumovirus (HMPV A/B): Not detected\n- Rhinovirus (RV): Not detected\n- Parechovirus (HPeV): Not detected\n- Mycoplasma pneumoniae (Mpneu): Not detected',
    'Positivo (3.72)': 'Positive (3.72)', 
    'Positivo (294.0)': 'Positive (294.0)',
    'Monocitosis confirmada.': 'Confirmed monocytosis.',
    'Recuento plaquetario: 57% seg, 9% cay, 2% metamielocitos, 20% linfo, 4% LGG, 1% Eos, 2% baso. Se observa desviación izquierda con refuerzo de la granulación neutrofílica. Presencia de linfocitos activados. Anisocromía.': 'Platelet count: 57% seg, 9% cay, 2% metamyelocytes, 20% linfo, 4% LGG, 1% Eos, 2% baso. Left shift with neutrophil granulation reinforcement observed. Activated lymphocytes present. Anisochromia.',
    'Determinaciones procesadas en muestra XXXXXXX de XX/X': 'Tests processed on sample X',
    'Pruebas añadidas a muestra XXXXXXX': 'Tests added to sample X',
    'No se observan agregados plaquetarios. Sí se observan plaquetas jóvenes de gran talla.': 'No platelet aggregates observed. Large young platelets observed.',
    'Se observan neutrófilos con refuerzo en la granulación, de posible origen reactivo.': 'Neutrophils observed with granulation reinforcement, possibly reactive in origin.',
    'Fórmula manual: segmentados 81%': 'Manual differential: segmented 81%',
    'O2 50%': 'Oxygen 50%',
    'SANGRE 1¦ MUESTRA= MEDIAL, SANGRE 2¦ MUESTRA= DISTAL': 'BLOOD 1st SAMPLE = MEDIAL, BLOOD 2nd SAMPLE = DISTAL',
    'Leucocitosis con desviación izquierda. Neutrófilos con hipersegmentación nuclear e intenso refuerzo de la granulación. Macrotrombocitos vacuolados.': 'Leukocytosis with left shift. Neutrophils with nuclear hypersegmentation and intense granulation reinforcement. Vacuolated macrothrombocytes.',
    'Trombocitosis comprobada con varios macrotrombocitos. Leucocitosis con desviación izquierda y refuerzo de la granulación neutrofílica. Frotis sugestivo de proceso reactivo.': 'Confirmed thrombocytosis with several macrothrombocytes. Leukocytosis with left shift and neutrophil granulation reinforcement. Smear suggestive of reactive process.',
    'SUBCLAVIA DERECHA.': 'RIGHT SUBCLAVIAN.',
    'CATTER SUBCLAVIA DERECHA': 'RIGHT SUBCLAVIAN CATHETER',
    'Se visualizan neutrófilos vacuolados con refuerzo de la granulación.': 'Vacuolated neutrophils with granulation reinforcement observed.',
    'Fórmula manual: segmentados 86%; linfocitos 10%; monocitos 4%; eosinófilos 0%; basófilos 0%.': 'Manual differential: segmented 86%; lymphocytes 10%; monocytes 4%; eosinophils 0%; basophils 0%.',
    'Fórmula manual: segmentados 89%; linfocitos 9%; monocitos 2%; eosinófilos 0%; basófilos 0%.': 'Manual differential: segmented 89%; lymphocytes 9%; monocytes 2%; eosinophils 0%; basophils 0%.',
    'Frotis revisado por Hematólogo. Linfocitosis a expensas de linfocitos reactivos, formas linfoplasmocitarias y linfocitos grandes granulares, de aspecto maduro. Trombocitosis confirmada al microscopio. Recomendamos control evolutivo.': 'Smear reviewed by Hematologist. Lymphocytosis due to reactive lymphocytes, lymphoplasmacytic forms, and large granular lymphocytes, mature appearance. Thrombocytosis confirmed under the microscope. Evolutionary control recommended.',
    'Recuento manual: 79% seg, 10% cay, 7% linfo,4% mono. Se observan desviación izquierda y refuerzo de la granulación neutrofílica. Hipocromía intensa con presencia de abudates anulocitos, varios eliptocitos. Hematíes con tendencia al rouleaux.': 'Manual differential: 79% seg, 10% cay, 7% linfo, 4% mono. Left shift and neutrophil granulation reinforcement observed. Intense hypochromia with abundant anulocytes, several elliptocytes. Red blood cells tendency to rouleaux.',
    'Estudio morfológico sin alteraciones rese¤ables.': 'Morphological study without remarkable alterations.',
    'ANULADO POR ERROR PETICIONARIO': 'CANCELLED DUE TO REQUESTOR ERROR', 
    'Se observan neutrófilos vacuolados, alguno con presencia de núcleos picnóticos. Linfocitos de aspecto activado.': 'Vacuolated neutrophils observed, some with pyknotic nuclei. Activated lymphocytes.',
    'Recuento manual: 60% seg, 2% cay, 13% mono, 19% linfo, 6% eos. Se visualizan linfocitos activados y neutrófilos vacuolados. Frecuentes núcleos con fenómeno de cariorrexis.': 'Manual count: 60% seg, 2% cay, 13% mono, 19% linfo, 6% eos. Activated lymphocytes and vacuolated neutrophils observed. Frequent nuclei with karyorrhexis phenomenon.',
    'Desviación izquierda. Neutrófilos vacuolados. Linfocitos activados.': 'Left shift. Vacuolated neutrophils. Activated lymphocytes.',
    'Recuento manual: 69% seg, 3% linfo, 2% mono, 1% eos, 2% baso. Neutrófilos vacuolados. Presencia de macrotrombocitos y agregados plaquetarios.': 'Manual count: 69% seg, 3% linfo, 2% mono, 1% eos, 2% baso. Vacuolated neutrophils. Presence of macrothrombocytes and platelet aggregates.',
    'sangre 2¦ muestra= arterial, sangre 3¦ muestra= distal, sangre 4¦ muestra= medial, sangre 5¦ muestra= proximal': '2ª blood sample = arterial, 3ª blood sample = distal, 4ª blood sample = medial, 5ª blood sample = proximal',
    'Se observan linfocitos de aspecto estimulado, desviación izquierda e intenso refuerzo de la granulación neutrofílica.': 'Stimulated lymphocytes observed, left shift, and intense reinforcement of neutrophilic granulation.',
    'No observo esquistocitos. No se observan agregados plaquetarios. Plaquetas comprobadas al microscopio óptico': 'No schistocytes observed. No platelet aggregates observed. Platelets confirmed by optical microscope.',
    'Procesado en la muestra XXXXXXX del día XXXX-XX-XX': 'Processed in sample X',
    'Tubo mal enrasado. Rogamos envíen nueva muestra. Muestra hemolizada': 'Poorly filled tube. Please send a new sample. Hemolyzed sample',
    'INFORME CITOMORFOLÓGICO (Muestra No. XXXXXXX) Muestra de médula ósea con buen grumo. Celularidad normal para la edad del paciente. Lagunas grasas conservadas. Serie megacariocítica ligeramente hiperpl sica sin anomalías morfológicas. Se observan abundantes células rotas. Medulograma: 0.75 % blastos; 4': 'CYTOMORPHOLOGICAL REPORT (Sample No. X) Bone marrow sample with good clumping. Normal cellularity for patient\'s age. Conserved fat spaces. Slightly hyperplastic megakaryocytic series without morphological anomalies. Abundant broken cells observed. Medulogram: 0.75% blasts; 4',
    'INFORME CITOMORFOLÓGICO (Muestra No. XXXXXXX) Muestra de médula ósea con buen grumo. Celularidad normal para la edad del paciente. Lagunas grasas conservadas. Serie megacariocítica ligeramente hiperpl sica sin anomalías morfológicas. Se observan abundantes células rotas. Medulograma: 0.75 % blastos': 'CYTOMORPHOLOGICAL REPORT (Sample No. X) Bone marrow sample with good clumping. Normal cellularity for patient\'s age. Conserved fat spaces. Slightly hyperplastic megakaryocytic series without morphological anomalies. Abundant broken cells observed. Medulogram: 0.75% blasts',
    'Población analizada: Leucocitaria. Se distinguen las siguientes subpoblaciones: 1. Células progenitoras CD34+ (2.53%) - Mieloblastos (CD117+): 2.53% 2. Granulocítica-Neutrófilo (50.28%) - Estadío I+II (23.58%) - Estadío III (56.88%) - Estadío IV (6.9%) - Estadío V (12,63%) 3. Monocítica (3.08%). El 57.8% de la población corresponden a monocitos maduros 4. Eritroide (18.42%) 5. Linfoide, se distinguen las siguientes subpoblaciones: - Linfocitos T CD3+ (59,38%) - Linfocitos T CD4+ (58%) - Linfocitos T CD8+ (38.64%) - Células NK CD3- CD56+ (5.82%) - Linfocitos B CD19+ (31.99%) sIgKappa/sIgLambda policlonal Conclusión: La frecuencia y fenotipo de la población progenitora mieloide no presenta alteraciones descriptibles con aparente compromiso madurativo compatible con la normalidad. No se detectan progenitores linfoides B. El patrón madurativo de la serie granulocítica presenta parones por acumulación compatibles con proceso SMD desde promielocito CD117-, siendo este m s evidente a nivel de mielocito. El patrón madurativo de la serie monocítica se encuentra alterado con elevación de formas inmaduras, al igual que ocurre con la serie roja analizada. Estudio compatible con proceso CRDM (Citopenia refractaria con displasia multilineal). Correlacionar con morfología y genética.': 'Leukocytic population analyzed. The following subpopulations are distinguished: 1. CD34+ progenitor cells (2.53%) - Myeloblasts (CD117+): 2.53% 2. Granulocytic-Neutrophil (50.28%) - Stage I+II (23.58%) - Stage III (56.88%) - Stage IV (6.9%) - Stage V (12.63%) 3. Monocytic (3.08%). 57.8% of the population consists of mature monocytes. 4. Erythroid (18.42%) 5. Lymphoid, the following subpopulations are distinguished: - T lymphocytes CD3+ (59.38%) - T lymphocytes CD4+ (58%) - T lymphocytes CD8+ (38.64%) - NK cells CD3- CD56+ (5.82%) - B lymphocytes CD19+ (31.99%) sIgKappa/sIgLambda polyclonal Conclusion: The frequency and phenotype of the myeloid progenitor population do not present describable alterations with apparent maturation compromise compatible with normality. B lymphoid progenitors are not detected. The maturation pattern of the granulocytic series presents pauses due to accumulation compatible with SMD process from CD117- promyelocyte, being more evident at the myelocyte level. The maturation pattern of the monocytic series is altered with elevation of immature forms, as occurs with the analyzed red series. Study compatible with CRDM process (Refractory cytopenia with multilineage dysplasia). Correlate with morphology and genetics.',
    'Se anula FISH dado que ni el estudio realizado, ni el diagnóstico de sospecha orientan hacia la utilización de una sonda específica. En caso de considerarse clinicamente indicada la realización de esta prueba en base a nuevos hallazgos clínicos, por favor, contactar con el laboratorio.': 'FISH cancelled since neither the study performed nor the suspected diagnosis guide towards the use of a specific probe. If clinically indicated based on new clinical findings, please contact the laboratory.',
    '46,XY': '46,XY',
    'Recuento manual: 27% seg, 64% linfo, 3% mono, 1% eos, 5% cay. Se visualizan linfocitos heterogéneos de aspecto estimulado. Elementos celulares con figuras apoptóticas. Neutrófilos vacuolados. Frotis sugestivo de proceso reactivo.': 'Manual differential: 27% segmented, 64% lymphocytes, 3% monocytes, 1% eosinophils, 5% cayocytes. Heterogeneous stimulated lymphocytes observed. Cellular elements with apoptotic figures. Vacuolated neutrophils. Smear suggestive of reactive process.',
    'Determinación realizada en N§ XXXXXXX': 'Determination performed on No. X',
    'Determinaciones realizadas en N§ XXXXXXX': 'Determinations performed on No. X',
    'Hipocromía moderada. Poiquilocitosis con presencia de frecuentes equinoitos, algún dianocito y eliptocito. Tendencia a rouleaux. Neutrófilos vacuolados con granulación tóxica.': 'Moderate hypochromia. Poikilocytosis with frequent acanthocytes, some dacrocytes and elliptocytes. Rouleaux formation tendency. Vacuolated neutrophils with toxic granulation.',
    'Recuento manual: 60% seg, 3% cay, 18% linfo, 19% mono. Se observan linfocitos de aspecto estimulado y neutrófilos vacuolados con refuerzo de la granulación.': 'Manual differential: 60% segmented, 3% cayocytes, 18% lymphocytes, 19% monocytes. Stimulated lymphocytes and vacuolated neutrophils with granulation reinforcement observed.',
    'Frotis sugestivo de proceso reactivo. En ausencia de causa secundaria se recomienda estudio hematológico.': 'Smear suggestive of reactive process. In the absence of a secondary cause, hematological study is recommended.',
    'MUESTRAS DILUIDAS, SE REQUIERE NUEVA MUESTRA': 'DILUTED SAMPLES, NEW SAMPLE REQUIRED',
    'MUESTRAS DILUIDAS': 'DILUTED SAMPLES', 
    'Población analizada: Linfocitaria (15.3%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (56.4%), 1094 cels/μL Linfocitos B sanos CD19+ CD20+ CD5- sIg Kappa/Lambda policlonal (2.85%), 55 cels/μL Linfocitos B clonales (27.2%), 528 cels/μL. Presentan el siguiente fenotipo CD19+low CD20+ CD5- CD11c- CD81+ CD200- CD38- FMC7- CD23- sIg Kappa- sIg Lambda+ Compatible con síndrome linfoproliferativo B': 'Population analyzed: Lymphocytic (15.3%). The following subpopulations are identified: CD3+ T lymphocytes (56.4%), 1094 cells/μL Healthy CD19+ CD20+ CD5- polyclonal sIg Kappa/Lambda B lymphocytes (2.85%), 55 cells/μL Clonal B lymphocytes (27.2%), 528 cells/μL. They present the following phenotype: CD19+low CD20+ CD5- CD11c- CD81+ CD200- CD38- FMC7- CD23- sIg Kappa- sIg Lambda+. Compatible with B lymphoproliferative syndrome.',
    'Población analizada: Linfocitaria (15.3%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (56.4%)': 'Population analyzed: Lymphocytic (15.3%). The following subpopulations are identified: CD3+ T lymphocytes (56.4%)',
    'anulada petición desde HOSMA': 'Request cancelled by HOSMA',
    'potasio comprobado en gasómetro': 'Potassium checked in blood gas analyzer',
    'Se visualizan neutrófilos vacuolados con granulación tóxica. Serie roja con hipocromía moderada, presencia de ovalocitos y eliptocitos. Macrotrombocitos con vacuolas en su interior.': 'Vacuolated neutrophils with toxic granulation observed. Red blood cells with moderate hypochromia, presence of ovalocytes and elliptocytes. Macrotrombocytes with vacuoles inside.',
    'Positivo (247.1)': 'Positive (247.1)',
    'Población analizada: Linfocitaria (46.86%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (76.59%), 375 cels/μL - Linfocitos T CD4+ (84.11%), 315 cels/μL - Linfocitos T CD8+ (11.61%), 43 cels/μL Linfocitos B CD19+ CD20+ (4.40%), 21 cels/μL Linfocitos NK T CD3+ CD56+ (5.52%), 27 cels/μL Células NK CD3- CD56+ (12.45%), 61 cels/μL': 'Population analyzed: Lymphocytic (46.86%). The following subpopulations are identified: CD3+ T lymphocytes (76.59%), 375 cells/μL - CD4+ T lymphocytes (84.11%), 315 cells/μL - CD8+ T lymphocytes (11.61%), 43 cells/μL CD19+ CD20+ B lymphocytes (4.40%), 21 cells/μL CD3+ CD56+ NK T lymphocytes (5.52%), 27 cells/μL CD3- CD56+ NK cells (12.45%), 61 cells/μL',
    'Hipocromía moderada. Se observan frecuentes dianocitos y algún eliptocito. Desviación izquierda con refuerzo de la granulación en neutrófilos.': 'Moderate hypochromia. Frequent dacrocytes and some elliptocytes observed. Left shift with granulation reinforcement in neutrophils.',
    'Serie roja con hipocromía leve, frecuentes macrovalocitos. Se observan desviación izquierda y neutrófilos con refuerzo en la granulación.Trombopenia comprobada.': 'Red blood cells with mild hypochromia, frequent macroovalocytes. Left shift and neutrophils with granulation reinforcement observed. Confirmed thrombocytopenia.',
    'Serie roja con hipocromía leve': 'Red blood cells with mild hypochromia',
    'Población analizada: Linfocitaria (20.7%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (73.6%)': 'Population analyzed: Lymphocytic (20.7%). The following subpopulations are identified: CD3+ T lymphocytes (73.6%)', 
    'Población analizada: Linfocitaria (20.7%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (73.6%), 714 cels/μL - Linfocitos T CD4+ (76.95%), 549 cels/μL - Linfocitos T CD8+ (17.28%), 123 cels/μL Linfocitos B CD19+ CD20+ (4.82%), 47 cels/μL Linfocitos NK T CD3+ CD56+ (7.70%), 75 cels/μL Células NK CD3- CD56+ (12.31%), 119 cels/μL': 'Population analyzed: Lymphocytic (20.7%). The following subpopulations are identified: CD3+ T lymphocytes (73.6%), 714 cells/μL - CD4+ T lymphocytes (76.95%), 549 cells/μL - CD8+ T lymphocytes (17.28%), 123 cells/μL CD19+ CD20+ B lymphocytes (4.82%), 47 cells/μL CD3+ CD56+ NK T lymphocytes (7.70%), 75 cells/μL CD3- CD56+ NK cells (12.31%), 119 cells/μL',
    'Población analizada: Linfocitaria (30.66%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (75.9%), 486 cels/μL - Linfocitos T CD4+ (81.7%), 397 cels/μL - Linfocitos T CD8+ (14.7%), 71 cels/μL Linfocitos B CD19+ CD20+ (8.9%), 57 cels/μL Linfocitos NK T CD3+ CD56+ (5.30%), 34 cels/μL Células NK CD3- CD56+ (6.1%), 39 cels/μL': 'Population analyzed: Lymphocytic (30.66%). The following subpopulations are identified: CD3+ T lymphocytes (75.9%), 486 cells/μL - CD4+ T lymphocytes (81.7%), 397 cells/μL - CD8+ T lymphocytes (14.7%), 71 cells/μL CD19+ CD20+ B lymphocytes (8.9%), 57 cells/μL CD3+ CD56+ NK T lymphocytes (5.30%), 34 cells/μL CD3- CD56+ NK cells (6.1%), 39 cells/μL',
    'Población analizada: Linfocitaria (30.66%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (75.9%)': 'Population analyzed: Lymphocytic (30.66%). The following subpopulations are identified: CD3+ T lymphocytes (75.9%)',
    'Población analizada: Linfocitaria (17%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (77.89%), 934 cels/μL - Linfocitos T CD4+ (81.98%), 766 cels/μL - Linfocitos T CD8+ (13.95%), 130 cels/μL Linfocitos B CD19+ CD20+ (5.29%), 63 cels/μL Linfocitos NK T CD3+ CD56+ (5.66%), 67 cels/μL Células NK CD3- CD56+ 10.75(%), 129 cels/μL': 'Population analyzed: Lymphocytic (17%). The following subpopulations are identified: CD3+ T lymphocytes (77.89%), 934 cells/μL - CD4+ T lymphocytes (81.98%), 766 cells/μL - CD8+ T lymphocytes (13.95%), 130 cells/μL CD19+ CD20+ B lymphocytes (5.29%), 63 cells/μL CD3+ CD56+ NK T lymphocytes (5.66%), 67 cells/μL CD3- CD56+ NK cells (10.75%), 129 cells/μL',
    'Población analizada: Linfocitaria (17%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (77.89%)': 'Population analyzed: Lymphocytic (17%). The following subpopulations are identified: CD3+ T lymphocytes (77.89%)',
    'Población analizada: Linfocitaria (46.86%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (76.59%)': 'Population analyzed: Lymphocytic (46.86%). The following subpopulations are identified: CD3+ T lymphocytes (76.59%)',
    'Población analizada: Linfocitaria (3.66%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (63.08%), 290 cels/μL - Linfocitos T CD4+ (83.99%), 244 cels/μL - Linfocitos T CD8+ (13.13%), 38 cels/μL Linfocitos B CD19+ CD20+ (13.13%), 60 cels/μL Linfocitos NK T CD3+ CD56+ (1.44%), 6 cels/μL Células NK CD3- CD56+ (18.33%), 84 cels/μL': 'Population analyzed: Lymphocytic (3.66%). The following subpopulations are identified: CD3+ T lymphocytes (63.08%), 290 cells/μL - CD4+ T lymphocytes (83.99%), 244 cells/μL - CD8+ T lymphocytes (13.13%), 38 cells/μL CD19+ CD20+ B lymphocytes (13.13%), 60 cells/μL CD3+ CD56+ NK T lymphocytes (1.44%), 6 cells/μL CD3- CD56+ NK cells (18.33%), 84 cells/μL',
    'Rogamos envíen nueva muestra para realizar bioquímica completa': 'Please send a new sample for complete biochemistry testing',
    'En ausencia de causa secundaria se recomienda seguimiento hematológico.': 'In the absence of secondary cause, hematological follow-up is recommended.',
    'Fórmula de investigación pendiente de confirmar por hematólogo': 'Investigational formula pending confirmation by hematologist',
    'Recuento manual: 18% seg, 3% cay, 78% linfo, 1% mono. Linfocitosis heterogénea con linfocitos de aspecto estimulado, de citoplasma basófilos y algunos con vacuolas citoplasm ticas.': 'Manual count: 18% seg, 3% cay, 78% linfo, 1% mono. Heterogeneous lymphocytosis with stimulated lymphocytes, basophilic cytoplasm, and some with cytoplasmic vacuoles.',
    'Se observa desviación izquierda, con presencia de neutrófilos vacuolados. Se visualizan linfocitos de aspecto activado y monocitos con múltiples vacuolas citoplasm ticas.': 'Left shift observed, with presence of vacuolated neutrophils. Activated lymphocytes and monocytes with multiple cytoplasmic vacuoles observed.',
    'Marcada anisopoiquilocitosis con hipocromía': 'Marked anisopoikilocytosis with hypochromia', 
    'Marcada anisopoiquilocitosis con hipocromía , presencia de eliptocitos , dacriocitos y esquistocitos. Descartar ferronpenia como primera posibilidad.': 'Marked anisopoikilocytosis with hypochromia, presence of elliptocytes, dacryocytes, and schistocytes. Rule out iron deficiency as the first possibility.',
    'En la serie roja se observa anisopoiquilocitosis con hipocromía, presencia de eliptocitos y esquistocitos.': 'The red cell series shows anisopoikilocytosis with hypochromia, presence of elliptocytes and schistocytes.',
    'Fórmula manual: segmentados 73%': 'Manual differential: segmented neutrophils 73%',
    'Positivo. Se observan una banda correspondiente a la proteína C1 y otra débil correspondiente a la proteína NS3': 'Positive. Bands corresponding to protein C1 and a weak band corresponding to protein NS3 are observed.',
    'Fórmula manual: segmentados 60%; linfocitos 31%; monocitos 3%; eosinófilos 6%; basófilos 0%.': 'Manual differential: segmented neutrophils 60%; lymphocytes 31%; monocytes 3%; eosinophils 6%; basophils 0%.',
    'No se realiza serología IgG e IgM COVID a pacientes ingresados': 'COVID IgG and IgM serology is not performed for hospitalized patients.',
    'Población analizada: Linfocitaria (3.66%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (63.08%)': 'Population analyzed: Lymphocytic (3.66%). The following subpopulations are identified: CD3+ T lymphocytes (63.08%)',
    'Población analizada: Linfocitaria (9.71%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (80.34%)': 'Population analyzed: Lymphocytic (9.71%). The following subpopulations are identified: CD3+ T lymphocytes (80.34%)',
    'Población analizada: Linfocitaria (9.71%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (80.34%), 570 cels/μL - Linfocitos T CD4+ (91.74%), 523 cels/μL - Linfocitos T CD8+ (7.25%), 41 cels/μL Linfocitos B CD19+ CD20+ (11.6%), 82 cels/μL Linfocitos NK T CD3+ CD56+ (1.3%), 9 cels/μL Células NK CD3- CD56+ (4.49%), 32 cels/μL': 'Population analyzed: Lymphocytic (9.71%). The following subpopulations are identified: CD3+ T lymphocytes (80.34%), 570 cells/μL - CD4+ T lymphocytes (91.74%), 523 cells/μL - CD8+ T lymphocytes (7.25%), 41 cells/μL CD19+ CD20+ B lymphocytes (11.6%), 82 cells/μL CD3+ CD56+ NK T lymphocytes (1.3%), 9 cells/μL CD3- CD56+ NK cells (4.49%), 32 cells/μL',
    'Población analizada: Linfocitaria (4.07%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (72.05%)': 'Population analyzed: Lymphocytic (4.07%). The following subpopulations are identified: CD3+ T lymphocytes (72.05%)',
    'Población analizada: Linfocitaria (4.07%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (72.05%), 367 cels/μL - Linfocitos T CD4+ (90.5%), 332 cels/μL - Linfocitos T CD8+ (8.2%), 30 cels/μL Linfocitos B CD19+ CD20+ (16.25%), 83 cels/μL Linfocitos NK T CD3+ CD56+ (1.20%), 6 cels/μL Células NK CD3- CD56+ (5.51%), 28 cels/μL': 'Population analyzed: Lymphocytic (4.07%). The following subpopulations are identified: CD3+ T lymphocytes (72.05%), 367 cells/μL - CD4+ T lymphocytes (90.5%), 332 cells/μL - CD8+ T lymphocytes (8.2%), 30 cells/μL CD19+ CD20+ B lymphocytes (16.25%), 83 cells/μL CD3+ CD56+ NK T lymphocytes (1.20%), 6 cells/μL CD3- CD56+ NK cells (5.51%), 28 cells/μL',
    'Serie roja con rouleaux e hipocromía leve': 'Red cell series with rouleaux formation and mild hypochromia', 
    'Serie roja con rouleaux e hipocromía leve, presencia de macrovalocitos. Se observa desviación izquierda.': 'Red cell series with rouleaux formation and mild hypochromia, presence of macrocytes. Left shift is observed.',
    'Población analizada: Linfocitaria (11.36%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (72.46%)': 'Population analyzed: Lymphocytic (11.36%). The following subpopulations are identified: CD3+ T lymphocytes (72.46%)',
    'Población analizada: Linfocitaria (11.36%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (72.46%), 587 cels/μL - Linfocitos T CD4+ (80.31%), 471 cels/μL - Linfocitos T CD8+ (18.36%), 108 cels/μL Linfocitos B CD19+ CD20+ (6.79%), 55 cels/μL Linfocitos NK T CD3+ CD56+ (2.11%), 17 cels/μL Células NK CD3- CD56+low (16.84%), 136 cels/μL': 'Population analyzed: Lymphocytic (11.36%). The following subpopulations are identified: CD3+ T lymphocytes (72.46%), 587 cells/μL - CD4+ T lymphocytes (80.31%), 471 cells/μL - CD8+ T lymphocytes (18.36%), 108 cells/μL CD19+ CD20+ B lymphocytes (6.79%), 55 cells/μL CD3+ CD56+ NK T lymphocytes (2.11%), 17 cells/μL CD3- CD56+low NK cells (16.84%), 136 cells/μL',
    'Población analizada: Linfocitaria (13.71%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (72.53%)': 'Population analyzed: Lymphocytic (13.71%). The following subpopulations are identified: CD3+ T lymphocytes (72.53%)',
    'Población analizada: Linfocitaria (13.71%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (72.53%), 820 cels/μL - Linfocitos T CD4+ (79.72%), 653 cels/μL - Linfocitos T CD8+ (18.92%), 155 cels/μL Linfocitos B CD19+ CD20+ (7.94%), 90 cels/μL Linfocitos NK T CD3+ CD56+ (2.93%), 33 cels/μL Células NK CD3- CD56+low (14.53%), 164 cels/μL': 'Population analyzed: Lymphocytic (13.71%). The following subpopulations are identified: CD3+ T lymphocytes (72.53%), 820 cells/μL - CD4+ T lymphocytes (79.72%), 653 cells/μL - CD8+ T lymphocytes (18.92%), 155 cells/μL CD19+ CD20+ B lymphocytes (7.94%), 90 cells/μL CD3+ CD56+ NK T lymphocytes (2.93%), 33 cells/μL CD3- CD56+low NK cells (14.53%), 164 cells/μL',
    'Población analizada: Linfocitaria (12.83%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (69.43%)': 'Population analyzed: Lymphocytic (12.83%). The following subpopulations are identified: CD3+ T lymphocytes (69.43%)',
    'Población analizada: Linfocitaria (12.83%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (69.43%), 507 cels/μL - Linfocitos T CD4+ (77.65%), 394 cels/μL - Linfocitos T CD8+ (20.47%), 103 cels/μL Linfocitos B CD19+ CD20+ (6.13%), 45 cels/μL Linfocitos NK T CD3+ CD56+ (1.64%), 12 cels/μL Células NK CD3- CD56+low (20.24%), 148 cels/μL': 'Population analyzed: Lymphocytic (12.83%). The following subpopulations are identified: CD3+ T lymphocytes (69.43%), 507 cells/μL - CD4+ T lymphocytes (77.65%), 394 cells/μL - CD8+ T lymphocytes (20.47%), 103 cells/μL CD19+ CD20+ B lymphocytes (6.13%), 45 cells/μL CD3+ CD56+ NK T lymphocytes (1.64%), 12 cells/μL CD3- CD56+low NK cells (20.24%), 148 cells/μL',
    'Población analizada: Linfocitaria (24.9%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (76.8%), 2135 cels/μL - Linfocitos T CD4+ (81.64%), 1743 cels/μL - Linfocitos T CD8+ (16.62%), 355 cels/μL Linfocitos B CD19+ CD20+ (13.3%), 370 cels/μL Linfocitos NK T CD3+ CD56+ (1.17%), 32 cels/μL Células NK CD3- CD56+ (8.65%), 240 cels/μL': 'Population analyzed: Lymphocytic (24.9%). The following subpopulations are identified: CD3+ T lymphocytes (76.8%), 2135 cells/μL - CD4+ T lymphocytes (81.64%), 1743 cells/μL - CD8+ T lymphocytes (16.62%), 355 cells/μL CD19+ CD20+ B lymphocytes (13.3%), 370 cells/μL CD3+ CD56+ NK T lymphocytes (1.17%), 32 cells/μL CD3- CD56+ NK cells (8.65%), 240 cells/μL',
    'Población analizada: Linfocitaria (14.88%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (74.83%), 1512 cels/μL - Linfocitos T CD4+ (82.47%), 1246 cels/μL - Linfocitos T CD8+ (16.01%), 242 cels/μL Linfocitos B CD19+ CD20+ (14.27%), 288 cels/μL Linfocitos NK T CD3+ CD56+ (1.45%), 29 cels/μL Células NK CD3- CD56+low (8.14%), 164 cels/μL': 'Population analyzed: Lymphocytic (14.88%). The following subpopulations are identified: CD3+ T lymphocytes (74.83%), 1512 cells/μL - CD4+ T lymphocytes (82.47%), 1246 cells/μL - CD8+ T lymphocytes (16.01%), 242 cells/μL CD19+ CD20+ B lymphocytes (14.27%), 288 cells/μL CD3+ CD56+ NK T lymphocytes (1.45%), 29 cells/μL CD3- CD56+low NK cells (8.14%), 164 cells/μL', 
    'Procesado en petición XXXXXXX': 'In request',
    'Recuento manual: 88% seg, 7% cay, 1% linfo, 4% mono. Refuerzo de la granulación neutrofílica e hipersegmentación nuclear.': 'Manual count: 88% segmented, 7% band, 1% lymphocytes, 4% monocytes. Neutrophil granulation reinforcement and nuclear hypersegmentation.',
    'No remite muestra de BAS': 'No BAS sample sent',
    'Leucocitosis con desviación izquierda. Neutrófilos vacuolados. Se visualizan varios macrotrombocitos. Frotis sugestivo de proceso reactivo.': 'Leukocytosis with left shift. Vacuolated neutrophils. Several macrothrombocytes observed. Smear suggestive of reactive process.',
    'Fórmula manual: segmentados 56%': 'Manual differential: 56% segmented neutrophils',
    'Recuento manual: 34% seg, 25% cay, 40% linfo, 1% mono. Anisopoiquilocitosis marcada con eliptocitos, acantocitos y algún equinocito. Neutrófilos hipogranulares vacuolados. Linfocitos estimulados y algún linfocito hendido.': 'Manual count: 34% segmented neutrophils, 25% band neutrophils, 40% lymphocytes, 1% monocytes. Marked anisopoikilocytosis with elliptocytes, acanthocytes, and some echinocytes. Hypogranular vacuolated neutrophils. Stimulated lymphocytes and occasional cleaved lymphocytes.',
    'Positivo (631.1)': 'Positive (631.1)',
    'Se observan neutrófilos con refuerzo en la granulación. Desviación izquierda.': 'Neutrophils with granulation reinforcement observed. Left shift.',
    'Los coronavirus son una extensa familia de virus que pueden causar infecciones respiratorias. El coronavirus que se ha descubierto m s recientemente causa la enfermedad por coronavirus COVID-19. Los síntomas m s comunes de la COVID-19 son fiebre': 'Coronaviruses are a large family of viruses that can cause respiratory infections. The most recently discovered coronavirus causes coronavirus disease COVID-19. The most common symptoms of COVID-19 are fever.',
    'Exudado Faríngeo/Nasofaríngeo': 'Pharyngeal/Nasopharyngeal exudate',
    'Consultar con su médico para una correcta interpretación del resultado.': 'Consult with your doctor for a correct interpretation of the result.',
    'An lisis cualitativo por Real-Time PCR (RT-PCR) para la detección de ARN del virus 2019-nCoV.': 'Qualitative analysis by Real-Time PCR (RT-PCR) for the detection of 2019-nCoV virus RNA.',
    'An lisis cualitativo por Real-Time PCR (RT-PCR) para la detección de ARN del virus 2019-nCov.': 'Qualitative analysis by Real-Time PCR (RT-PCR) for the detection of 2019-nCoV virus RNA.',
    'No remite muestra de esputo': 'No sputum sample sent',
    'Se observa anisopoiquilocitosis, hipocromía, frecuentes ovalocitos, algún esquistocito en proporción no significativa. Neutrófilos con refuerzo en la granulación.': 'Anisopoikilocytosis observed, hypochromia, frequent ovalocytes, some schistocytes in non-significant proportion. Neutrophils with granulation reinforcement.',
    'Recuento manual: 72% seg, 1% eos, 6% cay, 17% linfo, 4% mono. Trombopenia y neutropenia comprobadas. No se visualizan céluals de h bito bl stico. Refuerzo de la granulación neutrofílica.': 'Manual count: 72% segmented neutrophils, 1% eosinophils, 6% band neutrophils, 17% lymphocytes, 4% monocytes. Confirmed thrombocytopenia and neutropenia. No blasts visualized. Neutrophil granulation reinforcement.',
    'Prefiltro': 'Prefilter',
    'Se observa desviación izquierda. Se observan algunos segmentados degranulados.': 'Left shift observed. Some degranulated segmented neutrophils seen.',
    'CA++  POSTFILTRO': 'CA++ post-filter', 
    'CA POSTFILTRO': 'CA POST-FILTER',
    'CA++ POSTFILTRO': 'CA++ POST-FILTER',
    'HERIDA SACRA': 'Sacral wound',
    'Post-filtro': 'Post-filter',
    'Procesada en petición XXXXXXX': 'Processed under request X',
    'Recuento manual: 65% seg, 8% cay, 11% linfo, 12% mono, 3% eos, 1% baso. No se observan alteraciones morfológicas.': 'Manual count: 65% segmented neutrophils, 8% band neutrophils, 11% lymphocytes, 12% monocytes, 3% eosinophils, 1% basophils. No morphological alterations observed.',
    'Serie roja con doble población de hematíes, hipocromos y policrom ticos. Frecuentes ovalocitos. Presencia de linfocitos activados.': 'Red cell series with double population of hypochromic and polychromatic erythrocytes. Frequent ovalocytes. Presence of activated lymphocytes.',
    'Serie roja con doble población de hematíes': 'Red cell series with double population of erythrocytes',
    'Prueba ya solicitada en fecha XXXX-XX-XX en muestra XXXXXXX': 'Test already requested',
    'IL-6 = 47.84 pg/mL (VR <7.0)': 'IL-6 = 47.84 pg/mL (Reference value <7.0)',
    'Discreta microcitosis': 'Mild microcytosis',
    'No se detectan (0.1)': 'Not detected (0.1)',
    'No se observan agregados plaquetarios. Algunas plaquetas de gran talla.': 'No platelet aggregates observed. Some large platelets.',
    'Recuento manual: 54% seg, 40% cay, 3% metamielocitos, 1% mono 2% linfo.': 'Manual count: 54% segmented neutrophils, 40% band neutrophils, 3% metamyelocytes, 1% monocytes, 2% lymphocytes.',
    'Recuento manual: 54% seg': 'Manual count: 54% segmented neutrophils',
    'Positivo (47.97)': 'Positive (47.97)',
    'drenaje': 'drainage',
    'LIQUIDO PERITONEAL': 'Peritoneal fluid',
    'DRENAJE': 'Drainage',
    '0 parameters': '0 parameters', 
    'Positivo (76.0)': 'Positive (76.0)',
    'Negativo (5.78)': 'Negative (5.78)',
    'Negativo (4.6)': 'Negative (4.6)',
    'Frotis informado en muestra No. XXXXXXX': 'Smear reported in sample No. X',
    'Recuento manual: 78% seg': 'Manual count: 78% segmented neutrophils',
    '> 6.0 suero hemolizado': '> 6.0 hemolyzed serum',
    'Positivo (411.7)': 'Positive (411.7)',
    'Positivo (174.6)': 'Positive (174.6)',
    'Se observan 2 eritroblastos/100 leucocitos': '2 erythroblasts observed/100 leukocytes',
    'Fragments?': 'Fragments?',
    'Sistematico de orina dentro de la normalidad, no procede realizar sedimento urinario': 'Systemic urine within normal limits, no need to perform urine sediment',
    'Se observan dos poblaciones de hematíes': 'Two populations of erythrocytes observed',
    'Se observan dos poblaciones de hematíes, hipocromía y policromasia. Presencia de macrotrombocitos con dilataciones vacuolares en su interior.': 'Two populations of erythrocytes, hypochromia and polychromasia observed. Presence of macrothrombocytes with vacuolar dilations inside.',
    'Se observan linfocitos de aspecto estimulado y algún linfocito grande granular. Trombopenia comprobada.': 'Stimulated lymphocytes and some large granular lymphocytes observed. Confirmed thrombocytopenia.',
    'Recuento manual: 54% seg, 22% linfo, 1% LGG, 8% Mono, 15% cay. Se visualiza refuerzo de la granulación en neutrófilos. Varios linfocitos de aspecto activado.': 'Manual count: 54% segmented neutrophils, 22% lymphocytes, 1% large granular lymphocytes, 8% monocytes, 15% band neutrophils. Granulation reinforcement observed in neutrophils. Several activated lymphocytes.',
    'Se observan desviación izquierda, presencia de neutrófilos con refuerzo de la granulación. Serie roja con anisocitosis y anisocromía, se ven algunos dianocitos y abundantes hematíes hipocromos. Trombocitosis comprobada sin dismorfias.': 'Left shift observed, presence of neutrophils with granulation reinforcement. Red cell series with anisocytosis and anisochromia, some dianocytes and abundant hypochromic erythrocytes seen. Confirmed thrombocytosis without dysmorphic features.',
    'Fórmula manual: segmentados 66%': 'Manual count: 66% segmented', 
    'Fórmula manual: segmentados 60%': 'Manual count: 66% segmented',
    'Se observan neutrófilos con refuerzo en la granulación. Presencia de agregados plaquetarios.': 'Neutrophils with granulation reinforcement observed. Presence of platelet aggregates.',
    'Se observa anisopoiquilocitosis con hipocromía': 'Anisopoikilocytosis observed with hypochromia',
    'Se observa anisopoiquilocitosis con hipocromía, frecuentes dacriocitos y eliptocitos y algunos eritroblastos ortocrotm ticos. Se observa desviación izquierda. Recuento manual: 44%seg, 16% cay, 2% metamielo, 28% linfo, 3% LGG, 6% mono.': 'Anisopoikilocytosis observed with hypochromia, frequent dacryocytes and elliptocytes, and some orthochromatic erythroblasts. Left shift observed. Manual count: 44% segmented neutrophils, 16% lymphocytes, 2% metamyelocytes, 28% lymphocytes, 3% large granular lymphocytes (LGG), 6% monocytes.',
    'Recuento manual: 89% seg, 7% cay, 1% metamielocito, 2% linfo. Se visualizan neutrófilos vacuolados con intenso refuerzo de la granulación.': 'Manual count: 89% segmented neutrophils, 7% lymphocytes, 1% metamyelocyte, 2% lymphocytes. Vacuolated neutrophils with intense granulation reinforcement observed.',
    'Se observa anisopoiquilocitosis, con presencia de algunos queratocitos, dianocitos y equinocitos. Neutrófilos vacuolados.': 'Anisopoikilocytosis observed, with presence of some keratocytes, dianocytes, and echinocytes. Vacuolated neutrophils.',
    'en muestra XXXXXXX': 'in sample X',
    'Se envía al Ramón y Cajal': 'Sent to Ramón y Cajal (hospital/research center)',
    'Se observan linfocitos de aspecto estimulado. Neutrófilos vacuolados. Serie roja no valorable por artefacto en la muestra.': 'Stimulated lymphocytes observed. Vacuolated neutrophils. Red cell series not assessable due to artifact in the sample.',
    'Fórmula comprobada. No se visualizan células de h bito bl stico, se ven algunos neutrófilos vacuolados. En ausencia de causa secundaria se recomienda estudio hematológico.': 'Confirmed formula. No blasts visualized, some vacuolated neutrophils observed. In the absence of a secondary cause, hematologic study is recommended.',
    'Población analizada: Linfocitaria (4.5%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (61%), 543 cels/μL - Linfocitos T CD4+ (44.4%), 241 cels/μL - Linfocitos T CD8+ (52.5%), 285 cels/μL Linfocitos B CD19+ (23.2%), 206 cels/μL Células NK totales (9.15%), 81 cels/μL': 'Population analyzed: Lymphocytic (4.5%). The following subpopulations are identified: T lymphocytes CD3+ (61%), 543 cells/μL - T lymphocytes CD4+ (44.4%), 241 cells/μL - T lymphocytes CD8+ (52.5%), 285 cells/μL - B lymphocytes CD19+ (23.2%), 206 cells/μL - Total NK cells (9.15%), 81 cells/μL',
    'DD ERROR. SE RUEGA ENVÍEN NUEVA MUESTRA.': 'DD ERROR. Please send a new sample.',
    'Neutrófilos vacuolados con refuerzo de la granulación. Serie roja con hipocromía con hipocromía.': 'Vacuolated neutrophils with granulation reinforcement. Red cell series with hypochromia.',
    'Se observan linfocitos de aspecto estimulado y desviación izquierda. Trombopenia comprobada, sin agregados plaquetarios.': 'Stimulated lymphocytes observed with left shift. Confirmed thrombocytopenia, no platelet aggregates.',
    'Presencia de agregados plaquetarios. Se visualizan neutrófilos vacuolados y linfocitos de aspecto activado.': 'Presence of platelet aggregates. Vacuolated neutrophils and activated lymphocytes observed.',
    'Se recomienda remitir nueva muestra para comprobar resultados': 'A new sample is recommended to verify results', 
    'Recuento manual: 85% seg, 1% eos, 7% linfo, 1% mono, 6% cay. Se observan neutrofilos con refuerzo de la granulación y varios linfocitos de aspecto activado.': 'Manual count: 85% segmented neutrophils, 1% eosinophils, 7% lymphocytes, 1% monocytes, 6% mononuclear cells. Neutrophils observed with granulation reinforcement and several activated lymphocytes.',
    'Se visualizan agregados plaquetarios, por lo que la cifra de plaquetas puede estar infraestimada. Se observa algún linfocito de aspecto activado.': 'Platelet aggregates observed, so the platelet count may be underestimated. Some activated lymphocytes observed.',
    'Población analizada: Linfocitaria (5.63%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (59.48%)': 'Population analyzed: Lymphocytic (5.63%). The following subpopulations are identified: T lymphocytes CD3+ (59.48%)',
    'POST- FILTRO': 'POST-FILTER',
    'Población analizada: Linfocitaria (5.63%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (59.48%), 380 cels/μL - Linfocitos T CD4+ (49.18%), 187 cels/μL - Linfocitos T CD8+ (47.24%), 179 cels/μL Linfocitos B CD19+ CD20+ (10.08%), 64 cels/μL Linfocitos NK T CD3+ CD56+ (6.98%), 45 cels/μL Células NK CD3- CD56+ (18.09%), 116 cels/μL': 'Population analyzed: Lymphocytic (5.63%). The following subpopulations are identified: T lymphocytes CD3+ (59.48%), 380 cells/μL - T lymphocytes CD4+ (49.18%), 187 cells/μL - T lymphocytes CD8+ (47.24%), 179 cells/μL - B lymphocytes CD19+ CD20+ (10.08%), 64 cells/μL - NK T cells CD3+ CD56+ (6.98%), 45 cells/μL - NK cells CD3- CD56+ (18.09%), 116 cells/μL',
    'Serie roja con anisopoiquilocitosis e hipocromía': 'Red cell series with anisopoikilocytosis and hypochromia',
    'MUESTRAS COAGULADA': 'CLOTTED SAMPLES',
    'Se observan neutrófilos con refuerzo en la granulación y algunos linfocitos de aspecto activado. Resto de series sin alteraciones.': 'Neutrophils observed with granulation reinforcement and some activated lymphocytes. Other series without alterations.',
    'Serie roja con hipocromía y anisocitosis lves. Se observan linfocitos de aspecto activado, neutrófilos con hipersegmentación nuclear y refuerzo de la granulación. Trombopenia comprobada.': 'Red cell series with hypochromia and mild anisocytosis. Activated lymphocytes observed, neutrophils with nuclear hypersegmentation and granulation reinforcement. Confirmed thrombocytopenia.',
    'Serie roja con hipocromía y anisocitosis lves. Se observan linfocitos de aspecto activado': 'Red cell series with hypochromia and mild anisocytosis. Activated lymphocytes observed.',
    'Resultados comprobados. Se recomienda enviar nueva muestra para comprobar resultados': 'Results confirmed. It is recommended to send a new sample to verify results.',
    'CANCELADO POR ERROR PETICIONARIO': 'CANCELLED DUE TO REQUESTER ERROR',
    'Neutrófilos vacuolados con refuerzo de la granulación. Policromasia, frecuentes ovalocitos y equinocitos. Se observan linfocitos activados.': 'Vacuolated neutrophils with granulation reinforcement. Polychromasia, frequent ovalocytes and echinocytes observed. Activated lymphocytes observed.',
    'Se recomienda extracción venosa para comprobar resultados': 'Venous extraction recommended to verify results', 
    'Población analizada: Linfocitaria (7.14%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (64.85%)': 'Population analyzed: Lymphocytic (7.14%). The following subpopulations are identified: T lymphocytes CD3+ (64.85%)',
    'Población analizada: Linfocitaria (7.14%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (64.85%), 376 cels/μL - Linfocitos T CD4+ (50.56%), 190 cels/μL - Linfocitos T CD8+ (46.49%), 175cels/μL Linfocitos B CD19+ CD20+ (12.14%), 845 cels/μL Linfocitos NK T CD3+ CD56+ (5.97%), 34 cels/μL Células NK CD3- CD56+ (12.84%), 74 cels/μL': 'Population analyzed: Lymphocytic (7.14%). The following subpopulations are identified: T lymphocytes CD3+ (64.85%), 376 cells/μL - T lymphocytes CD4+ (50.56%), 190 cells/μL - T lymphocytes CD8+ (46.49%), 175 cells/μL - B lymphocytes CD19+ CD20+ (12.14%), 845 cells/μL - NK T cells CD3+ CD56+ (5.97%), 34 cells/μL - NK cells CD3- CD56+ (12.84%), 74 cells/μL',
    'Población analizada: Linfocitaria (11.3%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (68.6%)': 'Population analyzed: Lymphocytic (11.3%). The following subpopulations are identified: T lymphocytes CD3+ (68.6%)',
    'Población analizada: Linfocitaria (11.3%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (68.6%), 679 cels/μL - Linfocitos T CD4+ (59.03%), 401 cels/μL - Linfocitos T CD8+ (38.16%), 259 cels/μL Linfocitos B CD19+ CD20+ (12.06%), 119 cels/μL Linfocitos NK T CD3+ CD56+ (5.3%), 52 cels/μL Células NK CD3- CD56+ (11.27%), 111 cels/μL': 'Population analyzed: Lymphocytic (11.3%). The following subpopulations are identified: T lymphocytes CD3+ (68.6%), 679 cells/μL - T lymphocytes CD4+ (59.03%), 401 cells/μL - T lymphocytes CD8+ (38.16%), 259 cells/μL - B lymphocytes CD19+ CD20+ (12.06%), 119 cells/μL - NK T cells CD3+ CD56+ (5.3%), 52 cells/μL - NK cells CD3- CD56+ (11.27%), 111 cells/μL',
    'Población analizada: Linfocitaria (6.4%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (61.6%)': 'Population analyzed: Lymphocytic (6.4%). The following subpopulations are identified: T lymphocytes CD3+ (61.6%)',
    'Población analizada: Linfocitaria (6.4%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (61.6%), 308 cels/μL - Linfocitos T CD4+ (53.16%), 163 cels/μL - Linfocitos T CD8+ (44.07%), 136 cels/μL Linfocitos B CD19+ CD20+ (14.97%), 75 cels/μL Linfocitos NK T CD3+ CD56+ (5.45%), 27 cels/μL Células NK CD3- CD56+ (13.77%), 69 cels/μL': 'Population analyzed: Lymphocytic (6.4%). The following subpopulations are identified: T lymphocytes CD3+ (61.6%), 308 cells/μL - T lymphocytes CD4+ (53.16%), 163 cells/μL - T lymphocytes CD8+ (44.07%), 136 cells/μL - B lymphocytes CD19+ CD20+ (14.97%), 75 cells/μL - NK T cells CD3+ CD56+ (5.45%), 27 cells/μL - NK cells CD3- CD56+ (13.77%), 69 cells/μL',
    'Población analizada: Linfocitaria (12.6%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (74.93%)': 'Population analyzed: Lymphocytic (12.6%). The following subpopulations are identified: T lymphocytes CD3+ (74.93%)',
    'Población analizada: Linfocitaria (12.6%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (74.93%), 749 cels/μL - Linfocitos T CD4+ (78.21%), 465 cels/μL - Linfocitos T CD8+ (19.16%), 264 cels/μL Linfocitos B CD19+ CD20+ (10.53%), 105 cels/μL Linfocitos NK T CD3+ CD56+ (3.49%), 35 cels/μL Células NK CD3- CD56+ (8.43%), 84 cels/μL': 'Population analyzed: Lymphocytic (12.6%). The following subpopulations are identified: T lymphocytes CD3+ (74.93%), 749 cells/μL - T lymphocytes CD4+ (78.21%), 465 cells/μL - T lymphocytes CD8+ (19.16%), 264 cells/μL - B lymphocytes CD19+ CD20+ (10.53%), 105 cells/μL - NK T cells CD3+ CD56+ (3.49%), 35 cells/μL - NK cells CD3- CD56+ (8.43%), 84 cells/μL',
    'Población analizada: Linfocitaria (7.8%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (70.38%)': 'Population analyzed: Lymphocytic (7.8%). The following subpopulations are identified: T lymphocytes CD3+ (70.38%)',
    'Población analizada: Linfocitaria (7.8%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (70.38%), 500 cels/μL - Linfocitos T CD4+ (59.21%), 296 cels/μL - Linfocitos T CD8+ (38%), 190 cels/μL Linfocitos B CD19+ CD20+ (13.9%), 99 cels/μL Linfocitos NK T CD3+ CD56+ (4.88%), 34 cels/μL Células NK CD3- CD56+ (8.22%), 58 cels/μL': 'Population analyzed: Lymphocytic (7.8%). The following subpopulations are identified: T lymphocytes CD3+ (70.38%), 500 cells/μL - T lymphocytes CD4+ (59.21%), 296 cells/μL - T lymphocytes CD8+ (38%), 190 cells/μL - B lymphocytes CD19+ CD20+ (13.9%), 99 cells/μL - NK T cells CD3+ CD56+ (4.88%), 34 cells/μL - NK cells CD3- CD56+ (8.22%), 58 cells/μL',
    'Se observan linfocitos de aspecto estimulado y neutrófilos vacuolados con refuerzo de granulación. Hipocromía.': 'Activated lymphocytes observed and vacuolated neutrophils with granulation reinforcement. Hypochromia.', 
    'El herpesvirus varicela-zoster (VZV) es un virus de ADN lineal de cadena doble que pertenece a la familia Herpesviridae. El VZV se caracteriza por su capacidad de permanecer en estado latente en el interior del organismo humano.': 'The varicella-zoster virus (VZV) is a double-stranded linear DNA virus belonging to the Herpesviridae family. VZV is characterized by its ability to remain latent inside the human body.', 
    'Sin otras alteraciones citomorfológicas mas específicas en las tres series.': 'Without other more specific cytomorphological alterations in the three series.', 
    'Población analizada: Linfocitaria (8.5%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (61.39%), 362 cels/μL - Linfocitos T CD4+ (56.47%), 204 cels/μL - Linfocitos T CD8+ (40%), 145 cels/μL Linfocitos B CD19+ CD20+ (22.04%), 130 cels/μL Linfocitos NK T CD3+ CD56+ (3.9%), 23 cels/μL Células NK CD3- CD56+ (11.26%), 66 cels/μL': 'Analyzed population: Lymphocytic (8.5%). The following subpopulations were identified: CD3+ T lymphocytes (61.39%), 362 cells/μL - CD4+ T lymphocytes (56.47%), 204 cells/μL - CD8+ T lymphocytes (40%), 145 cells/μL CD19+ CD20+ B lymphocytes (22.04%), 130 cells/μL CD3+ CD56+ NK T lymphocytes (3.9%), 23 cells/μL CD3- CD56+ NK cells (11.26%), 66 cells/μL', 
    'Población analizada: Linfocitaria (8.86%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (52.17%), 339 cels/μL - Linfocitos T CD4+ (46.72%), 158 cels/μL - Linfocitos T CD8+ (49.54%), 168 cels/μL Linfocitos B CD19+ CD20+ (26.68%), 173 cels/μL Linfocitos NK T CD3+ CD56+ (2.48%), 16 cels/μL Células NK CD3- CD56+ (15.07%), 98 cels/μL': 'Analyzed population: Lymphocytic (8.86%). The following subpopulations were identified: CD3+ T lymphocytes (52.17%), 339 cells/μL - CD4+ T lymphocytes (46.72%), 158 cells/μL - CD8+ T lymphocytes (49.54%), 168 cells/μL CD19+ CD20+ B lymphocytes (26.68%), 173 cells/μL CD3+ CD56+ NK T lymphocytes (2.48%), 16 cells/μL CD3- CD56+ NK cells (15.07%), 98 cells/μL', 
    'Población analizada: Linfocitaria (17.7%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (81.03%), 1353 cels/μL - Linfocitos T CD4+ (78.21%), 1058cels/μL - Linfocitos T CD8+ (19.16%), 259 cels/μL Linfocitos B CD19+ CD20+ (9.94%), 166 cels/μL Linfocitos NK T CD3+ CD56+ (1.8%), 30 cels/μL Células NK CD3- CD56+low (5.76%), 96 cels/μL': 'Analyzed population: Lymphocytic (17.7%). The following subpopulations were identified: CD3+ T lymphocytes (81.03%), 1353 cells/μL - CD4+ T lymphocytes (78.21%), 1058 cells/μL - CD8+ T lymphocytes (19.16%), 259 cells/μL CD19+ CD20+ B lymphocytes (9.94%), 166 cells/μL CD3+ CD56+ NK T lymphocytes (1.8%), 30 cells/μL CD3- CD56+low NK cells (5.76%), 96 cells/μL', 
    'No remite muestra de suero para realizar determinaciones de urea y creatinina.': 'Does not send a serum sample for urea and creatinine determinations.', 
    'Población analizada: Linfocitaria (69%). Se detectan las siguientes subpoblaciones: - Linfocitos T CD3+ (1.25%) - Linfocitos B CD19+ (67.3%). Incluyen: - Linfocitos B clonales (100%). Presentan el siguiente fenotipo patológico: CD19+lo CD20- CD5- CD10- CD20- CD200+ CD11c- CD22- CD23-/+ (35%) CD81- FMC7- CD38- CD45+lo sIgKappa- sIgLambda-. Representan el 46.4 % de la población leucocitaria total analizada. Compatible con SLP-B': 'Analyzed population: Lymphocytic (69%). The following subpopulations are detected: - T lymphocytes CD3+ (1.25%) - B lymphocytes CD19+ (67.3%). These include: - Clonal B lymphocytes (100%). They present the following pathological phenotype: CD19+lo CD20- CD5- CD10- CD20- CD200+ CD11c- CD22- CD23-/+ (35%) CD81- FMC7- CD38- CD45+lo sIgKappa- sIgLambda-. They represent 46.4% of the total leukocyte population analyzed. Compatible with SLP-B', 
    'Población analizada: Linfocitaria (30.2%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (79.09%)': 'Analyzed population: Lymphocytic (30.2%). The following subpopulations are identified: T lymphocytes CD3+ (79.09%)', 
    'Se observan desviación izquierda, neutrófilos vacuolados con refuerzo de la granulación. Linfocitos activados, y algún linfocito grande granular. Anisocromía.': 'Left shift observed, vacuolated neutrophils with granulation reinforcement. Activated lymphocytes, and some large granular lymphocytes. Anisochromia.', 
    'Población analizada: Linfocitaria (24.9%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (76.8%)': 'Population analyzed: Lymphocytic (24.9%). The following subpopulations are identified: CD3+ T lymphocytes (76.8%)',
    'Población analizada: Linfocitaria (14.88%). Se identifican las siguientes subpoblaciones: Linfocitos T CD3+ (74.83%)': 'Population analyzed: Lymphocytic (14.88%). The following subpopulations are identified: CD3+ T lymphocytes (74.83%)', 
    'Fórmula manual: segmentados 21%': 'Manual formula: 21% segmented',
    'Se observan 40 % de células de aspecto bl stico (células de mediano tama¤o con núcleolar, plegado y algunos de aspecto monocitoide con citoplasma amplio y desprovistos de granulación, cromatina laxa visualiz ndose hasta 3 nucleolos). Hallazgos compatibles con leucemia aguda.': '40% of the cells appear blast-like (medium-sized cells with irregular, folded nuclei and some monocytic-like cells with ample cytoplasm, lacking granulation, and loose chromatin showing up to 3 nucleoli) are observed. Findings are compatible with acute leukemia.', 
    'Pruebas a¤adidas a muestra XXXXXXX': 'Test added to sample X', 
    'Población analizada: Leucocitaria. Se distinguen las siguientes subpoblaciones: 1. Células progenitoras CD34+ (2.53%) - Mieloblastos (CD117+): 2.53% 2. Granulocítica-Neutrófilo (50.28%) - Estadío I+II (23.58%) - Estadío III (56.88%) - Estadío IV (6.9%) - Estadío V (12': 'Analyzed population: Leukocytic. The following subpopulations are distinguished: 1. CD34+ Progenitor Cells (2.53%) - Myeloblasts (CD117+): 2.53% 2. Granulocytic-Neutrophil (50.28%) - Stage I+II (23.58%) - Stage III (56.88%) - Stage IV (6.9%) - Stage V (12%)'
}


lab['result_text'] = lab['result_text'].replace(dict_result_text)

print(lab['result_text'].value_counts())

lab['ref_values'] = lab['ref_values'].str.replace('', 'é', regex=False)

val_ref_values = lab[lab['ref_values'].str.contains(r'[a-zA-Z]', na=False)]['ref_values'].value_counts()

# Imprimir los valores únicos encontrados
print("\n", val_ref_values)

dict_ref_values = {
    'Bajo riesgo sepsis: <0.5': 'Low sepsis risk: <0.5',
    'Negativo: <0.9^Zona límite: 0.9-1^Reactivo: >1': 'Negative: <0.9^Borderline: 0.9-1^Reactive: >1',
    'Bajo riesgo sepsis: <0.5^Alto riesgo sepsis: >2': 'Low sepsis risk: <0.5^High sepsis risk: >2',
    'Negativo: <0.9': 'Negative: <0.9',
    'Positivo: >1': 'Positive: >1',
    'Positivo: >10': 'Positive: >10',
    'Negativo: <0.9^Zona límite: 0.9-1.1^Positivo: >1.1': 'Negative: <0.9^Borderline: 0.9-1.1^Positive: >1.1',
    'Límite de detección: 42.5 copias/mL': 'Detection limit: 42.5 copies/mL',
    'Negativo: <10': 'Negative: <10',
    'Positivo: >0.5': 'Positive: >0.5',
    'Negativo: <0.8': 'Negative: <0.8',
    'Negativo: <5': 'Negative: <5',
    'Negativo: <0.8 U/mL': 'Negative: <0.8 U/mL',
    'Extracción matutina: 4.82-19.5': 'Morning draw: 4.82-19.5',
    'Negativo: <0.7': 'Negative: <0.7',
    'Positivo: >1.2': 'Positive: >1.2',
    'Positivo: >1/20': 'Positive: >1/20',
    'Negativo: <0.5': 'Negative: <0.5',
    'Positivo: >1^': 'Positive: >1^',
    'No fumador: <5': 'Non-smoker: <5',
    'Negativo <20 UI/mL': 'Negative <20 IU/mL',
    'Negativo: <0.5^Zona límite: 0.5-1^Positivo: >1': 'Negative: <0.5^Borderline: 0.5-1^Positive: >1',
    'Extracción matutina: 4.82-19.5^Extracción vespertina: 2.47-11.9^': 'Morning draw: 4.82-19.5^Afternoon draw: 2.47-11.9^', 
    'Líquido pleural:': 'Pleural fluid:',
    'Negativo: <10^Positivo: =10^': 'Negative: <10^Positive: =10^',
    'Negativo: <0.7^Zona límite: 0.7-1^Positivo: >1': 'Negative: <0.7^Borderline: 0.7-1^Positive: >1',
    '(1.0 - 1.4)^*Nuevos valores de referencia 07-03-2017': '(1.0 - 1.4)^*New reference values 07-03-2017',
    'Heparinas de bajo peso molecular:': 'Low molecular weight heparins:',
    'Positivo: >1/20^': 'Positive: >1/20^',
    'Hombre: 56 - 84^Mujer:    50 - 70': 'Men: 56 - 84^Women: 50 - 70',
    'Límite de detección: 42.5 copias/mL^Unidades de medida actualizadas a copias/mL': 'Detection limit: 42.5 copies/mL^Units of measure updated to copies/mL',
    ' Cor 43 y HKU): No se detecta - Parainfluenza (HPIV1': 'Cor 43 and HKU): Not detected - Parainfluenza (HPIV1',
    'Negativo <20 UI/mL^Positivo =20 UI/mL^': 'Negative <20 IU/mL^Positive =20 IU/mL^',
    'No embarazo: 85-125': 'Not pregnant: 85-125',
    'Positivo: >1/100': 'Positive: >1/100',
    '<39^Cambio de límite inferior de detección 5/11/2019': '<39^Lower detection limit change 5/11/2019',
    'No fumador: <5^Fumador: <6.5^Cambio de límite inferior de detección 5/11/2019': 'Non-smoker: <5^Smoker: <6.5^Lower detection limit change 5/11/2019',
    'Negativo: <0.6': 'Negative: <0.6',
    'Negativo: <0.8 U/mL^Zona límite: 0.8-1.15 U/mL^Positivo: >1.5 U/mL^': 'Negative: <0.8 U/mL^Borderline: 0.8-1.15 U/mL^Positive: >1.5 U/mL^',
    'Premenopausia: <5.3': 'Premenopause: <5.3',
    'Negativo: <0.8^Zona límite: 0.8-1.1^Positivo: >1.1^': 'Negative: <0.8^Borderline: 0.8-1.1^Positive: >1.1^',
    'Negativo: <5^Indeterminado: 5-8^Positivo: >8^^^': 'Negative: <5^Indeterminate: 5-8^Positive: >8^^^',
    'Negativo: <5^Indeterminado: 5-8^Positivo: >8^': 'Negative: <5^Indeterminate: 5-8^Positive: >8^',
    'Límite de detección: 65.74 copias/mL': 'Detection limit: 65.74 copies/mL',
    'Límite detección: 57.27 copias/mL': 'Detection limit: 57.27 copies/mL',
    '73 m2': '73 m2', 
    'Extracción matutina: 7-63': 'Morning extraction: 7-63',
    'Positivo: >1/10': 'Positive: >1/10',
    'Líquido pleural: 7.07-7.71': 'Pleural fluid: 7.07-7.71',
    '(0.27-4.2)^Embarazo: <4.8^': '(0.27-4.2)^Pregnancy: <4.8^',
    'Positivo: >1:80^': 'Positive: >1:80^',
    'Líquido peritoneal: 88-109': 'Peritoneal fluid: 88-109',
    'Negativo: <1.0': 'Negative: <1.0',
    'Hombre: 56 - 84': 'Men: 56 - 84',
    'Déficit: <20': 'Deficit: <20',
    '60-80^Patológico: <50% glucosa sérica': '60-80^Pathological: <50% serum glucose',
    'Líquido pleural:^Transudado: <200^Exudado: >200^Líquido sinovial: <240': 'Pleural fluid:^Transudate: <200^Exudate: >200^Synovial fluid: <240',
    'Negativo: <0.7^Zona límite: 0.7-1.3^Positivo: >1.3^': 'Negative: <0.7^Borderline: 0.7-1.3^Positive: >1.3^',
    '<35^Cambio de límite inferior de detección 5/11/2019': '<35^Lower detection limit change 5/11/2019',
    'Positivo: >30': 'Positive: >30',
    'Premenopausia: <5.3^Posmenopausia: <8.3^Embarazo:^-Semana 3: 5.8 - 71.2 ^-Semana 4: 9.5 - 750^-Semana 5: 217 - 7138^-Semana 6: 158 - 31795^-Semana 7: 3697 - 163563^-Semana 8: 32065 - 149571^-Semana 9: 63803 - 151410^-Semana 10-11: 46509 - 186977^-Semana 12-13: 27832 - 210612^-Semana 14-15: 12039 - 70971^-Semana 16-18: 8099 - 58176': 'Premenopause: <5.3^Postmenopause: <8.3^Pregnancy:^-Week 3: 5.8 - 71.2^-Week 4: 9.5 - 750^-Week 5: 217 - 7138^-Week 6: 158 - 31795^-Week 7: 3697 - 163563^-Week 8: 32065 - 149571^-Week 9: 63803 - 151410^-Week 10-11: 46509 - 186977^-Week 12-13: 27832 - 210612^-Week 14-15: 12039 - 70971^-Week 16-18: 8099 - 58176',
    'Positivo: >1:20': 'Positive: >1:20',
    'Negativo: <1': 'Negative: <1',
    'Positivo: >1/10^*Nuevos valores de referencia 20-04-2018': 'Positive: >1/10^*New reference values 20-04-2018',
    'Limite de detección: 157 copias/mL': 'Detection limit: 157 copies/mL',
    'Patológico: >5': 'Pathological: >5',
    'Negativo: <0.6^Zona límite: 0.6-1^Positivo: >1': 'Negative: <0.6^Borderline: 0.6-1^Positive: >1',
    'mg/dL': 'mg/dL', 
    '<3^Nuevos valores de referencia 11/12/2019': '<3^New reference values 11/12/2019',
    'Positivo: >1/80^': 'Positive: >1/80^',
    'Negativo: <0.8^Zona límite: 0.8-1^Positivo: >1': 'Negative: <0.8^Borderline: 0.8-1^Positive: >1',
    'No embarazo: 85-125^Embarazo: 150-200': 'Non-pregnancy: 85-125^Pregnancy: 150-200',
    '0.93-1.7^Embarazo:^-Primer trimestre: 0.9-1.5^-Segundo y tercer trimestre: 0.7-1.3': '0.93-1.7^Pregnancy:^-First trimester: 0.9-1.5^-Second and third trimester: 0.7-1.3',
    'Negativo: <1^Zona límite: 1-30^Positivo: >30^Nuevos valores de referencia 6/02/2020': 'Negative: <1^Borderline: 1-30^Positive: >30^New reference values 6/02/2020',
    ' monocitos 0%': 'monocytes 0%',
    ' monocitos 4%': 'monocytes 4%',
    'Positivo: >17': 'Positive: >17',
    ' monocitos 7%': 'monocytes 7%',
    ' monocitos 1%': 'monocytes 1%',
    'Líquido pleural: 0.5-1.4': 'Pleural fluid: 0.5-1.4',
    '<50^*Nueva Técnica 29-08-2019 ': '<50^*New Technique 29-08-2019',
    'Extracción matutina: 7-63^Extracción vespertina: <20': 'Morning extraction: 7-63^Evening extraction: <20',
    'Positivo: >1:100': 'Positive: >1:100',
    ' monocitos 3%': 'monocytes 3%',
    ' monocitos 8%': 'monocytes 8%',
    ' si es posible BAL o BAS)': 'if possible bronchoalveolar lavage or bronchial aspiration',
    'No embarazo: <7^Mediana en embarazo:^-Semana 14: 25.3^-Semana 15: 29.0^-Semana 16: 33.3^-Semana 17: 38.3^-Semana 18: 44.0': 'Non-pregnancy: <7^Median in pregnancy:^-Week 14: 25.3^-Week 15: 29.0^-Week 16: 33.3^-Week 17: 38.3^-Week 18: 44.0',
    'Rango terapeútico: 0.6-1.2': 'Therapeutic range: 0.6-1.2',
    'Positivo: >1:320': 'Positive: >1:320', 
    'Posición ortost tica: 70-300': 'Orthostatic position: 70-300',
    'Pleuritis no tuberculosa: <45': 'Non-tuberculous pleuritis: <45',
    'Rango terapeútico: 0.6-1.2^Toxicidad: >2^': 'Therapeutic range: 0.6-1.2^Toxicity: >2^',
    'Alto riesgo: <0.25': 'High risk: <0.25',
    'Inmunidad adquirida o': 'Acquired immunity',
    'Positivo: >1:12': 'Positive: >1:12',
    'Positivo: >1:192': 'Positive: >1:192',
    'Negativo: <0.9^Zona límite: 0.9-1.1^Positivo: >1.1^*Nuevos valores de referencia desde 22/08/2018': 'Negative: <0.9^Borderline: 0.9-1.1^Positive: >1.1^*New reference values from 22/08/2018',
    'Positivo: >0.35': 'Positive: >0.35',
    'Positivo: >1:40': 'Positive: >1:40',
    'Positivo: >1:4': 'Positive: >1:4',
    ' 858 cels/µL - Linfocitos T CD8+ (14.01%)': '858 cells/µL - CD8+ T lymphocytes (14.01%)',
    ' monocitos 12%': 'monocytes 12%',
    ' 657 cels/µL - Linfocitos T CD8+ (22.14%)': '657 cells/µL - CD8+ T lymphocytes (22.14%)',
    ' 610 cels/µL - Linfocitos T CD8+ (29.51%)': '610 cells/µL - CD8+ T lymphocytes (29.51%)',
    ' 1207 cels/µL - Linfocitos T CD8+ (12.03%)': '1207 cells/µL - CD8+ T lymphocytes (12.03%)',
    ' monocitos 2%. Serie granulocítica con desviación izquierda y formas inmaduras (cayados': 'monocytes 2%. Granulocytic series with left shift and immature forms (bands)',
    ' 471cels/µL - Linfocitos T CD8+ (21.34%)': '471 cells/µL - CD8+ T lymphocytes (21.34%)',
    ' 59 cels/µL - Linfocitos T CD8+ (47.88%)': '59 cells/µL - CD8+ T lymphocytes (47.88%)',
    ' 568 cels/µL - Linfocitos T CD8+ (14.68%)': '568 cells/µL - CD8+ T lymphocytes (14.68%)',
    ' 675 cels/µL - Linfocitos T CD8+ (14.98%)': '675 cells/µL - CD8+ T lymphocytes (14.98%)',
    ' 1193 cels/µL - Linfocitos T CD8+ (12.07%)': '1193 cells/µL - CD8+ T lymphocytes (12.07%)', 
    '867 cels/µL - Linfocitos T CD8+ (28.40%)': '867 cells/µL - CD8+ T lymphocytes (28.40%)',
    ' 663cels/µL - Linfocitos T CD8+ (21.81%)': '663 cells/µL - CD8+ T lymphocytes (21.81%)',
    ' refuerzo de la granulación.': 'granulation reinforcement.',
    ' monocitos 5%': 'monocytes 5%',
    ' monocitos 6%': 'monocytes 6%',
    ' 798 cels/µL - Linfocitos T CD8+ (28.56%)': '798 cells/µL - CD8+ T lymphocytes (28.56%)',
    ' 779 cels/µL - Linfocitos T CD8+ (33.43%)': '779 cells/µL - CD8+ T lymphocytes (33.43%)',
    ' 723 cels/µL - Linfocitos T CD8+ (29.64%)': '723 cells/µL - CD8+ T lymphocytes (29.64%)',
    ' 62 cels/µL - Linfocitos T CD8+ (43.79%)': '62 cells/µL - CD8+ T lymphocytes (43.79%)',
    ' 204 cels/µL - Linfocitos T CD8+ (40%)': '204 cells/µL - CD8+ T lymphocytes (40%)',
    ' algún dianocito. Trombopenia comprobada.': 'some target cells. Confirmed thrombocytopenia.',
    ' 337 cels/µL - Linfocitos T CD8+ (52.46%)': '337 cells/µL - CD8+ T lymphocytes (52.46%)',
    ' 160 cels/µL - Linfocitos T CD8+ (57.80%)': '160 cells/µL - CD8+ T lymphocytes (57.80%)',
    ' 100 cels/µL - Linfocitos T CD8+ (44.67%)': '100 cells/µL - CD8+ T lymphocytes (44.67%)',
    ' 678 cels/µL - Linfocitos T CD8+ (41.51%)': '678 cells/µL - CD8+ T lymphocytes (41.51%)',
    ' 1058cels/µL - Linfocitos T CD8+ (19.16%)': '1058 cells/µL - CD8+ T lymphocytes (19.16%)',
    ' 221 cels/µL - Linfocitos T CD8+ (44.76%)': '221 cells/µL - CD8+ T lymphocytes (44.76%)',
    ' 44 cels/µL - Linfocitos T CD8+ (48.8%)': '44 cells/µL - CD8+ T lymphocytes (48.8%)',
    ' 549 cels/µL - Linfocitos T CD8+ (46.73%)': '549 cells/µL - CD8+ T lymphocytes (46.73%)',
    ' Neutrófilos 37%. Linfocitosis a expensas de linfocitos de pequeño tamaño y aspecto maduro, y sombras de Gumprecht. Compatible con síndrome linfoproliferativo crónico tipo Leucemia Linf tica Crónica.': 'Neutrophils 37%. Lymphocytosis due to small, mature-looking lymphocytes and Gumprecht shadows. Compatible with chronic lymphoproliferative syndrome type Chronic Lymphocytic Leukemia.',
    ' 288 cels/µL - Linfocitos T CD8+ (41.1%)': '288 cells/µL - CD8+ T lymphocytes (41.1%)',
    ' monocitos 10%': 'monocytes 10%', 
    ' 158 cels/µL - Linfocitos T CD8+ (49.54%)': '158 cells/µL - CD8+ T lymphocytes (49.54%)',
    ' Neutrófilos 60%. Recomendamos control evolutivo.': 'Neutrophils 60%. Evolutionary control recommended.',
    ' E2 y NS3': 'E2 and NS3',
    ' 282 cels/µL - Linfocitos T CD8+ (31.82%)': '282 cells/µL - CD8+ T lymphocytes (31.82%)',
    ' 726 cels/µL - Linfocitos T CD8+ (30%)': '726 cells/µL - CD8+ T lymphocytes (30%)',
    ' monocitos 31%': 'monocytes 31%',
    ' 467 cels/µL - Linfocitos T CD8+ (58.9%)': '467 cells/µL - CD8+ T lymphocytes (58.9%)',
    ' 163 cels/µL - Linfocitos T CD8+ (44.07%)': '163 cells/µL - CD8+ T lymphocytes (44.07%)',
    'Negativo: >1.2^Zona límite: 0.9-1.2^Positivo: <0.9': 'Negative: >1.2^Borderline: 0.9-1.2^Positive: <0.9',
    ' 11% eos': '11% eosinophils',
    ' 190 cels/µL - Linfocitos T CD8+ (46.49%)': '190 cells/µL - CD8+ T lymphocytes (46.49%)',
    ' 296 cels/µL - Linfocitos T CD8+ (38%)': '296 cells/µL - CD8+ T lymphocytes (38%)',
    ' 465 cels/µL - Linfocitos T CD8+ (19.16%)': '465 cells/µL - CD8+ T lymphocytes (19.16%)',
    ' 187 cels/µL - Linfocitos T CD8+ (47.24%)': '187 cells/µL - CD8+ T lymphocytes (47.24%)',
    ' algún equinocito y acantocito. Serie blanca con desviación izquierda y refuerzo de la granulación. Linfocitos activados. Trombopenia comprobada.': 'some echinocytes and acanthocytes. White cell series with left shift and granulation reinforcement. Activated lymphocytes. Confirmed thrombocytopenia.',
    ' disnea y tos seca. Algunos pacientes pueden presentar dolores': 'dyspnea and dry cough. Some patients may experience pain',
    ' 8% metamielo': '8% metamyelocytes',
    ' 3% metamielocitos': '3% metamyelocytes',
    'Positivo: >0.2^Enfermedades neuromusculares^o autoinmunes: 0.2-0.5^Miastenia gravis: >0.5': 'Positive: >0.2^Neuromuscular^or autoimmune diseases: 0.2-0.5^Myasthenia gravis: >0.5',
    ' 27 % eos': '27% eosinophils',
    '(2.5-8.0)^Nuevos valores de referencia 20/11/2019': '(2.5-8.0)^New reference values 11/20/2019',
    ' 16% cay': '16% bands',
    ' 1% metamielo': '1% metamyelocytes', 
    'Positivo: =10^': 'Positive: =10^',
    'Negativo: <10^Positivo: =10^^^': 'Negative: <10^Positive: =10^^^',
    'pg/mL': 'pg/mL',
    ' blastos 7%': 'blasts 7%',
    ' 14% linfo': '14% lympho',
    ' presentaron 46 cromosomas sin que se observaran alteraciones estructurales.': 'presented 46 chromosomes with no structural abnormalities observed.',
    ' por favor': 'please',
    ' 8% linfo': '8% lympho',
    ' frecuentes ovalocitos': 'frequent ovalocytes',
    ' 401 cels/µL - Linfocitos T CD8+ (38.16%)': '401 cells/µL - CD8+ T lymphocytes (38.16%)',
    ' 241 cels/µL - Linfocitos T CD8+ (52.5%)': '241 cells/µL - CD8+ T lymphocytes (52.5%)',
    ' 160 cels/µL - Linfocitos T CD8+ (48.7%)': '160 cells/µL - CD8+ T lymphocytes (48.7%)',
    ' 1246 cels/µL - Linfocitos T CD8+ (16.01%)': '1246 cells/µL - CD8+ T lymphocytes (16.01%)',
    'Límite detección: 57.27 copias/mL^Unidades de medida actualizadas a copias/mL.': 'Detection limit: 57.27 copies/mL^Units of measure updated to copies/mL.',
    'Límite de detección: 65.74 copias/mL^Unidades de medida actualizadas a copias/mL.': 'Detection limit: 65.74 copies/mL^Units of measure updated to copies/mL.',
    ' Neutrófilos 64%': 'Neutrophils 64%',
    ' dacriocitos y esquistocitos. Descartar ferronpenia como primera posibilidad.': 'dacrocytes and schistocytes. Rule out iron deficiency as the first possibility.', 
    ' 397 cels/µL - Linfocitos T CD8+ (14.7%)': '397 cells/µL - CD8+ T lymphocytes (14.7%)',
    ' 766 cels/µL - Linfocitos T CD8+ (13.95%)': '766 cells/µL - CD8+ T lymphocytes (13.95%)',
    ' 315 cels/µL - Linfocitos T CD8+ (11.61%)': '315 cells/µL - CD8+ T lymphocytes (11.61%)',
    ' 549 cels/µL - Linfocitos T CD8+ (17.28%)': '549 cells/µL - CD8+ T lymphocytes (17.28%)',
    ' 471 cels/µL - Linfocitos T CD8+ (18.36%)': '471 cells/µL - CD8+ T lymphocytes (18.36%)',
    ' 653 cels/µL - Linfocitos T CD8+ (18.92%)': '653 cells/µL - CD8+ T lymphocytes (18.92%)',
    ' 1743 cels/µL - Linfocitos T CD8+ (16.62%)': '1743 cells/µL - CD8+ T lymphocytes (16.62%)',
    ' se distinguen las siguientes subpoblaciones: - Linfocitos T CD3+ (59': 'the following subpopulations are distinguished: - CD3+ T lymphocytes (59',
    ' 394 cels/µL - Linfocitos T CD8+ (20.47%)': '394 cells/µL - CD8+ T lymphocytes (20.47%)',
    ' 244 cels/µL - Linfocitos T CD8+ (13.13%)': '244 cells/µL - CD8+ T lymphocytes (13.13%)',
    ' 523 cels/µL - Linfocitos T CD8+ (7.25%)': '523 cells/µL - CD8+ T lymphocytes (7.25%)',
    ' 332 cels/µL - Linfocitos T CD8+ (8.2%)': '332 cells/µL - CD8+ T lymphocytes (8.2%)',
    'Líquido ascítico: <164^': 'Ascitic fluid: <164^',
    'Líquido ascítico: <45': 'Ascitic fluid: <45',
    ' algún equinocito y ovalocito. Trombopenia comprobada.': 'some echinocyte and ovalocyte. Confirmed thrombocytopenia.',
    ' 55 cels/µL Linfocitos B clonales (27.2%)': '55 cells/µL Clonal B lymphocytes (27.2%)',
    '25 % segmentados; 5': '25% segmented; 5',
    ' 19 % mielocitos': '19% myelocytes',
    ' algún equinocito.': 'some echinocyte.', 
    '<50^*Nueva Técnica 29-08-2019': '<50^* New Technique 29-09-2019'
}

lab['ref_values'] = lab['ref_values'].replace(dict_ref_values)
val_ref_values_eng = lab[lab['ref_values'].str.contains(r'[a-zA-Z]', na=False)]['ref_values'].value_counts()

# Imprimir los valores únicos encontrados
print("\n", val_ref_values_eng)

lab['ud_result'] = lab['ud_result'].str.replace('', 'é', regex=False)
print(lab['ud_result'].value_counts())

dict_ud_result = {
    'copias/mL': 'copies/mL',  
    ' si es posible BAL o BAS).': 'if possible bronchoalveolar lavage or bronchial aspiration',
    'mU/1000 millones eri': 'mU/1000 million ery',
    ' linfocitos 31%': 'lymphocytes 31%',
    'mcg/dL': 'mcg/dL',
    ' si persisten síntomas).': 'if symptoms persist).',
    ' linfocitos 2%': 'lymphocytes 2%',
    ' se recomienda remitir nueva muestra': 'it is recommended to submit a new sample',
    ' no procede realizar sedimento urinario': 'it is not necessary to perform a urine sediment',
    ' linfocitos 20%': 'lymphocytes 20%',
    'mg/Kg': 'mg/Kg',
    ' 885 cels/µL - Linfocitos T CD4+ (68.98%)': '885 cells/µL - CD4+ T lymphocytes (68.98%)',
    ' 1144 cels/µL - Linfocitos T CD4+ (69.73%)': '1144 cells/µL - CD4+ T lymphocytes (69.73%)',
    ' 1244 cels/µL - Linfocitos T CD4+ (69.71%)': '1244 cells/µL - CD4+ T lymphocytes (69.71%)',
    ' 1067 cels/µL - Linfocitos T CD4+ (68.07%)': '1067 cells/µL - CD4+ T lymphocytes (68.07%)',
    ' Monocitos 2%': 'Monocytes 2%', 
    ' 1205 cels/µL - Linfocitos T CD4+ (64.66%)': '1205 cells/µL - CD4+ T lymphocytes (64.66%)',
    ' 1054 cels/µL - Linfocitos T CD4+ (68.62%)': '1054 cells/µL - CD4+ T lymphocytes (68.62%)',
    ' linfocitos 67%': 'lymphocytes 67%',
    ' eliptocitos': 'elliptocytes',
    ' y sombras de Gumprecht. Compatible con síndrome linfoproliferativo crónico tipo Leucemia Linf tica Crónica.': 'and Gumprecht shadows. Compatible with chronic lymphoproliferative syndrome, chronic lymphocytic leukemia type.',
    ' Monocitos 1%': 'Monocytes 1%',
    ' probable LLC con inmunofenotipo atípico.': 'probable CLL with atypical immunophenotype.',
    '6%)': '6%)',
    ' linfocitos 1%': 'lymphocytes 1%',
    ' tendencia a rouleaux. Punteado basófilo. Frecuentes ovalocitos.': 'tendency to rouleaux formation. Basophilic stippling. Frequent ovalocytes.',
    ' linfocitos 13%': 'lymphocytes 13%',
    ' se recomienda consultar con médico para valorar la realización del estudio de confirmación mediante PCR': 'it is recommended to consult with a doctor to evaluate the performance of confirmation study by PCR',
    ' 875 cels/µL - Linfocitos T CD4+ (75.18%)': '875 cells/µL - CD4+ T lymphocytes (75.18%)',
    ' 1042 cels/µL - Linfocitos T CD4+ (82.34%)': '1042 cells/µL - CD4+ T lymphocytes (82.34%)',
    ' 1421 cels/µL - Linfocitos T CD4+ (84.96%)': '1421 cells/µL - CD4+ T lymphocytes (84.96%)',
    ' 1391 cels/µL - Linfocitos T CD4+ (85.8%)': '1391 cells/µL - CD4+ T lymphocytes (85.8%)',
    ' 689 cels/µL - Linfocitos T CD4+ (82.36%)': '689 cells/µL - CD4+ T lymphocytes (82.36%)',
    ' 827 cels/µL - Linfocitos T CD4+ (81.6%)': '827 cells/µL - CD4+ T lymphocytes (81.6%)',
    ' linfocitos 18%': 'lymphocytes 18%', 
    ' anisocitosis con microcitosis. Se observan algunos dianocitos. Trombopenia comprobada.': 'anisocytosis with microcytosis. Some dianocytes are observed. Confirmed thrombocytopenia.',
    ' sin alteraciones que sugieran hemólisis o causa central de la anemia. Leucocitosis leve con neutrofilia de aspecto reactivo.': 'no changes suggesting hemolysis or central cause of anemia. Mild leukocytosis with reactive neutrophilia.',
    ' presencia de dianocitos. Serie blanca con desviación izquierda': 'presence of dianocytes. White cell series with left shift',
    ' linfocitos 45%': 'lymphocytes 45%',
    ' sin alteraciones morfológicas especificas. Haremos control evolutivo.': 'no specific morphological alterations. We will perform follow-up monitoring.',
    ' 115 cels/µL - Linfocitos T CD4+ (53.44%)': '115 cells/µL - CD4+ T lymphocytes (53.44%)',
    ' linfocitos 19%': 'lymphocytes 19%',
    ' 1353 cels/µL - Linfocitos T CD4+ (78.21%)': '1353 cells/µL - CD4+ T lymphocytes (78.21%)',
    ' 120 cels/µL - Linfocitos T CD4+ (49.46%)': '120 cells/µL - CD4+ T lymphocytes (49.46%)',
    ' 362 cels/µL - Linfocitos T CD4+ (56.47%)': '362 cells/µL - CD4+ T lymphocytes (56.47%)',
    ' 93 cels/µL - Linfocitos T CD4+ (47.6%)': '93 cells/µL - CD4+ T lymphocytes (47.6%)',
    ' 191 cels/µL - Linfocitos T CD4+ (52.07%)': '191 cells/µL - CD4+ T lymphocytes (52.07%)',
    ' 524 cels/µL - Linfocitos T CD4+ (54.99%)': '524 cells/µL - CD4+ T lymphocytes (54.99%)',
    ' neutrófilos con refuerzo en la granulación. Serie roja con anisocromía.': 'neutrophils with enhanced granulation. Red series with anisochromia.',
    ' 339 cels/µL - Linfocitos T CD4+ (46.72%)': '339 cells/µL - CD4+ T lymphocytes (46.72%)',
    ' con algún eliptocito.': 'with some elliptocyte.',
    ' dianocitos y algún equinocito. Se observan agregados plaquetarios.': 'dianocytes and some echinocyte. Platelet aggregates are observed.',
    ' algún dianocito y anulocito. Presencia de agregados plaquearios.': 'some dianocyte and anulocyte. Presence of platelet aggregates.',
    ' C2': 'C2',
    ' 470 cels/µL - Linfocitos T CD4+ (59.99%)': '470 cells/µL - CD4+ T lymphocytes (59.99%)',
    ' linfocitos 40%': 'lymphocytes 40%',
    ' 411 cels/µL - Linfocitos T CD4+ (53.69%)': '411 cells/µL - CD4+ T lymphocytes (53.69%)',
    ' 655 cels/µL - Linfocitos T CD4+ (71.89%)': '655 cells/µL - CD4+ T lymphocytes (71.89%)',
    ' 902 cels/µL - Linfocitos T CD4+ (73.47%)': '902 cells/µL - CD4+ T lymphocytes (73.47%)', 
    ' linfocitos 24%': 'lymphocytes 24%',
    ' algún eliptocito y dacricito. Neutrófilos con refuerzo de la granulación.': 'some elliptocyte and dacryocyte. Neutrophils with granulation reinforcement.',
    ' linfocitos 8%': 'lymphocytes 8%',
    ' envíen nueva muestra': 'send new sample',
    ' equinocitos y eliptocitos. Desviación izquierda.': 'echinocytes and elliptocytes. Left shift.',
    ' 1194 cels/µL - Linfocitos T CD4+ (39.16%)': '1194 cells/µL - CD4+ T lymphocytes (39.16%)',
    ' 1060 cels/µL - Linfocitos T CD4+ (51.78%)': '1060 cells/µL - CD4+ T lymphocytes (51.78%)',
    ' 393 cels/µL - Linfocitos T CD4+ (40.65%)': '393 cells/µL - CD4+ T lymphocytes (40.65%)',
    ' 734 cels/µL - Linfocitos T CD4+ (45.95%)': '734 cells/µL - CD4+ T lymphocytes (45.95%)',
    ' presencia de ovalocitos y eliptocitos': 'presence of ovalocytes and elliptocytes',
    ' 1178 cels/µL - Linfocitos T CD4+ (57.06%)': '1178 cells/µL - CD4+ T lymphocytes (57.06%)',
    ' linfocitos 3%': 'lymphocytes 3%',
    ' SE REQUIERE NUEVA MUESTRA': 'NEW SAMPLE REQUIRED',
    ' algunos hematíes policrom ticos. Frecuentes eliptocitos.': 'some polychromatic erythrocytes. Frequent elliptocytes.',
    'nmol/L': 'nmol/L',
    ' 308 cels/µL - Linfocitos T CD4+ (53.16%)': '308 cells/µL - CD4+ T lymphocytes (53.16%)',
    ' 749 cels/µL - Linfocitos T CD4+ (78.21%)': '749 cells/µL - CD4+ T lymphocytes (78.21%)',
    ' 500 cels/µL - Linfocitos T CD4+ (59.21%)': '500 cells/µL - CD4+ T lymphocytes (59.21%)',
    ' 376 cels/µL - Linfocitos T CD4+ (50.56%)': '376 cells/µL - CD4+ T lymphocytes (50.56%)',
    ' 380 cels/µL - Linfocitos T CD4+ (49.18%)': '380 cells/µL - CD4+ T lymphocytes (49.18%)', 
    ' neutrófilos con hipersegmentación nuclear y refuerzo de la granulación. Trombopenia comprobada.': 'neutrophils with nuclear hypersegmentation and granulation reinforcement. Confirmed thrombocytopenia.',
    ' con frecuentes eliptocitos': 'with frequent elliptocytes',
    ' hipocromos y policrom ticos. Frecuentes ovalocitos. Presencia de linfocitos activados.': 'hypochromic and polychromatic. Frequent ovalocytes. Presence of activated lymphocytes.',
    ' hipocromía y policromasia. Presencia de macrotrombocitos con dilataciones vacuolares en su interior.': 'hypochromia and polychromasia. Presence of macrothrombocytes with vacuolar dilations inside.',
    ' hipocromía': 'hypochromia',
    ' cansancio': 'fatigue',
    ' 8% cay': '8% cay',
    ' 40% cay': '40% cay',
    '75.6': '75.6',
    ' determinación realizada en número XXXXXXX': 'determination made with number X',
    '513.0': '513.0',
    ' 10% cay': '10% cay',
    ' 23% linfo': '23% linfo',
    ' 7% cay': '7% cay',
    '91.1': '91.1',
    '499.0': '499.0',
    '2.1': '2.1',
    ' 2% cay': '2% cay', 
    ' 1% eos': '1% eos',
    'celulas/mm3': 'cells/mm3',
    'XY': 'XY',
    ' todas las metafases analizadas mediante bandas GTL': 'all metaphases analyzed by GTL banding',
    ' 6% cay': '6% cay',
    ' 679 cels/µL - Linfocitos T CD4+ (59.03%)': '679 cells/µL - CD4+ T lymphocytes (59.03%)',
    ' linfocitos 27%': 'lymphocytes 27%',
    ' frecuentes dacriocitos y eliptocitos y algunos eritroblastos ortocrotm ticos. Se observa desviación izquierda. Recuento manual: 44%seg': 'frequent dacryocytes and elliptocytes and some orthochromatic erythroblasts. Left shift observed. Manual count: 44%seg',
    ' 543 cels/µL - Linfocitos T CD4+ (44.4%)': '543 cells/µL - CD4+ T lymphocytes (44.4%)',
    ' se observan frecuentes ovalocitos. Desviación izquierda. Neutrófilos con presencia de granulación tóxica e hipersegmentación nuclear. Se observan agregados plaquetarios.': 'frequent ovalocytes observed. Left shift. Neutrophils with presence of toxic granulation and nuclear hypersegmentation. Platelet aggregates observed.',
    ' 328 cels/µL - Linfocitos T CD4+ (48.7%)': '328 cells/µL - CD4+ T lymphocytes (48.7%)',
    ' no se observan blastos. Neutrófilos con refuerzo de la granulación y cariorrexis nuclear.': 'no blasts observed. Neutrophils with granulation reinforcement and nuclear karyorrhexis.',
    ' Monocitos 5%': 'Monocytes 5%',
    ' presencia de eliptocitos ': 'presence of elliptocytes',
    ' frecuentes macrovalocitos. Se observan desviación izquierda y neutrófilos con refuerzo en la granulación.Trombopenia comprobada.': 'frequent macrovalocytes. Left shift observed and neutrophils with granulation reinforcement. Confirmed thrombocytopenia.',
    ' 714 cels/µL - Linfocitos T CD4+ (76.95%)': '714 cells/µL - CD4+ T lymphocytes (76.95%)',
    ' 375 cels/µL - Linfocitos T CD4+ (84.11%)': '375 cells/µL - CD4+ T lymphocytes (84.11%)',
    ' 934 cels/µL - Linfocitos T CD4+ (81.98%)': '934 cells/µL - CD4+ T lymphocytes (81.98%)',
    ' 486 cels/µL - Linfocitos T CD4+ (81.7%)': '486 cells/µL - CD4+ T lymphocytes (81.7%)',
    ' 587 cels/µL - Linfocitos T CD4+ (80.31%)': '587 cells/µL - CD4+ T lymphocytes (80.31%)', 
    ' presencia de macrovalocitos. Se observa desviación izquierda.': 'presence of macrocytes. Left shift observed.',
    ' 2135 cels/µL - Linfocitos T CD4+ (81.64%)': '2135 cells/µL - CD4+ T lymphocytes (81.64%)',
    ' 1512 cels/µL - Linfocitos T CD4+ (82.47%)': '1512 cells/µL - CD4+ T lymphocytes (82.47%)',
    ' 820 cels/µL - Linfocitos T CD4+ (79.72%)': '820 cells/µL - CD4+ T lymphocytes (79.72%)',
    ' 507 cels/µL - Linfocitos T CD4+ (77.65%)': '507 cells/µL - CD4+ T lymphocytes (77.65%)',
    ' 570 cels/µL - Linfocitos T CD4+ (91.74%)': '570 cells/µL - CD4+ T lymphocytes (91.74%)',
    ' 367 cels/µL - Linfocitos T CD4+ (90.5%)': '367 cells/µL - CD4+ T lymphocytes (90.5%)',
    ' 290 cels/µL - Linfocitos T CD4+ (83.99%)': '290 cells/µL - CD4+ T lymphocytes (83.99%)',
    ' punteado basófilo. Se observan frecuentes dianocitos': 'basophilic stippling. Frequent dianocytes observed',
    ' linfocitos 15%': 'lymphocytes 15%',
    ' alguna de mayor tamño y bien granulada. Resto de las series sin alteraciones destacables. control evolutivo': 'some larger and well-granulated. Rest of the series without notable alterations. Evolutionary control',
    ' 1094 cels/µL Linfocitos B sanos CD19+ CD20+ CD5- sIg Kappa/Lambda policlonal (2.85%)': '1094 cells/µL Healthy B lymphocytes CD19+ CD20+ CD5- sIg Kappa/Lambda polyclonal (2.85%)',
    ' ni el diagnóstico de sospecha orientan hacia la utilización de una sonda específica. En caso de considerarse clinicamente indicada la realización de esta prueba en base a nuevos hallazgos clínicos': 'neither the suspected diagnosis directs towards the use of a specific probe. If clinically indicated based on new clinical findings',
    '63%) 3. Monocítica (3.08%). El 57.8% de la población corresponden a monocitos maduros 4. Eritroide (18.42%) 5. Linfoide': '63%) 3. Monocytic (3.08%). 57.8% of the population are mature monocytes 4. Erythroid (18.42%) 5. Lymphoid',
    ' 4,25 % promielocitos': '4.25% promyelocytes',
    '25 % promielocitos; 19 % mielocitos; 11 % metamielocitos; 6': '25% promyelocytes; 19% myelocytes; 11% metamyelocytes; 6',
    ' sin otras alteraciones morfológicas destacables.': 'no other notable morphological alterations.'
}

lab['ud_result'] = lab['ud_result'].replace(dict_ud_result)

print(lab['ud_result'].value_counts())

lab_columns = ['lab_id', 'patient_id', 'lab_number', 'lab_date', 'time_lab', 'item_lab',
               'val_result', 'result_text', 'ud_result', 'ref_values']

lab = lab.reindex(columns=lab_columns)


lab.to_csv(os.path.join(source_path, "english/lab_06_latin.csv"), sep = ',', encoding='utf8', index=False)

# %%
print(vital_signs.info())
